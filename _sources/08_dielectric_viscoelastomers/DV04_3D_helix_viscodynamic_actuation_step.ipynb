# %% [markdown]
# # Step-change helix actuation
# - Code for 3D large deformation electro-elasticity with u-p formulation
#
# - Electro-viscoelastic actuation of a helical actuator.
# - Uses quadrature representation of internal variable: viscous deformation tensor Cv.
# - VHB material properties taken from Wang et al., JMPS (2016).

# %% [markdown]
# ### Units
# - Length: mm
# - Mass: kg
# - Time:  s
# - Charge: nC
# - Force: mN
# - Stress: kPa
# - Energy: microJ
# - Electric potential: kV
#
# ### Software:
# - Dolfinx v0.8.0

# %% [markdown]
# # Import modules

# %%
# Import FEnicSx/dolfinx
import dolfinx

# For numerical arrays
import numpy as np

# For MPI-based parallelization
from mpi4py import MPI
comm = MPI.COMM_WORLD
rank = comm.Get_rank()

# PETSc solvers
from petsc4py import PETSc

# specific functions from dolfinx modules
from dolfinx import fem, mesh, io, plot, log
from dolfinx.fem import (Constant, dirichletbc, Function, functionspace, Expression )
from dolfinx.fem.petsc import NonlinearProblem
from dolfinx.nls.petsc import NewtonSolver
from dolfinx.io import VTXWriter, XDMFFile


# specific functions from ufl modules
import ufl
from ufl import (TestFunctions, TrialFunction, Identity, grad, det, div, dev, inv, tr, sqrt, conditional ,\
                 gt, dx, inner, derivative, dot, ln, split, exp, eq, cos, acos, ge, le, outer)

# basix finite elements
import basix
from basix.ufl import element, mixed_element, quadrature_element

# Matplotlib for plotting
import matplotlib.pyplot as plt
plt.close('all')

# For timing the code
from datetime import datetime


# Set level of detail for log messages (integer)
# Guide:
# CRITICAL  = 50, // errors that may lead to data corruption
# ERROR     = 40, // things that HAVE gone wrong
# WARNING   = 30, // things that MAY go wrong later
# INFO      = 20, // information of general interest (includes solver info)
# PROGRESS  = 16, // what's happening (broadly)
# TRACE     = 13, // what's happening (in detail)
# DBG       = 10  // sundry
#
log.set_log_level(log.LogLevel.WARNING)

# %% [markdown]
# # Define geometry

# %%
# Read in the 3D mesh and cell tags
with XDMFFile(MPI.COMM_WORLD,"meshes/helix.xdmf",'r') as infile:
    domain = infile.read_mesh(name="Grid",xpath="/Xdmf/Domain")
    cell_tags = infile.read_meshtags(domain,name="Grid")
domain.topology.create_connectivity(domain.topology.dim, domain.topology.dim-1)

# Also read in 2D facets for applying BCs
with XDMFFile(MPI.COMM_WORLD,"meshes/facet_helix.xdmf",'r') as infile:
    facet_tags = infile.read_meshtags(domain,name="Grid")

x = ufl.SpatialCoordinate(domain)

# %% [markdown]
# **Print out the unique cell index numbers**

# %%
top_imap = domain.topology.index_map(2)      # index map of 2D entities in domain
values = np.zeros(top_imap.size_global)      # an array of zeros of the same size as number of 2D entities
values[cell_tags.indices]=cell_tags.values   # populating the array with facet tag index numbers
print(np.unique(cell_tags.values))           # printing the unique indice
# Out:
# [542]

# %%
# # Identify the planar boundaries of the  box mesh
# #
# def Left(x):
#     return np.isclose(x[0], 0.0)
# def LeftCenter(x):
#     return np.logical_and(np.isclose(x[0], 0.0) , np.isclose(x[1], width/2.0))
# def Right(x):
#     return np.isclose(x[0], length)
# def Top(x):
#     return np.isclose(x[1], width)
# def Bottom(x):
#     return np.isclose(x[1], 0.0)
# def Center(x):
#     return np.isclose(x[1], width/2.0)
# def Front(x):
#     return np.isclose(x[2], width)
# def Back(x):
#     return np.isclose(x[2], 0.0)

# # Mark the sub-domains
# boundaries = [(1,Left),(2,LeftCenter),(3,Right),(4,Top),(5,Bottom),(6,Center),(7,Front),(8,Back)]


# # build collections of facets on each subdomain and mark them appropriately.
# facet_indices, facet_markers = [], [] # initalize empty collections of indices and markers.
# fdim = domain.topology.dim - 1 # geometric dimension of the facet (mesh dimension - 1)
# for (marker, locator) in boundaries:
#     facets = mesh.locate_entities(domain, fdim, locator) # an array of all the facets in a 
#                                                          # given subdomain ("locator")
#     facet_indices.append(facets)                         # add these facets to the collection.
#     facet_markers.append(np.full_like(facets, marker))   # mark them with the appropriate index.

# # Format the facet indices and markers as required for use in dolfinx.
# facet_indices = np.hstack(facet_indices).astype(np.int32)
# facet_markers = np.hstack(facet_markers).astype(np.int32)
# sorted_facets = np.argsort(facet_indices)
# # 
# # Add these marked facets as "mesh tags" for later use in BCs.
# facet_tags = mesh.meshtags(domain, fdim, facet_indices[sorted_facets], facet_markers[sorted_facets])

# %% [markdown]
# **Print out the unique facet index numbers**

# %%
top_imap = domain.topology.index_map(2)      # index map of 2D entities in domain (facets)
values = np.zeros(top_imap.size_global)      # an array of zeros of the same size as number of 2D entities
values[facet_tags.indices]=facet_tags.values # populating the array with facet tag index numbers
print(np.unique(facet_tags.values))          # printing the unique indices
# Out:
# [539 540 541]

# %% [markdown]
# # Markers from gmsh
# - Base - 539
# - Outside - 540
# - Inside - 541
# - Whole volume - 542

# %% [markdown]
# **Visualize reference configuration and boundary facets**

# %%
import pyvista
pyvista.set_jupyter_backend('html')
from dolfinx.plot import vtk_mesh
pyvista.start_xvfb()

# initialize a plotter
plotter = pyvista.Plotter()

# Add the mesh.
topology, cell_types, geometry = plot.vtk_mesh(domain, domain.topology.dim)
grid = pyvista.UnstructuredGrid(topology, cell_types, geometry)
plotter.add_mesh(grid, show_edges=True) 

labels = dict(zlabel='Z', xlabel='X', ylabel='Y')
plotter.add_axes(**labels)

plotter.screenshot("results/helix_step_mesh.png")

from IPython.display import Image
Image(filename='results/helix_step_mesh.png')

# %% [markdown]
# ### Un-comment this cell to see an interactive visualization of the mesh

# %%
# plotter.show()

# %% [markdown]
# ## Define boundary and volume integration measure

# %%
# Define the boundary integration measure "ds" using the facet tags,
# also specify the number of surface quadrature points.
ds = ufl.Measure('ds', domain=domain, subdomain_data=facet_tags, metadata={'quadrature_degree':4})

# Define the volume integration measure "dx" 
# also specify the number of volume quadrature points.
dx = ufl.Measure('dx', domain=domain, metadata={'quadrature_degree': 4})

# Create facet to cell connectivity required to determine boundary facets.
domain.topology.create_connectivity(domain.topology.dim, domain.topology.dim)
domain.topology.create_connectivity(domain.topology.dim, domain.topology.dim-1)
domain.topology.create_connectivity(domain.topology.dim-1, domain.topology.dim)

#  Define facet normal
n = ufl.FacetNormal(domain)

# %% [markdown]
# # Material parameters

# %%
# Equilibrium material parameters
#
rho = Constant(domain, PETSc.ScalarType(1e-6))           # 1000 kg/m^3 = 1e-6 kg/mm^3
#
Geq_0   = Constant(domain, PETSc.ScalarType(15.36))      # Shear modulus, kPa
Kbulk   = Constant(domain, PETSc.ScalarType(1e3*Geq_0))  # Bulk modulus, kPa
lambdaL = Constant(domain, PETSc.ScalarType(5.99))        # Arruda-Boyce locking stretch

# Viscoelasticity parameters from Wang et al (2016) for VHB4910
#
Gneq_1  = Constant(domain, PETSc.ScalarType(26.06))    #  Non-equilibrium shear modulus, kPa
tau_1   = Constant(domain, PETSc.ScalarType(0.6074))   #  relaxation time, s
#
Gneq_2  = Constant(domain, PETSc.ScalarType(26.53))    #  Non-equilibrium shear modulus, kPa
tau_2   = Constant(domain, PETSc.ScalarType(6.56))     #  relaxation time, s
#
Gneq_3  = Constant(domain, PETSc.ScalarType(10.83))    #  Non-equilinrium shear modulus, kPa
tau_3   = Constant(domain, PETSc.ScalarType(61.25))    #  relaxation time, s

# Electrostatic  parameters
vareps_0 = Constant(domain, PETSc.ScalarType(8.85E-3)) #  permittivity of free space pF/mm
vareps_r = Constant(domain, PETSc.ScalarType(4.8))     #  relative permittivity, dimensionless
vareps   = vareps_r*vareps_0         #  permittivity of the material

# %% [markdown]
# # Simulation time-control related params

# %%
# start time (sec)
t = 0.0

# total simulation time (sec)
Ttot = 2.5

# decay time constant for phi signal
tau_phi  = Ttot/20.0

# final phi (kV)
phiTot   = 2.0 

# number of steps for this simulation
numSteps = 625

# time step size (sec)
dt = Ttot/numSteps

# Create a constant for the time step
dk = Constant(domain, PETSc.ScalarType(dt))

# Function to linearly ramp up displacement on boundary.
def phiRamp(t):
    phi = phiTot*(1.0-exp(-t/tau_phi))
    return phi


# Generalized-alpha method parameters for calculating acceleration and velocity
alpha   = Constant(domain, PETSc.ScalarType(0.0))
gamma   = Constant(domain, PETSc.ScalarType(0.5+alpha))
beta    = Constant(domain, PETSc.ScalarType(0.25*(gamma+0.5)**2))

# %% [markdown]
# # Function spaces

# %%
U2 = element("Lagrange", domain.basix_cell(), 2, shape=(3,))  # For displacement
P1 = element("Lagrange", domain.basix_cell(), 1)  # For pressure and electric potential
P0 = quadrature_element(domain.basix_cell(), degree=2, scheme="default")
# Note: it seems that for the current version of dolfinx, 
# only degree=2 quadrature elements actually function properly 
# in e.g. visualization interpolations and problem solution.
T0 = basix.ufl.blocked_element(P0, shape=(3, 3)) # for Cv
#
TH = mixed_element([U2, P1, P1])  # Taylor-Hood style mixed element
ME = functionspace(domain, TH)    # Total space for all DOFs
#
V1 = functionspace(domain, P1) # Scalar function space.
V2 = functionspace(domain, U2) # Vector function space
V3 = functionspace(domain, T0) # Tensor function space
#
# Define actual functions with the required DOFs
w = Function(ME)
u, p, phi = split(w) # displacement u, presssure p, and electric potential phi

# A copy of functions to store values in the previous step
w_old  = Function(ME)
u_old, p_old, phi_old = split(w_old)   

# Define test functions   
u_test, p_test, phi_test = TestFunctions(ME)    

# Define trial functions needed for automatic differentiation
dw = TrialFunction(ME)

# Define a tensor-valued function for Cv.
Cv_1_old = Function(V3) 
Cv_2_old = Function(V3) 
Cv_3_old = Function(V3) 

# Functions for storing the velocity and acceleration at prev. step
v_old = Function(V2)
a_old = Function(V2)

# Initial conditions: 

# A function for constructing the identity matrix.
#
# To use the interpolate() feature, this must be defined as a 
# function of x.
def identity(x):
    values = np.zeros((domain.geometry.dim*domain.geometry.dim,
                      x.shape[1]), dtype=np.float64)
    values[0] = 1
    values[4] = 1
    values[8] = 1
    return values

# interpolate the identity onto the tensor-valued Cv function.
Cv_1_old.interpolate(identity)  
Cv_2_old.interpolate(identity) 
Cv_3_old.interpolate(identity)

# %% [markdown]
# # Subroutines for kinematics and constitutive equations

# %%
#------------------------------------------------------------- 
# Utility subroutines
#-------------------------------------------------------------
 
# Subroutine for a "safer" sqrt() function which avoids a divide by zero 
# when differentiated. 
def safe_sqrt(x):
    return sqrt(x + 1.0e-16)


#------------------------------------------------------------- 
# Subroutines for kinematics
#-------------------------------------------------------------

# Deformation gradient 
def F_calc(u):
    Id = Identity(3) 
    F = Id + grad(u) 
    return F

# Subrountine for computing the effective stretch
def lambdaBar_calc(u):
    F = F_calc(u)
    J = det(F)
    Fbar = J**(-1/3)*F
    Cbar = Fbar.T*Fbar
    I1 = tr(Cbar)
    lambdaBar = safe_sqrt(I1/3.0)
    return lambdaBar

#------------------------------------------------------------- 
# Subroutines for computing the viscous flow update
#-------------------------------------------------------------

# Subroutine for computing the viscous stretch Cv at the end of the step.
def Cv_update(u, Cv_old, tau_r):
    F = F_calc(u)
    J = det(F)
    C = F.T*F
    # new update from Shawn here
    Cbar = J**(-2./3.)*C
    fac = Cv_old + (dk/tau_r)*Cbar
    Cv_new = (det(fac))**(-1./3.) * fac
    return Cv_new 
 
#------------------------------------------------------------- 
# Subroutines for calculating the electric field and displacement
#-------------------------------------------------------------

# Referential electric displacement 
def Dmat_calc(u, phi):
    F = F_calc(u)
    J = det(F)
    C = F.T*F
    e_R  = - grad(phi) # referential electric field
    Dmat = vareps * J* inv(C)*e_R
    return Dmat

#------------------------------------------------------------- 
# Subroutines for calculating the Cauchy stress
#-------------------------------------------------------------

# Subroutine for computing the zeta-function in the Arruda-Boyce model.
def zeta_calc(u):
    lambdaBar = lambdaBar_calc(u)
    # Use Pade approximation of Langevin inverse (A. Cohen, 1991)
    # This is sixth-order accurate.
    z = lambdaBar/lambdaL
    z = conditional(gt(z,0.99), 0.99, z) # Keep from blowing up
    beta = z*(3.0 - z**2.0)/(1.0 - z**2.0)
    zeta = (lambdaL/(3*lambdaBar))*beta
    return zeta

# Generalized shear modulus for Arruda-Boyce model
def Geq_AB_calc(u):
    zeta = zeta_calc(u)
    Geq_AB  = Geq_0 * zeta
    return Geq_AB

# Subroutine for calculating the  equilibrium Cauchy stress
def T_eq_calc(u,p):
    F = F_calc(u)
    J = det(F)
    Fbar = J**(-1./3.)*F
    Bbar = Fbar*Fbar.T
    Geq  = Geq_AB_calc(u)
    T_eq = (1/J)* Geq * dev(Bbar) - p * Identity(3)
    return T_eq


# Subroutine for calculating the electrotatic contribution to the Cauchy stress
def T_maxw_calc(u,phi):
    F = F_calc(u)
    e_R  = - grad(phi)    # referential electric field
    e_sp = inv(F.T)*e_R   # spatial electric field 
    # Spatial Maxwel stress
    T_maxw = vareps*(outer(e_sp,e_sp) - 1/2*(inner(e_sp,e_sp))*Identity(3))
    return T_maxw

# Subroutine for the non-equilibrium Cauchy stress.
def T_neq_calc(u, Cv, Gneq):
    F  = F_calc(u)
    J = det(F)
    C = F.T*F
    # Shawn update here
    Fbar = J**(-1./3.) * F
    Cbar = J**(-2./3.) * C
    T_neq = J**(-1.) * Gneq * (Fbar * inv(Cv) * Fbar.T - (1./3.) * inner(Cbar, inv(Cv)) * Identity(3) ) 
    return T_neq

#------------------------------------------------------------- 
# Subroutine for calculating the total Piola stress
#-------------------------------------------------------------
   
# Subroutine for the total Piola stress.
def  Piola_calc(u, p, Cv_1, Cv_2, Cv_3, Gneq_1, Gneq_2, Gneq_3):
    F  = F_calc(u)
    J = det(F)
    
    T_eq = T_eq_calc(u,p)
    
    T_maxw = T_maxw_calc(u,phi)
    
    T_neq_1 = T_neq_calc(u, Cv_1, Gneq_1)
    
    T_neq_2 = T_neq_calc(u, Cv_2, Gneq_2)
        
    T_neq_3 = T_neq_calc(u, Cv_3, Gneq_3)
    
    T = T_eq + T_maxw + T_neq_1 + T_neq_2 + T_neq_3
    
    Piola = J*T*inv(F.T)
    
    return Piola

#---------------------------------------------------------------------
# Subroutine for updating  acceleration using the Newmark beta method:
# a = 1/(2*beta)*((u - u0 - v0*dt)/(0.5*dt*dt) - (1-2*beta)*a0)
#---------------------------------------------------------------------
def update_a(u, u_old, v_old, a_old):
    return (u-u_old-dk*v_old)/beta/dk**2 - (1-2*beta)/2/beta*a_old

#---------------------------------------------------------------------
# Subroutine for updating  velocity using the Newmark beta method
# v = dt * ((1-gamma)*a0 + gamma*a) + v0
#---------------------------------------------------------------------
def update_v(a, u_old, v_old, a_old):
    return v_old + dk*((1-gamma)*a_old + gamma*a)

#---------------------------------------------------------------------
# alpha-method averaging function
#---------------------------------------------------------------------
def avg(x_old, x_new, alpha):
    return alpha*x_old + (1-alpha)*x_new

# %% [markdown]
# # Evaluate kinematics and constitutive relations

# %%
# Get acceleration and velocity at end of step
a_new = update_a(u, u_old, v_old, a_old)
v_new = update_v(a_new, u_old, v_old, a_old)

# get avg (u,p) fields for generalized-alpha method
u_avg  = avg(u_old, u, alpha)
p_avg  = avg(p_old, p, alpha)

# Kinematical quantities
F  = F_calc(u_avg)
J  = det(F)
lambdaBar = lambdaBar_calc(u_avg)

# update the Cv tensors
Cv_1 = Cv_update(u_avg, Cv_1_old, tau_1)
Cv_2 = Cv_update(u_avg, Cv_2_old, tau_2)
Cv_3 = Cv_update(u_avg, Cv_3_old, tau_3)

# Referential electric displacement
Dmat = Dmat_calc(u_avg, phi)

#  Evaulate the total Piola stress
Piola = Piola_calc(u_avg, p_avg, Cv_1, Cv_2, Cv_3, Gneq_1, Gneq_2, Gneq_3)

# %% [markdown]
# # Weak forms

# %%
# The weak form for the equilibrium equation
#
Res_1  =  inner( Piola, grad(u_test))*dx \
    + inner(rho*a_new, u_test)*dx 
              
# The auxiliary equation for the pressure
#
Res_2 = inner((p_avg/Kbulk + ln(J)/J) , p_test)*dx

#  The weak form for Gauss's equation
Res_3 = inner(Dmat, grad(phi_test))*dx 

# The total residual
Res = Res_1 + Res_2 + Res_3

# Automatic differentiation tangent:
a = derivative(Res, w, dw)

# %% [markdown]
# # Set-up output files

# %%
# results file name
results_name = "helix_step"

# Function space for projection of results
P1 = element("Lagrange", domain.basix_cell(), 1)
VV1 = fem.functionspace(domain, P1) # linear scalar function space
#
U1 = element("Lagrange", domain.basix_cell(), 1, shape=(3,)) 
VV2 = fem.functionspace(domain, U1) # linear Vector function space
#
T1 = element("Lagrange", domain.basix_cell(), 1, shape=(3,3)) 
VV3 = fem.functionspace(domain, T1) # linear tensor function space

# For visualization purposes, we need to re-project the stress tensor onto a linear function space before 
# we write it (and its components and the von Mises stress, etc) to the VTX file. 
#
# This is because the stress is a complicated "mixed" function of the (quadratic Lagrangian) displacements
# and the (quadrature representation) plastic strain tensor and scalar equivalent plastic strain. 
#
# First, define a function for setting up this kind of projection problem for visualization purposes:
def setup_projection(u, V):

    trial = ufl.TrialFunction(V)
    test  = ufl.TestFunction(V)   

    a = ufl.inner(trial, test)*dx
    L = ufl.inner(u, test)*dx

    projection_problem = dolfinx.fem.petsc.LinearProblem(a, L, [], \
        petsc_options={"ksp_type": "cg", "ksp_rtol": 1e-16, "ksp_atol": 1e-16, "ksp_max_it": 1000})
    
    return projection_problem

# Create a linear problem for projecting the stress tensor onto the linear tensor function space VV3.
#
tensor_projection_problem = setup_projection(Piola, VV3)
Piola_temp = tensor_projection_problem.solve()

# %%
# primary fields to write to output file
u_vis      = Function(VV2, name="disp")
p_vis      = Function(VV1, name="p")
phi_vis    = Function(VV1, name="phi")

# %%
# Mises stress
T     = Piola_temp*F.T/J
T0    = T - (1/3)*tr(T)*Identity(3)
Mises = sqrt((3/2)*inner(T0, T0))
Mises_vis= Function(VV1,name="Mises")
Mises_expr = Expression(Mises,VV1.element.interpolation_points())

# Cauchy stress components
T11 = Function(VV1)
T11.name = "T11"
T11_expr = Expression(T[0,0],VV1.element.interpolation_points())

T22 = Function(VV1)
T22.name = "T22"
T22_expr = Expression(T[1,1],VV1.element.interpolation_points())

T33 = Function(VV1)
T33.name = "T33"
T33_expr = Expression(T[2,2],VV1.element.interpolation_points())

# %%
# Stretch measure
lambdaBar_vis      = Function(VV1)
lambdaBar_vis.name = "lambdaBar"
lambdaBar_expr     = Expression(lambdaBar, VV1.element.interpolation_points())

# Volumetric deformation
J_vis      = Function(VV1)
J_vis.name = "J"
J_expr     = Expression(J, VV1.element.interpolation_points())

# %%
# set up the output VTX files.
file_results = VTXWriter(
    MPI.COMM_WORLD,
    "results/" + results_name + ".bp",
    [  # put the functions here you wish to write to output
        u_vis, p_vis, phi_vis, # DOF outputs
        Mises_vis, T11, T22, T33, # stress outputs
        lambdaBar_vis, J_vis, # Kinematical outputs
    ],
    engine="BP4",
)

def writeResults(t):
    
    # Update the output fields before writing to VTX.
    #
    u_vis.interpolate(w.sub(0))
    p_vis.interpolate(w.sub(1))
    phi_vis.interpolate(w.sub(2))
    #
    # re-project to smooth visualization of quadrature functions
    # before interpolating.
    Piola_temp = tensor_projection_problem.solve()
    Mises_vis.interpolate(Mises_expr)
    T11.interpolate(T11_expr)
    T22.interpolate(T22_expr)
    T33.interpolate(T33_expr)
    #
    lambdaBar_vis.interpolate(lambdaBar_expr)
    J_vis.interpolate(J_expr)
       
    # Finally, write output fields to VTX.
    #
    file_results.write(t)

# %% [markdown]
# # Infrastructure for pulling out time history data (force, displacement, etc.)

# %%
# # computing the reaction force using the stress field
# traction = dot(Piola_temp, n)
# Force    = dot(traction, n)*ds(4)
# rxnForce = fem.form(Force)

# %%
# infrastructure for evaluating functions at a certain point efficiently
IntTol = 1.e-3 # tolerance for interpolating surface quantities, mesh is not totally precise.
pointForEval = np.array([5.1-IntTol, -IntTol, 35-IntTol])

bb_tree = dolfinx.geometry.bb_tree(domain,domain.topology.dim)
cell_candidates = dolfinx.geometry.compute_collisions_points(bb_tree, pointForEval)
colliding_cells = dolfinx.geometry.compute_colliding_cells(domain, cell_candidates, pointForEval).array

# %% [markdown]
# ## Boundary condtions

# %%
# Constant for applied electric potential
phi_cons = Constant(domain,PETSc.ScalarType(phiRamp(0)))

# Find the specific DOFs which will be constrained.
Base_u1_dofs = fem.locate_dofs_topological(ME.sub(0).sub(0), facet_tags.dim, facet_tags.find(539))
Base_u2_dofs = fem.locate_dofs_topological(ME.sub(0).sub(1), facet_tags.dim, facet_tags.find(539))
Base_u3_dofs = fem.locate_dofs_topological(ME.sub(0).sub(2), facet_tags.dim, facet_tags.find(539))
#
Inside_phi_dofs = fem.locate_dofs_topological(ME.sub(2), facet_tags.dim, facet_tags.find(541))
Outside_phi_dofs = fem.locate_dofs_topological(ME.sub(2), facet_tags.dim, facet_tags.find(540))


# building Dirichlet BCs
bcs_1 = dirichletbc(0.0, Base_u1_dofs, ME.sub(0).sub(0))  # u1 fix - Base
bcs_2 = dirichletbc(0.0, Base_u2_dofs, ME.sub(0).sub(1))  # u2 fix - Base
bcs_3 = dirichletbc(0.0, Base_u3_dofs, ME.sub(0).sub(2))  # u3 fix - Base
#
bcs_4 = dirichletbc(phi_cons, Outside_phi_dofs, ME.sub(2))  # phi ramp - Outside
bcs_5 = dirichletbc(0.0, Inside_phi_dofs, ME.sub(2))        # phi ground - Inside

bcs = [bcs_1, bcs_2, bcs_3, bcs_4, bcs_5]

# %% [markdown]
# ## Define the nonlinear variational problem

# %%
# Set up nonlinear problem
problem = NonlinearProblem(Res, w, bcs, a)

# the global newton solver and params
solver = NewtonSolver(MPI.COMM_WORLD, problem)
solver.convergence_criterion = "incremental"
solver.rtol = 1e-8
solver.atol = 1e-8
solver.max_it = 50
solver.report = True

#  The Krylov solver parameters.
ksp = solver.krylov_solver
opts = PETSc.Options()
option_prefix = ksp.getOptionsPrefix()
opts[f"{option_prefix}ksp_type"] = "preonly" # "preonly" works equally well
opts[f"{option_prefix}pc_type"] = "lu" # do not use 'gamg' pre-conditioner
opts[f"{option_prefix}pc_factor_mat_solver_type"] = "mumps"
opts[f"{option_prefix}ksp_max_it"] = 30
ksp.setFromOptions()

# %% [markdown]
# ##  Start calculation loop

# %%
# Give the step a descriptive name
step = "Actuate"

# Variables for storing time history
totSteps = 1000000
timeHist0 = np.zeros(shape=[totSteps])
timeHist1 = np.zeros(shape=[totSteps])
timeHist2 = np.zeros(shape=[totSteps])

# Iinitialize a counter for reporting data
ii=0

#  Set up temporary "helper" functions and expressions 
#  for updating the internal variables.
#
# For the Cv tensors:
Cv_1_temp = Function(V3)
Cv_1_expr = Expression(Cv_1, V3.element.interpolation_points())
#
Cv_2_temp = Function(V3)
Cv_2_expr = Expression(Cv_2, V3.element.interpolation_points())
#
Cv_3_temp = Function(V3)
Cv_3_expr = Expression(Cv_3, V3.element.interpolation_points())
#
# and also for the velocity and acceleration.
v_temp = Function(V2)
a_temp = Function(V2)
#
v_expr = Expression(v_new,V2.element.interpolation_points())
a_expr = Expression(a_new,V2.element.interpolation_points())

# Write initial state to file
writeResults(t=0.0)    

# print a message for simulation startup
print("------------------------------------")
print("Simulation Start")
print("------------------------------------")
# Store start time 
startTime = datetime.now()

# Time-stepping solution procedure loop
while (round(t + dt, 9) <= Ttot):
  
    # increment time
    t += dt 
    
    # increment counter
    ii += 1
    
    # update time variables in time-dependent BCs 
    phi_cons.value = phiRamp(t)
    
    # Solve the problem
    try:
      (iter, converged) = solver.solve(w)
    except: # Break the loop if solver fails
      print("Did not converge, stopping")
      break
        
    # Collect results from MPI ghost processes
    w.x.scatter_forward()

    # Print progress of calculation         
    if ii%1 == 0:
      now = datetime.now()
      current_time = now.strftime("%H:%M:%S")
      print("Step: {} | Increment: {} | Iterations: {}".format(step, ii, iter))
      print("dt: {} | Simulation Time: {} s | Percent of total time: {}%".format(round(dt,4), round(t,4), round(100*t/Ttot,4)))
      print() 
      
    # Write output to file
    writeResults(t)
       
       
    # Store time history variables at this time
    timeHist0[ii] = w.sub(0).sub(1).eval([5.1-IntTol, -IntTol, 35-IntTol],colliding_cells[0])[0] # time history of displacement at a point
    timeHist1[ii] = w.sub(2).eval([5.1-IntTol, -IntTol, 35-IntTol],colliding_cells[0])[0] # time history of voltage phi at a point
    timeHist2[ii] = t # current time
    
    
    # update internal variables 
    #
    # interpolate the values of the internal variables into their "temp" functions
    Cv_1_temp.interpolate(Cv_1_expr)
    Cv_2_temp.interpolate(Cv_2_expr)
    Cv_3_temp.interpolate(Cv_3_expr)
    #
    v_temp.interpolate(v_expr)
    a_temp.interpolate(a_expr)
    
    # Update DOFs for next step
    w_old.x.array[:] = w.x.array
    
    # update the old values of internal variables for next step
    Cv_1_old.x.array[:] = Cv_1_temp.x.array[:]
    Cv_2_old.x.array[:] = Cv_2_temp.x.array[:]
    Cv_3_old.x.array[:] = Cv_3_temp.x.array[:]
    #
    v_old.x.array[:] = v_temp.x.array[:]
    a_old.x.array[:] = a_temp.x.array[:]
    

    
# close the output file.
file_results.close()
         
# End analysis
print("-----------------------------------------")
print("End computation")                 
# Report elapsed real time for the analysis
endTime = datetime.now()
elapseTime = endTime - startTime
print("------------------------------------------")
print("Elapsed real time:  {}".format(elapseTime))
print("------------------------------------------")
# Out:
# ------------------------------------
# Simulation Start
# ------------------------------------
# Step: Actuate | Increment: 1 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.004 s | Percent of total time: 0.16%
#
# Step: Actuate | Increment: 2 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.008 s | Percent of total time: 0.32%
#
# Step: Actuate | Increment: 3 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.012 s | Percent of total time: 0.48%
#
# Step: Actuate | Increment: 4 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.016 s | Percent of total time: 0.64%
#
# Step: Actuate | Increment: 5 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.02 s | Percent of total time: 0.8%
#
# Step: Actuate | Increment: 6 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.024 s | Percent of total time: 0.96%
#
# Step: Actuate | Increment: 7 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.028 s | Percent of total time: 1.12%
#
# Step: Actuate | Increment: 8 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.032 s | Percent of total time: 1.28%
#
# Step: Actuate | Increment: 9 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.036 s | Percent of total time: 1.44%
#
# Step: Actuate | Increment: 10 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.04 s | Percent of total time: 1.6%
#
# Step: Actuate | Increment: 11 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.044 s | Percent of total time: 1.76%
#
# Step: Actuate | Increment: 12 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.048 s | Percent of total time: 1.92%
#
# Step: Actuate | Increment: 13 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.052 s | Percent of total time: 2.08%
#
# Step: Actuate | Increment: 14 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.056 s | Percent of total time: 2.24%
#
# Step: Actuate | Increment: 15 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.06 s | Percent of total time: 2.4%
#
# Step: Actuate | Increment: 16 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.064 s | Percent of total time: 2.56%
#
# Step: Actuate | Increment: 17 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.068 s | Percent of total time: 2.72%
#
# Step: Actuate | Increment: 18 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.072 s | Percent of total time: 2.88%
#
# Step: Actuate | Increment: 19 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.076 s | Percent of total time: 3.04%
#
# Step: Actuate | Increment: 20 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.08 s | Percent of total time: 3.2%
#
# Step: Actuate | Increment: 21 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.084 s | Percent of total time: 3.36%
#
# Step: Actuate | Increment: 22 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.088 s | Percent of total time: 3.52%
#
# Step: Actuate | Increment: 23 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.092 s | Percent of total time: 3.68%
#
# Step: Actuate | Increment: 24 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.096 s | Percent of total time: 3.84%
#
# Step: Actuate | Increment: 25 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.1 s | Percent of total time: 4.0%
#
# Step: Actuate | Increment: 26 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.104 s | Percent of total time: 4.16%
#
# Step: Actuate | Increment: 27 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.108 s | Percent of total time: 4.32%
#
# Step: Actuate | Increment: 28 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.112 s | Percent of total time: 4.48%
#
# Step: Actuate | Increment: 29 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.116 s | Percent of total time: 4.64%
#
# Step: Actuate | Increment: 30 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.12 s | Percent of total time: 4.8%
#
# Step: Actuate | Increment: 31 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.124 s | Percent of total time: 4.96%
#
# Step: Actuate | Increment: 32 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.128 s | Percent of total time: 5.12%
#
# Step: Actuate | Increment: 33 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.132 s | Percent of total time: 5.28%
#
# Step: Actuate | Increment: 34 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.136 s | Percent of total time: 5.44%
#
# Step: Actuate | Increment: 35 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.14 s | Percent of total time: 5.6%
#
# Step: Actuate | Increment: 36 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.144 s | Percent of total time: 5.76%
#
# Step: Actuate | Increment: 37 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.148 s | Percent of total time: 5.92%
#
# Step: Actuate | Increment: 38 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.152 s | Percent of total time: 6.08%
#
# Step: Actuate | Increment: 39 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.156 s | Percent of total time: 6.24%
#
# Step: Actuate | Increment: 40 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.16 s | Percent of total time: 6.4%
#
# Step: Actuate | Increment: 41 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.164 s | Percent of total time: 6.56%
#
# Step: Actuate | Increment: 42 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.168 s | Percent of total time: 6.72%
#
# Step: Actuate | Increment: 43 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.172 s | Percent of total time: 6.88%
#
# Step: Actuate | Increment: 44 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.176 s | Percent of total time: 7.04%
#
# Step: Actuate | Increment: 45 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.18 s | Percent of total time: 7.2%
#
# Step: Actuate | Increment: 46 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.184 s | Percent of total time: 7.36%
#
# Step: Actuate | Increment: 47 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.188 s | Percent of total time: 7.52%
#
# Step: Actuate | Increment: 48 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.192 s | Percent of total time: 7.68%
#
# Step: Actuate | Increment: 49 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.196 s | Percent of total time: 7.84%
#
# Step: Actuate | Increment: 50 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.2 s | Percent of total time: 8.0%
#
# Step: Actuate | Increment: 51 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.204 s | Percent of total time: 8.16%
#
# Step: Actuate | Increment: 52 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.208 s | Percent of total time: 8.32%
#
# Step: Actuate | Increment: 53 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.212 s | Percent of total time: 8.48%
#
# Step: Actuate | Increment: 54 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.216 s | Percent of total time: 8.64%
#
# Step: Actuate | Increment: 55 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.22 s | Percent of total time: 8.8%
#
# Step: Actuate | Increment: 56 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.224 s | Percent of total time: 8.96%
#
# Step: Actuate | Increment: 57 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.228 s | Percent of total time: 9.12%
#
# Step: Actuate | Increment: 58 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.232 s | Percent of total time: 9.28%
#
# Step: Actuate | Increment: 59 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.236 s | Percent of total time: 9.44%
#
# Step: Actuate | Increment: 60 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.24 s | Percent of total time: 9.6%
#
# Step: Actuate | Increment: 61 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.244 s | Percent of total time: 9.76%
#
# Step: Actuate | Increment: 62 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.248 s | Percent of total time: 9.92%
#
# Step: Actuate | Increment: 63 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.252 s | Percent of total time: 10.08%
#
# Step: Actuate | Increment: 64 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.256 s | Percent of total time: 10.24%
#
# Step: Actuate | Increment: 65 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.26 s | Percent of total time: 10.4%
#
# Step: Actuate | Increment: 66 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.264 s | Percent of total time: 10.56%
#
# Step: Actuate | Increment: 67 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.268 s | Percent of total time: 10.72%
#
# Step: Actuate | Increment: 68 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.272 s | Percent of total time: 10.88%
#
# Step: Actuate | Increment: 69 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.276 s | Percent of total time: 11.04%
#
# Step: Actuate | Increment: 70 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.28 s | Percent of total time: 11.2%
#
# Step: Actuate | Increment: 71 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.284 s | Percent of total time: 11.36%
#
# Step: Actuate | Increment: 72 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.288 s | Percent of total time: 11.52%
#
# Step: Actuate | Increment: 73 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.292 s | Percent of total time: 11.68%
#
# Step: Actuate | Increment: 74 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.296 s | Percent of total time: 11.84%
#
# Step: Actuate | Increment: 75 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.3 s | Percent of total time: 12.0%
#
# Step: Actuate | Increment: 76 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.304 s | Percent of total time: 12.16%
#
# Step: Actuate | Increment: 77 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.308 s | Percent of total time: 12.32%
#
# Step: Actuate | Increment: 78 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.312 s | Percent of total time: 12.48%
#
# Step: Actuate | Increment: 79 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.316 s | Percent of total time: 12.64%
#
# Step: Actuate | Increment: 80 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.32 s | Percent of total time: 12.8%
#
# Step: Actuate | Increment: 81 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.324 s | Percent of total time: 12.96%
#
# Step: Actuate | Increment: 82 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.328 s | Percent of total time: 13.12%
#
# Step: Actuate | Increment: 83 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.332 s | Percent of total time: 13.28%
#
# Step: Actuate | Increment: 84 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.336 s | Percent of total time: 13.44%
#
# Step: Actuate | Increment: 85 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.34 s | Percent of total time: 13.6%
#
# Step: Actuate | Increment: 86 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.344 s | Percent of total time: 13.76%
#
# Step: Actuate | Increment: 87 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.348 s | Percent of total time: 13.92%
#
# Step: Actuate | Increment: 88 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.352 s | Percent of total time: 14.08%
#
# Step: Actuate | Increment: 89 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.356 s | Percent of total time: 14.24%
#
# Step: Actuate | Increment: 90 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.36 s | Percent of total time: 14.4%
#
# Step: Actuate | Increment: 91 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.364 s | Percent of total time: 14.56%
#
# Step: Actuate | Increment: 92 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.368 s | Percent of total time: 14.72%
#
# Step: Actuate | Increment: 93 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.372 s | Percent of total time: 14.88%
#
# Step: Actuate | Increment: 94 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.376 s | Percent of total time: 15.04%
#
# Step: Actuate | Increment: 95 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.38 s | Percent of total time: 15.2%
#
# Step: Actuate | Increment: 96 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.384 s | Percent of total time: 15.36%
#
# Step: Actuate | Increment: 97 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.388 s | Percent of total time: 15.52%
#
# Step: Actuate | Increment: 98 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.392 s | Percent of total time: 15.68%
#
# Step: Actuate | Increment: 99 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.396 s | Percent of total time: 15.84%
#
# Step: Actuate | Increment: 100 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.4 s | Percent of total time: 16.0%
#
# Step: Actuate | Increment: 101 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.404 s | Percent of total time: 16.16%
#
# Step: Actuate | Increment: 102 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.408 s | Percent of total time: 16.32%
#
# Step: Actuate | Increment: 103 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.412 s | Percent of total time: 16.48%
#
# Step: Actuate | Increment: 104 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.416 s | Percent of total time: 16.64%
#
# Step: Actuate | Increment: 105 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.42 s | Percent of total time: 16.8%
#
# Step: Actuate | Increment: 106 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.424 s | Percent of total time: 16.96%
#
# Step: Actuate | Increment: 107 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.428 s | Percent of total time: 17.12%
#
# Step: Actuate | Increment: 108 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.432 s | Percent of total time: 17.28%
#
# Step: Actuate | Increment: 109 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.436 s | Percent of total time: 17.44%
#
# Step: Actuate | Increment: 110 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.44 s | Percent of total time: 17.6%
#
# Step: Actuate | Increment: 111 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.444 s | Percent of total time: 17.76%
#
# Step: Actuate | Increment: 112 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.448 s | Percent of total time: 17.92%
#
# Step: Actuate | Increment: 113 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.452 s | Percent of total time: 18.08%
#
# Step: Actuate | Increment: 114 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.456 s | Percent of total time: 18.24%
#
# Step: Actuate | Increment: 115 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.46 s | Percent of total time: 18.4%
#
# Step: Actuate | Increment: 116 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.464 s | Percent of total time: 18.56%
#
# Step: Actuate | Increment: 117 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.468 s | Percent of total time: 18.72%
#
# Step: Actuate | Increment: 118 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.472 s | Percent of total time: 18.88%
#
# Step: Actuate | Increment: 119 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.476 s | Percent of total time: 19.04%
#
# Step: Actuate | Increment: 120 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.48 s | Percent of total time: 19.2%
#
# Step: Actuate | Increment: 121 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.484 s | Percent of total time: 19.36%
#
# Step: Actuate | Increment: 122 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.488 s | Percent of total time: 19.52%
#
# Step: Actuate | Increment: 123 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.492 s | Percent of total time: 19.68%
#
# Step: Actuate | Increment: 124 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.496 s | Percent of total time: 19.84%
#
# Step: Actuate | Increment: 125 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.5 s | Percent of total time: 20.0%
#
# Step: Actuate | Increment: 126 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.504 s | Percent of total time: 20.16%
#
# Step: Actuate | Increment: 127 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.508 s | Percent of total time: 20.32%
#
# Step: Actuate | Increment: 128 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.512 s | Percent of total time: 20.48%
#
# Step: Actuate | Increment: 129 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.516 s | Percent of total time: 20.64%
#
# Step: Actuate | Increment: 130 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.52 s | Percent of total time: 20.8%
#
# Step: Actuate | Increment: 131 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.524 s | Percent of total time: 20.96%
#
# Step: Actuate | Increment: 132 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.528 s | Percent of total time: 21.12%
#
# Step: Actuate | Increment: 133 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.532 s | Percent of total time: 21.28%
#
# Step: Actuate | Increment: 134 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.536 s | Percent of total time: 21.44%
#
# Step: Actuate | Increment: 135 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.54 s | Percent of total time: 21.6%
#
# Step: Actuate | Increment: 136 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.544 s | Percent of total time: 21.76%
#
# Step: Actuate | Increment: 137 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.548 s | Percent of total time: 21.92%
#
# Step: Actuate | Increment: 138 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.552 s | Percent of total time: 22.08%
#
# Step: Actuate | Increment: 139 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.556 s | Percent of total time: 22.24%
#
# Step: Actuate | Increment: 140 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.56 s | Percent of total time: 22.4%
#
# Step: Actuate | Increment: 141 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.564 s | Percent of total time: 22.56%
#
# Step: Actuate | Increment: 142 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.568 s | Percent of total time: 22.72%
#
# Step: Actuate | Increment: 143 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.572 s | Percent of total time: 22.88%
#
# Step: Actuate | Increment: 144 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.576 s | Percent of total time: 23.04%
#
# Step: Actuate | Increment: 145 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.58 s | Percent of total time: 23.2%
#
# Step: Actuate | Increment: 146 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.584 s | Percent of total time: 23.36%
#
# Step: Actuate | Increment: 147 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.588 s | Percent of total time: 23.52%
#
# Step: Actuate | Increment: 148 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.592 s | Percent of total time: 23.68%
#
# Step: Actuate | Increment: 149 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.596 s | Percent of total time: 23.84%
#
# Step: Actuate | Increment: 150 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.6 s | Percent of total time: 24.0%
#
# Step: Actuate | Increment: 151 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.604 s | Percent of total time: 24.16%
#
# Step: Actuate | Increment: 152 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.608 s | Percent of total time: 24.32%
#
# Step: Actuate | Increment: 153 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.612 s | Percent of total time: 24.48%
#
# Step: Actuate | Increment: 154 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.616 s | Percent of total time: 24.64%
#
# Step: Actuate | Increment: 155 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.62 s | Percent of total time: 24.8%
#
# Step: Actuate | Increment: 156 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.624 s | Percent of total time: 24.96%
#
# Step: Actuate | Increment: 157 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.628 s | Percent of total time: 25.12%
#
# Step: Actuate | Increment: 158 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.632 s | Percent of total time: 25.28%
#
# Step: Actuate | Increment: 159 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.636 s | Percent of total time: 25.44%
#
# Step: Actuate | Increment: 160 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.64 s | Percent of total time: 25.6%
#
# Step: Actuate | Increment: 161 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.644 s | Percent of total time: 25.76%
#
# Step: Actuate | Increment: 162 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.648 s | Percent of total time: 25.92%
#
# Step: Actuate | Increment: 163 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.652 s | Percent of total time: 26.08%
#
# Step: Actuate | Increment: 164 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.656 s | Percent of total time: 26.24%
#
# Step: Actuate | Increment: 165 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.66 s | Percent of total time: 26.4%
#
# Step: Actuate | Increment: 166 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.664 s | Percent of total time: 26.56%
#
# Step: Actuate | Increment: 167 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.668 s | Percent of total time: 26.72%
#
# Step: Actuate | Increment: 168 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.672 s | Percent of total time: 26.88%
#
# Step: Actuate | Increment: 169 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.676 s | Percent of total time: 27.04%
#
# Step: Actuate | Increment: 170 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.68 s | Percent of total time: 27.2%
#
# Step: Actuate | Increment: 171 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.684 s | Percent of total time: 27.36%
#
# Step: Actuate | Increment: 172 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.688 s | Percent of total time: 27.52%
#
# Step: Actuate | Increment: 173 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.692 s | Percent of total time: 27.68%
#
# Step: Actuate | Increment: 174 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.696 s | Percent of total time: 27.84%
#
# Step: Actuate | Increment: 175 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.7 s | Percent of total time: 28.0%
#
# Step: Actuate | Increment: 176 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.704 s | Percent of total time: 28.16%
#
# Step: Actuate | Increment: 177 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.708 s | Percent of total time: 28.32%
#
# Step: Actuate | Increment: 178 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.712 s | Percent of total time: 28.48%
#
# Step: Actuate | Increment: 179 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.716 s | Percent of total time: 28.64%
#
# Step: Actuate | Increment: 180 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.72 s | Percent of total time: 28.8%
#
# Step: Actuate | Increment: 181 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.724 s | Percent of total time: 28.96%
#
# Step: Actuate | Increment: 182 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.728 s | Percent of total time: 29.12%
#
# Step: Actuate | Increment: 183 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.732 s | Percent of total time: 29.28%
#
# Step: Actuate | Increment: 184 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.736 s | Percent of total time: 29.44%
#
# Step: Actuate | Increment: 185 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.74 s | Percent of total time: 29.6%
#
# Step: Actuate | Increment: 186 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.744 s | Percent of total time: 29.76%
#
# Step: Actuate | Increment: 187 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.748 s | Percent of total time: 29.92%
#
# Step: Actuate | Increment: 188 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.752 s | Percent of total time: 30.08%
#
# Step: Actuate | Increment: 189 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.756 s | Percent of total time: 30.24%
#
# Step: Actuate | Increment: 190 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.76 s | Percent of total time: 30.4%
#
# Step: Actuate | Increment: 191 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.764 s | Percent of total time: 30.56%
#
# Step: Actuate | Increment: 192 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.768 s | Percent of total time: 30.72%
#
# Step: Actuate | Increment: 193 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.772 s | Percent of total time: 30.88%
#
# Step: Actuate | Increment: 194 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.776 s | Percent of total time: 31.04%
#
# Step: Actuate | Increment: 195 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.78 s | Percent of total time: 31.2%
#
# Step: Actuate | Increment: 196 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.784 s | Percent of total time: 31.36%
#
# Step: Actuate | Increment: 197 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.788 s | Percent of total time: 31.52%
#
# Step: Actuate | Increment: 198 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.792 s | Percent of total time: 31.68%
#
# Step: Actuate | Increment: 199 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.796 s | Percent of total time: 31.84%
#
# Step: Actuate | Increment: 200 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.8 s | Percent of total time: 32.0%
#
# Step: Actuate | Increment: 201 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.804 s | Percent of total time: 32.16%
#
# Step: Actuate | Increment: 202 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.808 s | Percent of total time: 32.32%
#
# Step: Actuate | Increment: 203 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.812 s | Percent of total time: 32.48%
#
# Step: Actuate | Increment: 204 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.816 s | Percent of total time: 32.64%
#
# Step: Actuate | Increment: 205 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.82 s | Percent of total time: 32.8%
#
# Step: Actuate | Increment: 206 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.824 s | Percent of total time: 32.96%
#
# Step: Actuate | Increment: 207 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.828 s | Percent of total time: 33.12%
#
# Step: Actuate | Increment: 208 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.832 s | Percent of total time: 33.28%
#
# Step: Actuate | Increment: 209 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.836 s | Percent of total time: 33.44%
#
# Step: Actuate | Increment: 210 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.84 s | Percent of total time: 33.6%
#
# Step: Actuate | Increment: 211 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.844 s | Percent of total time: 33.76%
#
# Step: Actuate | Increment: 212 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.848 s | Percent of total time: 33.92%
#
# Step: Actuate | Increment: 213 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.852 s | Percent of total time: 34.08%
#
# Step: Actuate | Increment: 214 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.856 s | Percent of total time: 34.24%
#
# Step: Actuate | Increment: 215 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.86 s | Percent of total time: 34.4%
#
# Step: Actuate | Increment: 216 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.864 s | Percent of total time: 34.56%
#
# Step: Actuate | Increment: 217 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.868 s | Percent of total time: 34.72%
#
# Step: Actuate | Increment: 218 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.872 s | Percent of total time: 34.88%
#
# Step: Actuate | Increment: 219 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.876 s | Percent of total time: 35.04%
#
# Step: Actuate | Increment: 220 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.88 s | Percent of total time: 35.2%
#
# Step: Actuate | Increment: 221 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.884 s | Percent of total time: 35.36%
#
# Step: Actuate | Increment: 222 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.888 s | Percent of total time: 35.52%
#
# Step: Actuate | Increment: 223 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.892 s | Percent of total time: 35.68%
#
# Step: Actuate | Increment: 224 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.896 s | Percent of total time: 35.84%
#
# Step: Actuate | Increment: 225 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.9 s | Percent of total time: 36.0%
#
# Step: Actuate | Increment: 226 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.904 s | Percent of total time: 36.16%
#
# Step: Actuate | Increment: 227 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.908 s | Percent of total time: 36.32%
#
# Step: Actuate | Increment: 228 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.912 s | Percent of total time: 36.48%
#
# Step: Actuate | Increment: 229 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.916 s | Percent of total time: 36.64%
#
# Step: Actuate | Increment: 230 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.92 s | Percent of total time: 36.8%
#
# Step: Actuate | Increment: 231 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.924 s | Percent of total time: 36.96%
#
# Step: Actuate | Increment: 232 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.928 s | Percent of total time: 37.12%
#
# Step: Actuate | Increment: 233 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.932 s | Percent of total time: 37.28%
#
# Step: Actuate | Increment: 234 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.936 s | Percent of total time: 37.44%
#
# Step: Actuate | Increment: 235 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.94 s | Percent of total time: 37.6%
#
# Step: Actuate | Increment: 236 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.944 s | Percent of total time: 37.76%
#
# Step: Actuate | Increment: 237 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.948 s | Percent of total time: 37.92%
#
# Step: Actuate | Increment: 238 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.952 s | Percent of total time: 38.08%
#
# Step: Actuate | Increment: 239 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.956 s | Percent of total time: 38.24%
#
# Step: Actuate | Increment: 240 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.96 s | Percent of total time: 38.4%
#
# Step: Actuate | Increment: 241 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.964 s | Percent of total time: 38.56%
#
# Step: Actuate | Increment: 242 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.968 s | Percent of total time: 38.72%
#
# Step: Actuate | Increment: 243 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.972 s | Percent of total time: 38.88%
#
# Step: Actuate | Increment: 244 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.976 s | Percent of total time: 39.04%
#
# Step: Actuate | Increment: 245 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.98 s | Percent of total time: 39.2%
#
# Step: Actuate | Increment: 246 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.984 s | Percent of total time: 39.36%
#
# Step: Actuate | Increment: 247 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.988 s | Percent of total time: 39.52%
#
# Step: Actuate | Increment: 248 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.992 s | Percent of total time: 39.68%
#
# Step: Actuate | Increment: 249 | Iterations: 4
# dt: 0.004 | Simulation Time: 0.996 s | Percent of total time: 39.84%
#
# Step: Actuate | Increment: 250 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.0 s | Percent of total time: 40.0%
#
# Step: Actuate | Increment: 251 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.004 s | Percent of total time: 40.16%
#
# Step: Actuate | Increment: 252 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.008 s | Percent of total time: 40.32%
#
# Step: Actuate | Increment: 253 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.012 s | Percent of total time: 40.48%
#
# Step: Actuate | Increment: 254 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.016 s | Percent of total time: 40.64%
#
# Step: Actuate | Increment: 255 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.02 s | Percent of total time: 40.8%
#
# Step: Actuate | Increment: 256 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.024 s | Percent of total time: 40.96%
#
# Step: Actuate | Increment: 257 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.028 s | Percent of total time: 41.12%
#
# Step: Actuate | Increment: 258 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.032 s | Percent of total time: 41.28%
#
# Step: Actuate | Increment: 259 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.036 s | Percent of total time: 41.44%
#
# Step: Actuate | Increment: 260 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.04 s | Percent of total time: 41.6%
#
# Step: Actuate | Increment: 261 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.044 s | Percent of total time: 41.76%
#
# Step: Actuate | Increment: 262 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.048 s | Percent of total time: 41.92%
#
# Step: Actuate | Increment: 263 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.052 s | Percent of total time: 42.08%
#
# Step: Actuate | Increment: 264 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.056 s | Percent of total time: 42.24%
#
# Step: Actuate | Increment: 265 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.06 s | Percent of total time: 42.4%
#
# Step: Actuate | Increment: 266 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.064 s | Percent of total time: 42.56%
#
# Step: Actuate | Increment: 267 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.068 s | Percent of total time: 42.72%
#
# Step: Actuate | Increment: 268 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.072 s | Percent of total time: 42.88%
#
# Step: Actuate | Increment: 269 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.076 s | Percent of total time: 43.04%
#
# Step: Actuate | Increment: 270 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.08 s | Percent of total time: 43.2%
#
# Step: Actuate | Increment: 271 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.084 s | Percent of total time: 43.36%
#
# Step: Actuate | Increment: 272 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.088 s | Percent of total time: 43.52%
#
# Step: Actuate | Increment: 273 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.092 s | Percent of total time: 43.68%
#
# Step: Actuate | Increment: 274 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.096 s | Percent of total time: 43.84%
#
# Step: Actuate | Increment: 275 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.1 s | Percent of total time: 44.0%
#
# Step: Actuate | Increment: 276 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.104 s | Percent of total time: 44.16%
#
# Step: Actuate | Increment: 277 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.108 s | Percent of total time: 44.32%
#
# Step: Actuate | Increment: 278 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.112 s | Percent of total time: 44.48%
#
# Step: Actuate | Increment: 279 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.116 s | Percent of total time: 44.64%
#
# Step: Actuate | Increment: 280 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.12 s | Percent of total time: 44.8%
#
# Step: Actuate | Increment: 281 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.124 s | Percent of total time: 44.96%
#
# Step: Actuate | Increment: 282 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.128 s | Percent of total time: 45.12%
#
# Step: Actuate | Increment: 283 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.132 s | Percent of total time: 45.28%
#
# Step: Actuate | Increment: 284 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.136 s | Percent of total time: 45.44%
#
# Step: Actuate | Increment: 285 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.14 s | Percent of total time: 45.6%
#
# Step: Actuate | Increment: 286 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.144 s | Percent of total time: 45.76%
#
# Step: Actuate | Increment: 287 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.148 s | Percent of total time: 45.92%
#
# Step: Actuate | Increment: 288 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.152 s | Percent of total time: 46.08%
#
# Step: Actuate | Increment: 289 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.156 s | Percent of total time: 46.24%
#
# Step: Actuate | Increment: 290 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.16 s | Percent of total time: 46.4%
#
# Step: Actuate | Increment: 291 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.164 s | Percent of total time: 46.56%
#
# Step: Actuate | Increment: 292 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.168 s | Percent of total time: 46.72%
#
# Step: Actuate | Increment: 293 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.172 s | Percent of total time: 46.88%
#
# Step: Actuate | Increment: 294 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.176 s | Percent of total time: 47.04%
#
# Step: Actuate | Increment: 295 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.18 s | Percent of total time: 47.2%
#
# Step: Actuate | Increment: 296 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.184 s | Percent of total time: 47.36%
#
# Step: Actuate | Increment: 297 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.188 s | Percent of total time: 47.52%
#
# Step: Actuate | Increment: 298 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.192 s | Percent of total time: 47.68%
#
# Step: Actuate | Increment: 299 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.196 s | Percent of total time: 47.84%
#
# Step: Actuate | Increment: 300 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.2 s | Percent of total time: 48.0%
#
# Step: Actuate | Increment: 301 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.204 s | Percent of total time: 48.16%
#
# Step: Actuate | Increment: 302 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.208 s | Percent of total time: 48.32%
#
# Step: Actuate | Increment: 303 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.212 s | Percent of total time: 48.48%
#
# Step: Actuate | Increment: 304 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.216 s | Percent of total time: 48.64%
#
# Step: Actuate | Increment: 305 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.22 s | Percent of total time: 48.8%
#
# Step: Actuate | Increment: 306 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.224 s | Percent of total time: 48.96%
#
# Step: Actuate | Increment: 307 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.228 s | Percent of total time: 49.12%
#
# Step: Actuate | Increment: 308 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.232 s | Percent of total time: 49.28%
#
# Step: Actuate | Increment: 309 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.236 s | Percent of total time: 49.44%
#
# Step: Actuate | Increment: 310 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.24 s | Percent of total time: 49.6%
#
# Step: Actuate | Increment: 311 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.244 s | Percent of total time: 49.76%
#
# Step: Actuate | Increment: 312 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.248 s | Percent of total time: 49.92%
#
# Step: Actuate | Increment: 313 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.252 s | Percent of total time: 50.08%
#
# Step: Actuate | Increment: 314 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.256 s | Percent of total time: 50.24%
#
# Step: Actuate | Increment: 315 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.26 s | Percent of total time: 50.4%
#
# Step: Actuate | Increment: 316 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.264 s | Percent of total time: 50.56%
#
# Step: Actuate | Increment: 317 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.268 s | Percent of total time: 50.72%
#
# Step: Actuate | Increment: 318 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.272 s | Percent of total time: 50.88%
#
# Step: Actuate | Increment: 319 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.276 s | Percent of total time: 51.04%
#
# Step: Actuate | Increment: 320 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.28 s | Percent of total time: 51.2%
#
# Step: Actuate | Increment: 321 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.284 s | Percent of total time: 51.36%
#
# Step: Actuate | Increment: 322 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.288 s | Percent of total time: 51.52%
#
# Step: Actuate | Increment: 323 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.292 s | Percent of total time: 51.68%
#
# Step: Actuate | Increment: 324 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.296 s | Percent of total time: 51.84%
#
# Step: Actuate | Increment: 325 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.3 s | Percent of total time: 52.0%
#
# Step: Actuate | Increment: 326 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.304 s | Percent of total time: 52.16%
#
# Step: Actuate | Increment: 327 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.308 s | Percent of total time: 52.32%
#
# Step: Actuate | Increment: 328 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.312 s | Percent of total time: 52.48%
#
# Step: Actuate | Increment: 329 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.316 s | Percent of total time: 52.64%
#
# Step: Actuate | Increment: 330 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.32 s | Percent of total time: 52.8%
#
# Step: Actuate | Increment: 331 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.324 s | Percent of total time: 52.96%
#
# Step: Actuate | Increment: 332 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.328 s | Percent of total time: 53.12%
#
# Step: Actuate | Increment: 333 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.332 s | Percent of total time: 53.28%
#
# Step: Actuate | Increment: 334 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.336 s | Percent of total time: 53.44%
#
# Step: Actuate | Increment: 335 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.34 s | Percent of total time: 53.6%
#
# Step: Actuate | Increment: 336 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.344 s | Percent of total time: 53.76%
#
# Step: Actuate | Increment: 337 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.348 s | Percent of total time: 53.92%
#
# Step: Actuate | Increment: 338 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.352 s | Percent of total time: 54.08%
#
# Step: Actuate | Increment: 339 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.356 s | Percent of total time: 54.24%
#
# Step: Actuate | Increment: 340 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.36 s | Percent of total time: 54.4%
#
# Step: Actuate | Increment: 341 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.364 s | Percent of total time: 54.56%
#
# Step: Actuate | Increment: 342 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.368 s | Percent of total time: 54.72%
#
# Step: Actuate | Increment: 343 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.372 s | Percent of total time: 54.88%
#
# Step: Actuate | Increment: 344 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.376 s | Percent of total time: 55.04%
#
# Step: Actuate | Increment: 345 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.38 s | Percent of total time: 55.2%
#
# Step: Actuate | Increment: 346 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.384 s | Percent of total time: 55.36%
#
# Step: Actuate | Increment: 347 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.388 s | Percent of total time: 55.52%
#
# Step: Actuate | Increment: 348 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.392 s | Percent of total time: 55.68%
#
# Step: Actuate | Increment: 349 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.396 s | Percent of total time: 55.84%
#
# Step: Actuate | Increment: 350 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.4 s | Percent of total time: 56.0%
#
# Step: Actuate | Increment: 351 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.404 s | Percent of total time: 56.16%
#
# Step: Actuate | Increment: 352 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.408 s | Percent of total time: 56.32%
#
# Step: Actuate | Increment: 353 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.412 s | Percent of total time: 56.48%
#
# Step: Actuate | Increment: 354 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.416 s | Percent of total time: 56.64%
#
# Step: Actuate | Increment: 355 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.42 s | Percent of total time: 56.8%
#
# Step: Actuate | Increment: 356 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.424 s | Percent of total time: 56.96%
#
# Step: Actuate | Increment: 357 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.428 s | Percent of total time: 57.12%
#
# Step: Actuate | Increment: 358 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.432 s | Percent of total time: 57.28%
#
# Step: Actuate | Increment: 359 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.436 s | Percent of total time: 57.44%
#
# Step: Actuate | Increment: 360 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.44 s | Percent of total time: 57.6%
#
# Step: Actuate | Increment: 361 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.444 s | Percent of total time: 57.76%
#
# Step: Actuate | Increment: 362 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.448 s | Percent of total time: 57.92%
#
# Step: Actuate | Increment: 363 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.452 s | Percent of total time: 58.08%
#
# Step: Actuate | Increment: 364 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.456 s | Percent of total time: 58.24%
#
# Step: Actuate | Increment: 365 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.46 s | Percent of total time: 58.4%
#
# Step: Actuate | Increment: 366 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.464 s | Percent of total time: 58.56%
#
# Step: Actuate | Increment: 367 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.468 s | Percent of total time: 58.72%
#
# Step: Actuate | Increment: 368 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.472 s | Percent of total time: 58.88%
#
# Step: Actuate | Increment: 369 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.476 s | Percent of total time: 59.04%
#
# Step: Actuate | Increment: 370 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.48 s | Percent of total time: 59.2%
#
# Step: Actuate | Increment: 371 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.484 s | Percent of total time: 59.36%
#
# Step: Actuate | Increment: 372 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.488 s | Percent of total time: 59.52%
#
# Step: Actuate | Increment: 373 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.492 s | Percent of total time: 59.68%
#
# Step: Actuate | Increment: 374 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.496 s | Percent of total time: 59.84%
#
# Step: Actuate | Increment: 375 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.5 s | Percent of total time: 60.0%
#
# Step: Actuate | Increment: 376 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.504 s | Percent of total time: 60.16%
#
# Step: Actuate | Increment: 377 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.508 s | Percent of total time: 60.32%
#
# Step: Actuate | Increment: 378 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.512 s | Percent of total time: 60.48%
#
# Step: Actuate | Increment: 379 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.516 s | Percent of total time: 60.64%
#
# Step: Actuate | Increment: 380 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.52 s | Percent of total time: 60.8%
#
# Step: Actuate | Increment: 381 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.524 s | Percent of total time: 60.96%
#
# Step: Actuate | Increment: 382 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.528 s | Percent of total time: 61.12%
#
# Step: Actuate | Increment: 383 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.532 s | Percent of total time: 61.28%
#
# Step: Actuate | Increment: 384 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.536 s | Percent of total time: 61.44%
#
# Step: Actuate | Increment: 385 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.54 s | Percent of total time: 61.6%
#
# Step: Actuate | Increment: 386 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.544 s | Percent of total time: 61.76%
#
# Step: Actuate | Increment: 387 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.548 s | Percent of total time: 61.92%
#
# Step: Actuate | Increment: 388 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.552 s | Percent of total time: 62.08%
#
# Step: Actuate | Increment: 389 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.556 s | Percent of total time: 62.24%
#
# Step: Actuate | Increment: 390 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.56 s | Percent of total time: 62.4%
#
# Step: Actuate | Increment: 391 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.564 s | Percent of total time: 62.56%
#
# Step: Actuate | Increment: 392 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.568 s | Percent of total time: 62.72%
#
# Step: Actuate | Increment: 393 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.572 s | Percent of total time: 62.88%
#
# Step: Actuate | Increment: 394 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.576 s | Percent of total time: 63.04%
#
# Step: Actuate | Increment: 395 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.58 s | Percent of total time: 63.2%
#
# Step: Actuate | Increment: 396 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.584 s | Percent of total time: 63.36%
#
# Step: Actuate | Increment: 397 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.588 s | Percent of total time: 63.52%
#
# Step: Actuate | Increment: 398 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.592 s | Percent of total time: 63.68%
#
# Step: Actuate | Increment: 399 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.596 s | Percent of total time: 63.84%
#
# Step: Actuate | Increment: 400 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.6 s | Percent of total time: 64.0%
#
# Step: Actuate | Increment: 401 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.604 s | Percent of total time: 64.16%
#
# Step: Actuate | Increment: 402 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.608 s | Percent of total time: 64.32%
#
# Step: Actuate | Increment: 403 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.612 s | Percent of total time: 64.48%
#
# Step: Actuate | Increment: 404 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.616 s | Percent of total time: 64.64%
#
# Step: Actuate | Increment: 405 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.62 s | Percent of total time: 64.8%
#
# Step: Actuate | Increment: 406 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.624 s | Percent of total time: 64.96%
#
# Step: Actuate | Increment: 407 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.628 s | Percent of total time: 65.12%
#
# Step: Actuate | Increment: 408 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.632 s | Percent of total time: 65.28%
#
# Step: Actuate | Increment: 409 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.636 s | Percent of total time: 65.44%
#
# Step: Actuate | Increment: 410 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.64 s | Percent of total time: 65.6%
#
# Step: Actuate | Increment: 411 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.644 s | Percent of total time: 65.76%
#
# Step: Actuate | Increment: 412 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.648 s | Percent of total time: 65.92%
#
# Step: Actuate | Increment: 413 | Iterations: 4
# ...
# dt: 0.004 | Simulation Time: 1.96 s | Percent of total time: 78.4%
#
# Step: Actuate | Increment: 491 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.964 s | Percent of total time: 78.56%
#
# Step: Actuate | Increment: 492 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.968 s | Percent of total time: 78.72%
#
# Step: Actuate | Increment: 493 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.972 s | Percent of total time: 78.88%
#
# Step: Actuate | Increment: 494 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.976 s | Percent of total time: 79.04%
#
# Step: Actuate | Increment: 495 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.98 s | Percent of total time: 79.2%
#
# Step: Actuate | Increment: 496 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.984 s | Percent of total time: 79.36%
#
# Step: Actuate | Increment: 497 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.988 s | Percent of total time: 79.52%
#
# Step: Actuate | Increment: 498 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.992 s | Percent of total time: 79.68%
#
# Step: Actuate | Increment: 499 | Iterations: 4
# dt: 0.004 | Simulation Time: 1.996 s | Percent of total time: 79.84%
#
# Step: Actuate | Increment: 500 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.0 s | Percent of total time: 80.0%
#
# Step: Actuate | Increment: 501 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.004 s | Percent of total time: 80.16%
#
# Step: Actuate | Increment: 502 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.008 s | Percent of total time: 80.32%
#
# Step: Actuate | Increment: 503 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.012 s | Percent of total time: 80.48%
#
# Step: Actuate | Increment: 504 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.016 s | Percent of total time: 80.64%
#
# Step: Actuate | Increment: 505 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.02 s | Percent of total time: 80.8%
#
# Step: Actuate | Increment: 506 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.024 s | Percent of total time: 80.96%
#
# Step: Actuate | Increment: 507 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.028 s | Percent of total time: 81.12%
#
# Step: Actuate | Increment: 508 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.032 s | Percent of total time: 81.28%
#
# Step: Actuate | Increment: 509 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.036 s | Percent of total time: 81.44%
#
# Step: Actuate | Increment: 510 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.04 s | Percent of total time: 81.6%
#
# Step: Actuate | Increment: 511 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.044 s | Percent of total time: 81.76%
#
# Step: Actuate | Increment: 512 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.048 s | Percent of total time: 81.92%
#
# Step: Actuate | Increment: 513 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.052 s | Percent of total time: 82.08%
#
# Step: Actuate | Increment: 514 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.056 s | Percent of total time: 82.24%
#
# Step: Actuate | Increment: 515 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.06 s | Percent of total time: 82.4%
#
# Step: Actuate | Increment: 516 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.064 s | Percent of total time: 82.56%
#
# Step: Actuate | Increment: 517 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.068 s | Percent of total time: 82.72%
#
# Step: Actuate | Increment: 518 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.072 s | Percent of total time: 82.88%
#
# Step: Actuate | Increment: 519 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.076 s | Percent of total time: 83.04%
#
# Step: Actuate | Increment: 520 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.08 s | Percent of total time: 83.2%
#
# Step: Actuate | Increment: 521 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.084 s | Percent of total time: 83.36%
#
# Step: Actuate | Increment: 522 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.088 s | Percent of total time: 83.52%
#
# Step: Actuate | Increment: 523 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.092 s | Percent of total time: 83.68%
#
# Step: Actuate | Increment: 524 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.096 s | Percent of total time: 83.84%
#
# Step: Actuate | Increment: 525 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.1 s | Percent of total time: 84.0%
#
# Step: Actuate | Increment: 526 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.104 s | Percent of total time: 84.16%
#
# Step: Actuate | Increment: 527 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.108 s | Percent of total time: 84.32%
#
# Step: Actuate | Increment: 528 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.112 s | Percent of total time: 84.48%
#
# Step: Actuate | Increment: 529 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.116 s | Percent of total time: 84.64%
#
# Step: Actuate | Increment: 530 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.12 s | Percent of total time: 84.8%
#
# Step: Actuate | Increment: 531 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.124 s | Percent of total time: 84.96%
#
# Step: Actuate | Increment: 532 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.128 s | Percent of total time: 85.12%
#
# Step: Actuate | Increment: 533 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.132 s | Percent of total time: 85.28%
#
# Step: Actuate | Increment: 534 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.136 s | Percent of total time: 85.44%
#
# Step: Actuate | Increment: 535 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.14 s | Percent of total time: 85.6%
#
# Step: Actuate | Increment: 536 | Iterations: 3
# dt: 0.004 | Simulation Time: 2.144 s | Percent of total time: 85.76%
#
# Step: Actuate | Increment: 537 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.148 s | Percent of total time: 85.92%
#
# Step: Actuate | Increment: 538 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.152 s | Percent of total time: 86.08%
#
# Step: Actuate | Increment: 539 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.156 s | Percent of total time: 86.24%
#
# Step: Actuate | Increment: 540 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.16 s | Percent of total time: 86.4%
#
# Step: Actuate | Increment: 541 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.164 s | Percent of total time: 86.56%
#
# Step: Actuate | Increment: 542 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.168 s | Percent of total time: 86.72%
#
# Step: Actuate | Increment: 543 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.172 s | Percent of total time: 86.88%
#
# Step: Actuate | Increment: 544 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.176 s | Percent of total time: 87.04%
#
# Step: Actuate | Increment: 545 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.18 s | Percent of total time: 87.2%
#
# Step: Actuate | Increment: 546 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.184 s | Percent of total time: 87.36%
#
# Step: Actuate | Increment: 547 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.188 s | Percent of total time: 87.52%
#
# Step: Actuate | Increment: 548 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.192 s | Percent of total time: 87.68%
#
# Step: Actuate | Increment: 549 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.196 s | Percent of total time: 87.84%
#
# Step: Actuate | Increment: 550 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.2 s | Percent of total time: 88.0%
#
# Step: Actuate | Increment: 551 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.204 s | Percent of total time: 88.16%
#
# Step: Actuate | Increment: 552 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.208 s | Percent of total time: 88.32%
#
# Step: Actuate | Increment: 553 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.212 s | Percent of total time: 88.48%
#
# Step: Actuate | Increment: 554 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.216 s | Percent of total time: 88.64%
#
# Step: Actuate | Increment: 555 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.22 s | Percent of total time: 88.8%
#
# Step: Actuate | Increment: 556 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.224 s | Percent of total time: 88.96%
#
# Step: Actuate | Increment: 557 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.228 s | Percent of total time: 89.12%
#
# Step: Actuate | Increment: 558 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.232 s | Percent of total time: 89.28%
#
# Step: Actuate | Increment: 559 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.236 s | Percent of total time: 89.44%
#
# Step: Actuate | Increment: 560 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.24 s | Percent of total time: 89.6%
#
# Step: Actuate | Increment: 561 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.244 s | Percent of total time: 89.76%
#
# Step: Actuate | Increment: 562 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.248 s | Percent of total time: 89.92%
#
# Step: Actuate | Increment: 563 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.252 s | Percent of total time: 90.08%
#
# Step: Actuate | Increment: 564 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.256 s | Percent of total time: 90.24%
#
# Step: Actuate | Increment: 565 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.26 s | Percent of total time: 90.4%
#
# Step: Actuate | Increment: 566 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.264 s | Percent of total time: 90.56%
#
# Step: Actuate | Increment: 567 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.268 s | Percent of total time: 90.72%
#
# Step: Actuate | Increment: 568 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.272 s | Percent of total time: 90.88%
#
# Step: Actuate | Increment: 569 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.276 s | Percent of total time: 91.04%
#
# Step: Actuate | Increment: 570 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.28 s | Percent of total time: 91.2%
#
# Step: Actuate | Increment: 571 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.284 s | Percent of total time: 91.36%
#
# Step: Actuate | Increment: 572 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.288 s | Percent of total time: 91.52%
#
# Step: Actuate | Increment: 573 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.292 s | Percent of total time: 91.68%
#
# Step: Actuate | Increment: 574 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.296 s | Percent of total time: 91.84%
#
# Step: Actuate | Increment: 575 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.3 s | Percent of total time: 92.0%
#
# Step: Actuate | Increment: 576 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.304 s | Percent of total time: 92.16%
#
# Step: Actuate | Increment: 577 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.308 s | Percent of total time: 92.32%
#
# Step: Actuate | Increment: 578 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.312 s | Percent of total time: 92.48%
#
# Step: Actuate | Increment: 579 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.316 s | Percent of total time: 92.64%
#
# Step: Actuate | Increment: 580 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.32 s | Percent of total time: 92.8%
#
# Step: Actuate | Increment: 581 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.324 s | Percent of total time: 92.96%
#
# Step: Actuate | Increment: 582 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.328 s | Percent of total time: 93.12%
#
# Step: Actuate | Increment: 583 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.332 s | Percent of total time: 93.28%
#
# Step: Actuate | Increment: 584 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.336 s | Percent of total time: 93.44%
#
# Step: Actuate | Increment: 585 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.34 s | Percent of total time: 93.6%
#
# Step: Actuate | Increment: 586 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.344 s | Percent of total time: 93.76%
#
# Step: Actuate | Increment: 587 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.348 s | Percent of total time: 93.92%
#
# Step: Actuate | Increment: 588 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.352 s | Percent of total time: 94.08%
#
# Step: Actuate | Increment: 589 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.356 s | Percent of total time: 94.24%
#
# Step: Actuate | Increment: 590 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.36 s | Percent of total time: 94.4%
#
# Step: Actuate | Increment: 591 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.364 s | Percent of total time: 94.56%
#
# Step: Actuate | Increment: 592 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.368 s | Percent of total time: 94.72%
#
# Step: Actuate | Increment: 593 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.372 s | Percent of total time: 94.88%
#
# Step: Actuate | Increment: 594 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.376 s | Percent of total time: 95.04%
#
# Step: Actuate | Increment: 595 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.38 s | Percent of total time: 95.2%
#
# Step: Actuate | Increment: 596 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.384 s | Percent of total time: 95.36%
#
# Step: Actuate | Increment: 597 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.388 s | Percent of total time: 95.52%
#
# Step: Actuate | Increment: 598 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.392 s | Percent of total time: 95.68%
#
# Step: Actuate | Increment: 599 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.396 s | Percent of total time: 95.84%
#
# Step: Actuate | Increment: 600 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.4 s | Percent of total time: 96.0%
#
# Step: Actuate | Increment: 601 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.404 s | Percent of total time: 96.16%
#
# Step: Actuate | Increment: 602 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.408 s | Percent of total time: 96.32%
#
# Step: Actuate | Increment: 603 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.412 s | Percent of total time: 96.48%
#
# Step: Actuate | Increment: 604 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.416 s | Percent of total time: 96.64%
#
# Step: Actuate | Increment: 605 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.42 s | Percent of total time: 96.8%
#
# Step: Actuate | Increment: 606 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.424 s | Percent of total time: 96.96%
#
# Step: Actuate | Increment: 607 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.428 s | Percent of total time: 97.12%
#
# Step: Actuate | Increment: 608 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.432 s | Percent of total time: 97.28%
#
# Step: Actuate | Increment: 609 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.436 s | Percent of total time: 97.44%
#
# Step: Actuate | Increment: 610 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.44 s | Percent of total time: 97.6%
#
# Step: Actuate | Increment: 611 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.444 s | Percent of total time: 97.76%
#
# Step: Actuate | Increment: 612 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.448 s | Percent of total time: 97.92%
#
# Step: Actuate | Increment: 613 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.452 s | Percent of total time: 98.08%
#
# Step: Actuate | Increment: 614 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.456 s | Percent of total time: 98.24%
#
# Step: Actuate | Increment: 615 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.46 s | Percent of total time: 98.4%
#
# Step: Actuate | Increment: 616 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.464 s | Percent of total time: 98.56%
#
# Step: Actuate | Increment: 617 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.468 s | Percent of total time: 98.72%
#
# Step: Actuate | Increment: 618 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.472 s | Percent of total time: 98.88%
#
# Step: Actuate | Increment: 619 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.476 s | Percent of total time: 99.04%
#
# Step: Actuate | Increment: 620 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.48 s | Percent of total time: 99.2%
#
# Step: Actuate | Increment: 621 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.484 s | Percent of total time: 99.36%
#
# Step: Actuate | Increment: 622 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.488 s | Percent of total time: 99.52%
#
# Step: Actuate | Increment: 623 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.492 s | Percent of total time: 99.68%
#
# Step: Actuate | Increment: 624 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.496 s | Percent of total time: 99.84%
#
# Step: Actuate | Increment: 625 | Iterations: 4
# dt: 0.004 | Simulation Time: 2.5 s | Percent of total time: 100.0%
#
# -----------------------------------------
# End computation
# ------------------------------------------
# Elapsed real time:  0:12:59.389947
# ------------------------------------------

# %% [markdown]
# # Plot results

# %%
# set plot font to size 18
font = {'size'   : 18}
plt.rc('font', **font)

# Get array of default plot colors
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']


# Only plot as far as we have time history data
ind = np.argmax(timeHist2) + 1


# Two-axis plotting
fig, (ax1, ax2) = plt.subplots(2,1, sharex='col')

ax1.plot(timeHist2[0:ind], timeHist1[0:ind], c=colors[3], linewidth=1.0, marker='.')
ax1.grid(linestyle="--", linewidth=0.5, color='b')
ax1.set_ylabel('Electric potential (kV)')
# ax1.set_xlim([0,5])
from matplotlib.ticker import AutoMinorLocator,FormatStrFormatter
ax1.xaxis.set_minor_locator(AutoMinorLocator())
ax1.yaxis.set_minor_locator(AutoMinorLocator())

ax2.plot(timeHist2[0:ind], timeHist0[0:ind], c=colors[0], linewidth=1.0, marker='.')
ax2.grid(linestyle="--", linewidth=0.5, color='b')
ax2.set_xlabel('Time (s)')
ax2.set_ylabel('Displacement (mm)')
from matplotlib.ticker import AutoMinorLocator,FormatStrFormatter
ax2.xaxis.set_minor_locator(AutoMinorLocator())
ax2.yaxis.set_minor_locator(AutoMinorLocator())
#plt.show()



# fig = plt.gcf()
# fig.set_size_inches(7,5)
# plt.tight_layout()
# plt.savefig("results/electro-viscoelastic_helix_step_actuation.png", dpi=600)


plt.figure()

# Two-axis plotting
fig, (ax1, ax2) = plt.subplots(2,1, sharex='col')

ax1.plot(timeHist2[0:ind], timeHist1[0:ind], c=colors[0], linewidth=2.0)
ax1.grid(linestyle="--", linewidth=0.5, color='b')
ax1.set_ylabel(r'$\phi$ (kV)')

ax2.plot(timeHist2[0:ind], timeHist0[0:ind], c=colors[1], linewidth=2.0)
ax2.grid(linestyle="--", linewidth=0.5, color='b')
ax2.set_xlabel(r'Time (s)')
ax2.set_ylabel(r'Disp. (mm)')
#plt.show()

# ax1.set_ylim([0.35,1.05])
ax1.set_xlim([0.0,2.5])
# ax2.set_ylim([0.35,1.05])
ax2.set_xlim([0.0,2.5])


fig = plt.gcf()
fig.set_size_inches(7,5)
plt.tight_layout()
plt.savefig("results/electro-viscoelastic_helix_step_actuation.png", dpi=600)
