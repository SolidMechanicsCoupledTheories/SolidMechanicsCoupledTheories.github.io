# %% [markdown]
# # Six-arm gripper actuation
# - Code for 3D large deformation electro-elasticity with u-p formulation
#
# - Electro-viscoelastic actuation of a six-arm VHB gripper.
# - Uses quadrature representation of internal variable: viscous deformation tensor Cv.
# - VHB material properties taken from Wang et al., JMPS (2016).

# %% [markdown]
# ### Units
# - Length: mm
# - Mass: kg
# - Time:  s
# - Charge: nC
# - Force: mN
# - Stress: kPa
# - Energy: microJ
# - Electric potential: kV
#
# ### Software:
# - Dolfinx v0.8.0

# %% [markdown]
# # Import modules

# %%
# Import FEnicSx/dolfinx
import dolfinx

# For numerical arrays
import numpy as np

# For MPI-based parallelization
from mpi4py import MPI
comm = MPI.COMM_WORLD
rank = comm.Get_rank()

# PETSc solvers
from petsc4py import PETSc

# specific functions from dolfinx modules
from dolfinx import fem, mesh, io, plot, log
from dolfinx.fem import (Constant, dirichletbc, Function, functionspace, Expression )
from dolfinx.fem.petsc import NonlinearProblem
from dolfinx.nls.petsc import NewtonSolver
from dolfinx.io import VTXWriter, XDMFFile


# specific functions from ufl modules
import ufl
from ufl import (TestFunctions, TrialFunction, Identity, grad, det, div, dev, inv, tr, sqrt, conditional ,\
                 gt, dx, inner, derivative, dot, ln, split, exp, eq, cos, acos, ge, le, outer)

# basix finite elements
import basix
from basix.ufl import element, mixed_element, quadrature_element

# Matplotlib for plotting
import matplotlib.pyplot as plt
plt.close('all')

# For timing the code
from datetime import datetime


# Set level of detail for log messages (integer)
# Guide:
# CRITICAL  = 50, // errors that may lead to data corruption
# ERROR     = 40, // things that HAVE gone wrong
# WARNING   = 30, // things that MAY go wrong later
# INFO      = 20, // information of general interest (includes solver info)
# PROGRESS  = 16, // what's happening (broadly)
# TRACE     = 13, // what's happening (in detail)
# DBG       = 10  // sundry
#
log.set_log_level(log.LogLevel.WARNING)

# %% [markdown]
# # Define geometry

# %%
# Read in the 3D mesh and cell tags
with XDMFFile(MPI.COMM_WORLD,"meshes/gripper_six.xdmf",'r') as infile:
    domain = infile.read_mesh(name="Grid",xpath="/Xdmf/Domain")
    cell_tags = infile.read_meshtags(domain,name="Grid")
domain.topology.create_connectivity(domain.topology.dim, domain.topology.dim-1)

# Also read in 2D facets for applying BCs
with XDMFFile(MPI.COMM_WORLD,"meshes/facet_gripper_six.xdmf",'r') as infile:
    facet_tags = infile.read_meshtags(domain,name="Grid")

x = ufl.SpatialCoordinate(domain)

# %% [markdown]
# **Print out the unique cell index numbers**

# %%
top_imap = domain.topology.index_map(2)      # index map of 2D entities in domain
values = np.zeros(top_imap.size_global)      # an array of zeros of the same size as number of 2D entities
values[cell_tags.indices]=cell_tags.values   # populating the array with facet tag index numbers
print(np.unique(cell_tags.values))           # printing the unique indice
# Out:
# [71]

# %%
def Pinned(x):
    return np.logical_and(np.logical_and(np.isclose(x[0], 0),np.isclose(x[1], 0)),np.isclose(x[2],0))
    
# # Identify the planar boundaries of the  box mesh
# #
# def Left(x):
#     return np.isclose(x[0], 0.0)
# def LeftCenter(x):
#     return np.logical_and(np.isclose(x[0], 0.0) , np.isclose(x[1], width/2.0))
# def Right(x):
#     return np.isclose(x[0], length)
# def Top(x):
#     return np.isclose(x[1], width)
# def Bottom(x):
#     return np.isclose(x[1], 0.0)
# def Center(x):
#     return np.isclose(x[1], width/2.0)
# def Front(x):
#     return np.isclose(x[2], width)
# def Back(x):
#     return np.isclose(x[2], 0.0)

# # Mark the sub-domains
# boundaries = [(1,Left),(2,LeftCenter),(3,Right),(4,Top),(5,Bottom),(6,Center),(7,Front),(8,Back)]


# # build collections of facets on each subdomain and mark them appropriately.
# facet_indices, facet_markers = [], [] # initalize empty collections of indices and markers.
# fdim = domain.topology.dim - 1 # geometric dimension of the facet (mesh dimension - 1)
# for (marker, locator) in boundaries:
#     facets = mesh.locate_entities(domain, fdim, locator) # an array of all the facets in a 
#                                                          # given subdomain ("locator")
#     facet_indices.append(facets)                         # add these facets to the collection.
#     facet_markers.append(np.full_like(facets, marker))   # mark them with the appropriate index.

# # Format the facet indices and markers as required for use in dolfinx.
# facet_indices = np.hstack(facet_indices).astype(np.int32)
# facet_markers = np.hstack(facet_markers).astype(np.int32)
# sorted_facets = np.argsort(facet_indices)
# # 
# # Add these marked facets as "mesh tags" for later use in BCs.
# facet_tags = mesh.meshtags(domain, fdim, facet_indices[sorted_facets], facet_markers[sorted_facets])

# %% [markdown]
# **Print out the unique facet index numbers**

# %%
top_imap = domain.topology.index_map(2)      # index map of 2D entities in domain (facets)
values = np.zeros(top_imap.size_global)      # an array of zeros of the same size as number of 2D entities
values[facet_tags.indices]=facet_tags.values # populating the array with facet tag index numbers
print(np.unique(facet_tags.values))          # printing the unique indices
# Out:
# [72 73 74 75 76]

# %% [markdown]
# # Markers from gmsh
# - Physical Surface("Ztop", 72) = {8};
# - Physical Surface("Zmid", 73) = {1};
# - Physical Surface("Zbot", 74) = {15};
# - Physical Surface("Xbot", 75) = {6,7,13,14};
# - Physical Surface("Ybot", 76) = {4,5,11,12};

# %% [markdown]
# **Visualize reference configuration and boundary facets**

# %%
import pyvista
pyvista.set_jupyter_backend('html')
from dolfinx.plot import vtk_mesh
pyvista.start_xvfb()

# initialize a plotter
plotter = pyvista.Plotter()

# Add the mesh.
topology, cell_types, geometry = plot.vtk_mesh(domain, domain.topology.dim)
grid = pyvista.UnstructuredGrid(topology, cell_types, geometry)
plotter.add_mesh(grid, show_edges=True) 

labels = dict(zlabel='Z', xlabel='X', ylabel='Y')
plotter.add_axes(**labels)

plotter.screenshot("results/gripper_six_mesh.png")

from IPython.display import Image
Image(filename='results/gripper_six_mesh.png')

# %% [markdown]
# ### Un-comment this cell to see an interactive visualization of the mesh

# %%
# plotter.show()

# %% [markdown]
# ## Define boundary and volume integration measure

# %%
# Define the boundary integration measure "ds" using the facet tags,
# also specify the number of surface quadrature points.
ds = ufl.Measure('ds', domain=domain, subdomain_data=facet_tags, metadata={'quadrature_degree':4})

# Define the volume integration measure "dx" 
# also specify the number of volume quadrature points.
dx = ufl.Measure('dx', domain=domain, metadata={'quadrature_degree': 4})

# Create facet to cell connectivity required to determine boundary facets.
domain.topology.create_connectivity(domain.topology.dim, domain.topology.dim)
domain.topology.create_connectivity(domain.topology.dim, domain.topology.dim-1)
domain.topology.create_connectivity(domain.topology.dim-1, domain.topology.dim)

#  Define facet normal
n = ufl.FacetNormal(domain)

# %% [markdown]
# # Material parameters

# %%
# Equilibrium material parameters
#
rho = Constant(domain, PETSc.ScalarType(1e-6))           # 1000 kg/m^3 = 1e-6 kg/mm^3
#
Geq_0   = Constant(domain, PETSc.ScalarType(15.36))      # Shear modulus, kPa
Kbulk   = Constant(domain, PETSc.ScalarType(1e3*Geq_0))  # Bulk modulus, kPa
lambdaL = Constant(domain, PETSc.ScalarType(5.99))        # Arruda-Boyce locking stretch

# Viscoelasticity parameters from Wang et al (2016) for VHB4910
#
Gneq_1  = Constant(domain, PETSc.ScalarType(26.06))    #  Non-equilibrium shear modulus, kPa
tau_1   = Constant(domain, PETSc.ScalarType(0.6074))   #  relaxation time, s
#
Gneq_2  = Constant(domain, PETSc.ScalarType(26.53))    #  Non-equilibrium shear modulus, kPa
tau_2   = Constant(domain, PETSc.ScalarType(6.56))     #  relaxation time, s
#
Gneq_3  = Constant(domain, PETSc.ScalarType(10.83))    #  Non-equilinrium shear modulus, kPa
tau_3   = Constant(domain, PETSc.ScalarType(61.25))    #  relaxation time, s

# Electrostatic  parameters
vareps_0 = Constant(domain, PETSc.ScalarType(8.85E-3)) #  permittivity of free space pF/mm
vareps_r = Constant(domain, PETSc.ScalarType(4.8))     #  relative permittivity, dimensionless
vareps   = vareps_r*vareps_0         #  permittivity of the material

# %% [markdown]
# # Simulation time-control related params

# %%
# start time (sec)
t = 0.0

# final phi (kV)
phiTot   = 4.5 # was 8.5

# frequency for actuation, Hz, cycles/sec
freq   = 4.0# either 1/4 or 4

# angular frequency radians/s
omega  = 2.*np.pi*freq       

# number of cycles 
ncycles= 5

# total simulation time
Ttot   = ncycles/freq


# number of steps for this simulation
numSteps = 100*ncycles

# time step size (sec)
dt = Ttot/numSteps

# Create a constant for the time step
dk = Constant(domain, PETSc.ScalarType(dt))

# Function to linearly ramp up displacement on boundary.
def phiRamp(t):
    phi = phiTot*np.sin(omega*t)
    return phi


# Generalized-alpha method parameters for calculating acceleration and velocity
alpha   = Constant(domain, PETSc.ScalarType(0.0))
gamma   = Constant(domain, PETSc.ScalarType(0.5+alpha))
beta    = Constant(domain, PETSc.ScalarType(0.25*(gamma+0.5)**2))

# %% [markdown]
# # Function spaces

# %%
U2 = element("Lagrange", domain.basix_cell(), 2, shape=(3,))  # For displacement
P1 = element("Lagrange", domain.basix_cell(), 1)  # For pressure and electric potential
P0 = quadrature_element(domain.basix_cell(), degree=2, scheme="default")
# Note: it seems that for the current version of dolfinx, 
# only degree=2 quadrature elements actually function properly 
# in e.g. visualization interpolations and problem solution.
T0 = basix.ufl.blocked_element(P0, shape=(3, 3)) # for Cv
#
TH = mixed_element([U2, P1, P1])  # Taylor-Hood style mixed element
ME = functionspace(domain, TH)    # Total space for all DOFs
#
V1 = functionspace(domain, P1) # Scalar function space.
V2 = functionspace(domain, U2) # Vector function space
V3 = functionspace(domain, T0) # Tensor function space
#
# Define actual functions with the required DOFs
w = Function(ME)
u, p, phi = split(w) # displacement u, presssure p, and electric potential phi

# A copy of functions to store values in the previous step
w_old  = Function(ME)
u_old, p_old, phi_old = split(w_old)   

# Define test functions   
u_test, p_test, phi_test = TestFunctions(ME)    

# Define trial functions needed for automatic differentiation
dw = TrialFunction(ME)

# Define a tensor-valued function for Cv.
Cv_1_old = Function(V3) 
Cv_2_old = Function(V3) 
Cv_3_old = Function(V3) 

# Functions for storing the velocity and acceleration at prev. step
v_old = Function(V2)
a_old = Function(V2)

# Initial conditions: 

# A function for constructing the identity matrix.
#
# To use the interpolate() feature, this must be defined as a 
# function of x.
def identity(x):
    values = np.zeros((domain.geometry.dim*domain.geometry.dim,
                      x.shape[1]), dtype=np.float64)
    values[0] = 1
    values[4] = 1
    values[8] = 1
    return values

# interpolate the identity onto the tensor-valued Cv function.
Cv_1_old.interpolate(identity)  
Cv_2_old.interpolate(identity) 
Cv_3_old.interpolate(identity)

# %% [markdown]
# # Subroutines for kinematics and constitutive equations

# %%
#------------------------------------------------------------- 
# Utility subroutines
#-------------------------------------------------------------
 
# Subroutine for a "safer" sqrt() function which avoids a divide by zero 
# when differentiated. 
def safe_sqrt(x):
    return sqrt(x + 1.0e-16)


#------------------------------------------------------------- 
# Subroutines for kinematics
#-------------------------------------------------------------

# Deformation gradient 
def F_calc(u):
    Id = Identity(3) 
    F = Id + grad(u) 
    return F

# Subrountine for computing the effective stretch
def lambdaBar_calc(u):
    F = F_calc(u)
    J = det(F)
    Fbar = J**(-1/3)*F
    Cbar = Fbar.T*Fbar
    I1 = tr(Cbar)
    lambdaBar = safe_sqrt(I1/3.0)
    return lambdaBar

#------------------------------------------------------------- 
# Subroutines for computing the viscous flow update
#-------------------------------------------------------------

# Subroutine for computing the viscous stretch Cv at the end of the step.
def Cv_update(u, Cv_old, tau_r):
    F = F_calc(u)
    J = det(F)
    C = F.T*F
    # new update from Shawn here
    Cbar = J**(-2./3.)*C
    fac = Cv_old + (dk/tau_r)*Cbar
    Cv_new = (det(fac))**(-1./3.) * fac
    return Cv_new 
 
#------------------------------------------------------------- 
# Subroutines for calculating the electric field and displacement
#-------------------------------------------------------------

# Referential electric displacement 
def Dmat_calc(u, phi):
    F = F_calc(u)
    J = det(F)
    C = F.T*F
    e_R  = - grad(phi) # referential electric field
    Dmat = vareps * J* inv(C)*e_R
    return Dmat

#------------------------------------------------------------- 
# Subroutines for calculating the Cauchy stress
#-------------------------------------------------------------

# Subroutine for computing the zeta-function in the Arruda-Boyce model.
def zeta_calc(u):
    lambdaBar = lambdaBar_calc(u)
    # Use Pade approximation of Langevin inverse (A. Cohen, 1991)
    # This is sixth-order accurate.
    z = lambdaBar/lambdaL
    z = conditional(gt(z,0.99), 0.99, z) # Keep from blowing up
    beta = z*(3.0 - z**2.0)/(1.0 - z**2.0)
    zeta = (lambdaL/(3*lambdaBar))*beta
    return zeta

# Generalized shear modulus for Arruda-Boyce model
def Geq_AB_calc(u):
    zeta = zeta_calc(u)
    Geq_AB  = Geq_0 * zeta
    return Geq_AB

# Subroutine for calculating the  equilibrium Cauchy stress
def T_eq_calc(u,p):
    F = F_calc(u)
    J = det(F)
    Fbar = J**(-1./3.)*F
    Bbar = Fbar*Fbar.T
    Geq  = Geq_AB_calc(u)
    T_eq = (1/J)* Geq * dev(Bbar) - p * Identity(3)
    return T_eq


# Subroutine for calculating the electrotatic contribution to the Cauchy stress
def T_maxw_calc(u,phi):
    F = F_calc(u)
    e_R  = - grad(phi)    # referential electric field
    e_sp = inv(F.T)*e_R   # spatial electric field 
    # Spatial Maxwel stress
    T_maxw = vareps*(outer(e_sp,e_sp) - 1/2*(inner(e_sp,e_sp))*Identity(3))
    return T_maxw

# Subroutine for the non-equilibrium Cauchy stress.
def T_neq_calc(u, Cv, Gneq):
    F  = F_calc(u)
    J = det(F)
    C = F.T*F
    # Shawn update here
    Fbar = J**(-1./3.) * F
    Cbar = J**(-2./3.) * C
    T_neq = J**(-1.) * Gneq * (Fbar * inv(Cv) * Fbar.T - (1./3.) * inner(Cbar, inv(Cv)) * Identity(3) ) 
    return T_neq

#------------------------------------------------------------- 
# Subroutine for calculating the total Piola stress
#-------------------------------------------------------------
   
# Subroutine for the total Piola stress.
def  Piola_calc(u, p, Cv_1, Cv_2, Cv_3, Gneq_1, Gneq_2, Gneq_3):
    F  = F_calc(u)
    J = det(F)
    
    T_eq = T_eq_calc(u,p)
    
    T_maxw = T_maxw_calc(u,phi)
    
    T_neq_1 = T_neq_calc(u, Cv_1, Gneq_1)
    
    T_neq_2 = T_neq_calc(u, Cv_2, Gneq_2)
        
    T_neq_3 = T_neq_calc(u, Cv_3, Gneq_3)
    
    T = T_eq + T_maxw + T_neq_1 + T_neq_2 + T_neq_3
    
    Piola = J*T*inv(F.T)
    
    return Piola

#---------------------------------------------------------------------
# Subroutine for updating  acceleration using the Newmark beta method:
# a = 1/(2*beta)*((u - u0 - v0*dt)/(0.5*dt*dt) - (1-2*beta)*a0)
#---------------------------------------------------------------------
def update_a(u, u_old, v_old, a_old):
    return (u-u_old-dk*v_old)/beta/dk**2 - (1-2*beta)/2/beta*a_old

#---------------------------------------------------------------------
# Subroutine for updating  velocity using the Newmark beta method
# v = dt * ((1-gamma)*a0 + gamma*a) + v0
#---------------------------------------------------------------------
def update_v(a, u_old, v_old, a_old):
    return v_old + dk*((1-gamma)*a_old + gamma*a)

#---------------------------------------------------------------------
# alpha-method averaging function
#---------------------------------------------------------------------
def avg(x_old, x_new, alpha):
    return alpha*x_old + (1-alpha)*x_new

# %% [markdown]
# # Evaluate kinematics and constitutive relations

# %%
# Get acceleration and velocity at end of step
a_new = update_a(u, u_old, v_old, a_old)
v_new = update_v(a_new, u_old, v_old, a_old)

# get avg (u,p) fields for generalized-alpha method
u_avg  = avg(u_old, u, alpha)
p_avg  = avg(p_old, p, alpha)

# Kinematical quantities
F  = F_calc(u_avg)
J  = det(F)
lambdaBar = lambdaBar_calc(u_avg)

# update the Cv tensors
Cv_1 = Cv_update(u_avg, Cv_1_old, tau_1)
Cv_2 = Cv_update(u_avg, Cv_2_old, tau_2)
Cv_3 = Cv_update(u_avg, Cv_3_old, tau_3)

# Referential electric displacement
Dmat = Dmat_calc(u_avg, phi)

#  Evaulate the total Piola stress
Piola = Piola_calc(u_avg, p_avg, Cv_1, Cv_2, Cv_3, Gneq_1, Gneq_2, Gneq_3)

# %% [markdown]
# # Weak forms

# %%
# The weak form for the equilibrium equation
#
Res_1  =  inner( Piola, grad(u_test))*dx \
    + inner(rho*a_new, u_test)*dx 
              
# The auxiliary equation for the pressure
#
Res_2 = inner((p_avg/Kbulk + ln(J)/J) , p_test)*dx

#  The weak form for Gauss's equation
Res_3 = inner(Dmat, grad(phi_test))*dx 

# The total residual
Res = Res_1 + Res_2 + Res_3

# Automatic differentiation tangent:
a = derivative(Res, w, dw)

# %% [markdown]
# # Set-up output files

# %%
# results file name
results_name = "gripper_six_FourHz"

# Function space for projection of results
P1 = element("Lagrange", domain.basix_cell(), 1)
VV1 = fem.functionspace(domain, P1) # linear scalar function space
#
U1 = element("Lagrange", domain.basix_cell(), 1, shape=(3,)) 
VV2 = fem.functionspace(domain, U1) # linear Vector function space
#
T1 = element("Lagrange", domain.basix_cell(), 1, shape=(3,3)) 
VV3 = fem.functionspace(domain, T1) # linear tensor function space

# For visualization purposes, we need to re-project the stress tensor onto a linear function space before 
# we write it (and its components and the von Mises stress, etc) to the VTX file. 
#
# This is because the stress is a complicated "mixed" function of the (quadratic Lagrangian) displacements
# and the (quadrature representation) plastic strain tensor and scalar equivalent plastic strain. 
#
# First, define a function for setting up this kind of projection problem for visualization purposes:
def setup_projection(u, V):

    trial = ufl.TrialFunction(V)
    test  = ufl.TestFunction(V)   

    a = ufl.inner(trial, test)*dx
    L = ufl.inner(u, test)*dx

    projection_problem = dolfinx.fem.petsc.LinearProblem(a, L, [], \
        petsc_options={"ksp_type": "cg", "ksp_rtol": 1e-16, "ksp_atol": 1e-16, "ksp_max_it": 1000})
    
    return projection_problem

# Create a linear problem for projecting the stress tensor onto the linear tensor function space VV3.
#
tensor_projection_problem = setup_projection(Piola, VV3)
Piola_temp = tensor_projection_problem.solve()

# %%
# primary fields to write to output file
u_vis      = Function(VV2, name="disp")
p_vis      = Function(VV1, name="p")
phi_vis    = Function(VV1, name="phi")

# %%
# Mises stress
T     = Piola_temp*F.T/J
T0    = T - (1/3)*tr(T)*Identity(3)
Mises = sqrt((3/2)*inner(T0, T0))
Mises_vis= Function(VV1,name="Mises")
Mises_expr = Expression(Mises,VV1.element.interpolation_points())

# Cauchy stress components
T11 = Function(VV1)
T11.name = "T11"
T11_expr = Expression(T[0,0],VV1.element.interpolation_points())

T22 = Function(VV1)
T22.name = "T22"
T22_expr = Expression(T[1,1],VV1.element.interpolation_points())

T33 = Function(VV1)
T33.name = "T33"
T33_expr = Expression(T[2,2],VV1.element.interpolation_points())

# %%
# Stretch measure
lambdaBar_vis      = Function(VV1)
lambdaBar_vis.name = "lambdaBar"
lambdaBar_expr     = Expression(lambdaBar, VV1.element.interpolation_points())

# Volumetric deformation
J_vis      = Function(VV1)
J_vis.name = "J"
J_expr     = Expression(J, VV1.element.interpolation_points())

# %%
# set up the output VTX files.
file_results = VTXWriter(
    MPI.COMM_WORLD,
    "results/" + results_name + ".bp",
    [  # put the functions here you wish to write to output
        u_vis, p_vis, phi_vis, # DOF outputs
        Mises_vis, T11, T22, T33, # stress outputs
        lambdaBar_vis, J_vis, # Kinematical outputs
    ],
    engine="BP4",
)

def writeResults(t):
    
    # Update the output fields before writing to VTX.
    #
    u_vis.interpolate(w.sub(0))
    p_vis.interpolate(w.sub(1))
    phi_vis.interpolate(w.sub(2))
    #
    # re-project to smooth visualization of quadrature functions
    # before interpolating.
    Piola_temp = tensor_projection_problem.solve()
    Mises_vis.interpolate(Mises_expr)
    T11.interpolate(T11_expr)
    T22.interpolate(T22_expr)
    T33.interpolate(T33_expr)
    #
    lambdaBar_vis.interpolate(lambdaBar_expr)
    J_vis.interpolate(J_expr)
       
    # Finally, write output fields to VTX.
    #
    file_results.write(t)

# %% [markdown]
# # Infrastructure for pulling out time history data (force, displacement, etc.)

# %%
# # computing the reaction force using the stress field
# traction = dot(Piola_temp, n)
# Force    = dot(traction, n)*ds(4)
# rxnForce = fem.form(Force)

# %%
# infrastructure for evaluating functions at a certain point efficiently
pointForEvalDisp = np.array([0, 50, 0])
pointForEvalPhi = np.array([0, 0, 0.5])
pointForEvalDispB = np.array([43.3, 25.0, 0])

bb_tree = dolfinx.geometry.bb_tree(domain,domain.topology.dim)
cell_candidates = dolfinx.geometry.compute_collisions_points(bb_tree, pointForEvalDisp)
colliding_cellsDisp = dolfinx.geometry.compute_colliding_cells(domain, cell_candidates, pointForEvalDisp).array

bb_tree = dolfinx.geometry.bb_tree(domain,domain.topology.dim)
cell_candidates = dolfinx.geometry.compute_collisions_points(bb_tree, pointForEvalPhi)
colliding_cellsPhi = dolfinx.geometry.compute_colliding_cells(domain, cell_candidates, pointForEvalPhi).array

bb_tree = dolfinx.geometry.bb_tree(domain,domain.topology.dim)
cell_candidates = dolfinx.geometry.compute_collisions_points(bb_tree, pointForEvalDispB)
colliding_cellsDispB = dolfinx.geometry.compute_colliding_cells(domain, cell_candidates, pointForEvalDispB).array

# %% [markdown]
# ## Boundary condtions

# %%
# Constant for applied electric potential
phi_cons = Constant(domain,PETSc.ScalarType(phiRamp(0)))

# Find the specific DOFs which will be constrained.
xSym_u1_dofs = fem.locate_dofs_topological(ME.sub(0).sub(0), facet_tags.dim, facet_tags.find(75))
ySym_u2_dofs = fem.locate_dofs_topological(ME.sub(0).sub(1), facet_tags.dim, facet_tags.find(76))
#
Top_phi_dofs = fem.locate_dofs_topological(ME.sub(2), facet_tags.dim, facet_tags.find(72))
Mid_phi_dofs = fem.locate_dofs_topological(ME.sub(2), facet_tags.dim, facet_tags.find(73))
Bot_phi_dofs = fem.locate_dofs_topological(ME.sub(2), facet_tags.dim, facet_tags.find(74))

# building Dirichlet BCs
bcs_1 = dirichletbc(0.0, xSym_u1_dofs, ME.sub(0).sub(0))  # u1 fix - xSym
bcs_2 = dirichletbc(0.0, ySym_u2_dofs, ME.sub(0).sub(1))  # u2 fix - ySym
#
bcs_3 = dirichletbc(phi_cons, Top_phi_dofs, ME.sub(2))  # phi ramp - Top
bcs_4 = dirichletbc(0.0, Mid_phi_dofs, ME.sub(2))        # phi ground - Midplane
bcs_5 = dirichletbc(0.0, Bot_phi_dofs, ME.sub(2))        # phi ground - Bottom

# Zero displacement boundary conditions for the fixed point
#
V0, submap = ME.sub(0).collapse()
#
fixed_u_dofs = fem.locate_dofs_geometrical((ME.sub(0), V0), Pinned)
fixed_disp   = Function(V0)
fixed_disp.interpolate(lambda x: np.stack(( np.zeros(x.shape[1]), np.zeros(x.shape[1]),  np.zeros(x.shape[1]) ) ) )
bcs_6 = dirichletbc(fixed_disp, fixed_u_dofs, ME.sub(0))        # pinned BC

bcs = [bcs_1, bcs_2, bcs_3, bcs_4, bcs_5, bcs_6]

# %% [markdown]
# ## Define the nonlinear variational problem

# %%
# Set up nonlinear problem
problem = NonlinearProblem(Res, w, bcs, a)

# the global newton solver and params
solver = NewtonSolver(MPI.COMM_WORLD, problem)
solver.convergence_criterion = "incremental"
solver.rtol = 1e-8
solver.atol = 1e-8
solver.max_it = 50
solver.report = True

#  The Krylov solver parameters.
ksp = solver.krylov_solver
opts = PETSc.Options()
option_prefix = ksp.getOptionsPrefix()
opts[f"{option_prefix}ksp_type"] = "preonly" # "preonly" works equally well
opts[f"{option_prefix}pc_type"] = "lu" # do not use 'gamg' pre-conditioner
opts[f"{option_prefix}pc_factor_mat_solver_type"] = "mumps"
opts[f"{option_prefix}ksp_max_it"] = 30
ksp.setFromOptions()

# %% [markdown]
# ##  Start calculation loop

# %%
# Give the step a descriptive name
step = "Actuate"

# Variables for storing time history
totSteps = 1000000
timeHist0 = np.zeros(shape=[totSteps])
timeHist1 = np.zeros(shape=[totSteps])
timeHist2 = np.zeros(shape=[totSteps])
timeHist3 = np.zeros(shape=[totSteps])

# Iinitialize a counter for reporting data
ii=0

#  Set up temporary "helper" functions and expressions 
#  for updating the internal variables.
#
# For the Cv tensors:
Cv_1_temp = Function(V3)
Cv_1_expr = Expression(Cv_1, V3.element.interpolation_points())
#
Cv_2_temp = Function(V3)
Cv_2_expr = Expression(Cv_2, V3.element.interpolation_points())
#
Cv_3_temp = Function(V3)
Cv_3_expr = Expression(Cv_3, V3.element.interpolation_points())
#
# and also for the velocity and acceleration.
v_temp = Function(V2)
a_temp = Function(V2)
#
v_expr = Expression(v_new,V2.element.interpolation_points())
a_expr = Expression(a_new,V2.element.interpolation_points())

# Write initial state to file
writeResults(t=0.0)    

# print a message for simulation startup
print("------------------------------------")
print("Simulation Start")
print("------------------------------------")
# Store start time 
startTime = datetime.now()

# Time-stepping solution procedure loop
while (round(t + dt, 9) <= Ttot):
  
    # increment time
    t += dt 
    
    # increment counter
    ii += 1
    
    # update time variables in time-dependent BCs 
    phi_cons.value = phiRamp(t)
    
    # Solve the problem
    try:
      (iter, converged) = solver.solve(w)
    except: # Break the loop if solver fails
      print("Did not converge, stopping")
      break
        
    # Collect results from MPI ghost processes
    w.x.scatter_forward()

    # Print progress of calculation         
    if ii%1 == 0:
      now = datetime.now()
      current_time = now.strftime("%H:%M:%S")
      print("Step: {} | Increment: {} | Iterations: {}".format(step, ii, iter))
      print("dt: {} | Simulation Time: {} s | Percent of total time: {}%".format(round(dt,4), round(t,4), round(100*t/Ttot,4)))
      print() 
      
    # Write output to file
    writeResults(t)
       
       
    # Store time history variables at this time
    timeHist0[ii] = t # current time
    timeHist1[ii] = w.sub(2).eval([0, 0, 0.5],colliding_cellsPhi[0])[0] # time history of voltage phi at a point
    timeHist2[ii] = w.sub(0).sub(1).eval([0, 50, 0],colliding_cellsDisp[0])[0] # time history of displacement at a point
    timeHist3[ii] = w.sub(0).sub(1).eval([43.4, 25.0, 0],colliding_cellsDispB[0])[0] # time history of displacement at a point
    
    # update internal variables 
    #
    # interpolate the values of the internal variables into their "temp" functions
    Cv_1_temp.interpolate(Cv_1_expr)
    Cv_2_temp.interpolate(Cv_2_expr)
    Cv_3_temp.interpolate(Cv_3_expr)
    #
    v_temp.interpolate(v_expr)
    a_temp.interpolate(a_expr)
    
    # Update DOFs for next step
    w_old.x.array[:] = w.x.array
    
    # update the old values of internal variables for next step
    Cv_1_old.x.array[:] = Cv_1_temp.x.array[:]
    Cv_2_old.x.array[:] = Cv_2_temp.x.array[:]
    Cv_3_old.x.array[:] = Cv_3_temp.x.array[:]
    #
    v_old.x.array[:] = v_temp.x.array[:]
    a_old.x.array[:] = a_temp.x.array[:]
    

    
# close the output file.
file_results.close()
         
# End analysis
print("-----------------------------------------")
print("End computation")                 
# Report elapsed real time for the analysis
endTime = datetime.now()
elapseTime = endTime - startTime
print("------------------------------------------")
print("Elapsed real time:  {}".format(elapseTime))
print("------------------------------------------")
# Out:
# ------------------------------------
# Simulation Start
# ------------------------------------
# Step: Actuate | Increment: 1 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.0025 s | Percent of total time: 0.2%
#
# Step: Actuate | Increment: 2 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.005 s | Percent of total time: 0.4%
#
# Step: Actuate | Increment: 3 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.0075 s | Percent of total time: 0.6%
#
# Step: Actuate | Increment: 4 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.01 s | Percent of total time: 0.8%
#
# Step: Actuate | Increment: 5 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.0125 s | Percent of total time: 1.0%
#
# Step: Actuate | Increment: 6 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.015 s | Percent of total time: 1.2%
#
# Step: Actuate | Increment: 7 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.0175 s | Percent of total time: 1.4%
#
# Step: Actuate | Increment: 8 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.02 s | Percent of total time: 1.6%
#
# Step: Actuate | Increment: 9 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.0225 s | Percent of total time: 1.8%
#
# Step: Actuate | Increment: 10 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.025 s | Percent of total time: 2.0%
#
# Step: Actuate | Increment: 11 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.0275 s | Percent of total time: 2.2%
#
# Step: Actuate | Increment: 12 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.03 s | Percent of total time: 2.4%
#
# Step: Actuate | Increment: 13 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.0325 s | Percent of total time: 2.6%
#
# Step: Actuate | Increment: 14 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.035 s | Percent of total time: 2.8%
#
# Step: Actuate | Increment: 15 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.0375 s | Percent of total time: 3.0%
#
# Step: Actuate | Increment: 16 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.04 s | Percent of total time: 3.2%
#
# Step: Actuate | Increment: 17 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.0425 s | Percent of total time: 3.4%
#
# Step: Actuate | Increment: 18 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.045 s | Percent of total time: 3.6%
#
# Step: Actuate | Increment: 19 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.0475 s | Percent of total time: 3.8%
#
# Step: Actuate | Increment: 20 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.05 s | Percent of total time: 4.0%
#
# Step: Actuate | Increment: 21 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.0525 s | Percent of total time: 4.2%
#
# Step: Actuate | Increment: 22 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.055 s | Percent of total time: 4.4%
#
# Step: Actuate | Increment: 23 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.0575 s | Percent of total time: 4.6%
#
# Step: Actuate | Increment: 24 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.06 s | Percent of total time: 4.8%
#
# Step: Actuate | Increment: 25 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.0625 s | Percent of total time: 5.0%
#
# Step: Actuate | Increment: 26 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.065 s | Percent of total time: 5.2%
#
# Step: Actuate | Increment: 27 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.0675 s | Percent of total time: 5.4%
#
# Step: Actuate | Increment: 28 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.07 s | Percent of total time: 5.6%
#
# Step: Actuate | Increment: 29 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.0725 s | Percent of total time: 5.8%
#
# Step: Actuate | Increment: 30 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.075 s | Percent of total time: 6.0%
#
# Step: Actuate | Increment: 31 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.0775 s | Percent of total time: 6.2%
#
# Step: Actuate | Increment: 32 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.08 s | Percent of total time: 6.4%
#
# Step: Actuate | Increment: 33 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.0825 s | Percent of total time: 6.6%
#
# Step: Actuate | Increment: 34 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.085 s | Percent of total time: 6.8%
#
# Step: Actuate | Increment: 35 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.0875 s | Percent of total time: 7.0%
#
# Step: Actuate | Increment: 36 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.09 s | Percent of total time: 7.2%
#
# Step: Actuate | Increment: 37 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.0925 s | Percent of total time: 7.4%
#
# Step: Actuate | Increment: 38 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.095 s | Percent of total time: 7.6%
#
# Step: Actuate | Increment: 39 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.0975 s | Percent of total time: 7.8%
#
# Step: Actuate | Increment: 40 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.1 s | Percent of total time: 8.0%
#
# Step: Actuate | Increment: 41 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.1025 s | Percent of total time: 8.2%
#
# Step: Actuate | Increment: 42 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.105 s | Percent of total time: 8.4%
#
# Step: Actuate | Increment: 43 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.1075 s | Percent of total time: 8.6%
#
# Step: Actuate | Increment: 44 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.11 s | Percent of total time: 8.8%
#
# Step: Actuate | Increment: 45 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.1125 s | Percent of total time: 9.0%
#
# Step: Actuate | Increment: 46 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.115 s | Percent of total time: 9.2%
#
# Step: Actuate | Increment: 47 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.1175 s | Percent of total time: 9.4%
#
# Step: Actuate | Increment: 48 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.12 s | Percent of total time: 9.6%
#
# Step: Actuate | Increment: 49 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.1225 s | Percent of total time: 9.8%
#
# Step: Actuate | Increment: 50 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.125 s | Percent of total time: 10.0%
#
# Step: Actuate | Increment: 51 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.1275 s | Percent of total time: 10.2%
#
# Step: Actuate | Increment: 52 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.13 s | Percent of total time: 10.4%
#
# Step: Actuate | Increment: 53 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.1325 s | Percent of total time: 10.6%
#
# Step: Actuate | Increment: 54 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.135 s | Percent of total time: 10.8%
#
# Step: Actuate | Increment: 55 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.1375 s | Percent of total time: 11.0%
#
# Step: Actuate | Increment: 56 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.14 s | Percent of total time: 11.2%
#
# Step: Actuate | Increment: 57 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.1425 s | Percent of total time: 11.4%
#
# Step: Actuate | Increment: 58 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.145 s | Percent of total time: 11.6%
#
# Step: Actuate | Increment: 59 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.1475 s | Percent of total time: 11.8%
#
# Step: Actuate | Increment: 60 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.15 s | Percent of total time: 12.0%
#
# Step: Actuate | Increment: 61 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.1525 s | Percent of total time: 12.2%
#
# Step: Actuate | Increment: 62 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.155 s | Percent of total time: 12.4%
#
# Step: Actuate | Increment: 63 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.1575 s | Percent of total time: 12.6%
#
# Step: Actuate | Increment: 64 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.16 s | Percent of total time: 12.8%
#
# Step: Actuate | Increment: 65 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.1625 s | Percent of total time: 13.0%
#
# Step: Actuate | Increment: 66 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.165 s | Percent of total time: 13.2%
#
# Step: Actuate | Increment: 67 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.1675 s | Percent of total time: 13.4%
#
# Step: Actuate | Increment: 68 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.17 s | Percent of total time: 13.6%
#
# Step: Actuate | Increment: 69 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.1725 s | Percent of total time: 13.8%
#
# Step: Actuate | Increment: 70 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.175 s | Percent of total time: 14.0%
#
# Step: Actuate | Increment: 71 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.1775 s | Percent of total time: 14.2%
#
# Step: Actuate | Increment: 72 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.18 s | Percent of total time: 14.4%
#
# Step: Actuate | Increment: 73 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.1825 s | Percent of total time: 14.6%
#
# Step: Actuate | Increment: 74 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.185 s | Percent of total time: 14.8%
#
# Step: Actuate | Increment: 75 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.1875 s | Percent of total time: 15.0%
#
# Step: Actuate | Increment: 76 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.19 s | Percent of total time: 15.2%
#
# Step: Actuate | Increment: 77 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.1925 s | Percent of total time: 15.4%
#
# Step: Actuate | Increment: 78 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.195 s | Percent of total time: 15.6%
#
# Step: Actuate | Increment: 79 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.1975 s | Percent of total time: 15.8%
#
# Step: Actuate | Increment: 80 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.2 s | Percent of total time: 16.0%
#
# Step: Actuate | Increment: 81 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.2025 s | Percent of total time: 16.2%
#
# Step: Actuate | Increment: 82 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.205 s | Percent of total time: 16.4%
#
# Step: Actuate | Increment: 83 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.2075 s | Percent of total time: 16.6%
#
# Step: Actuate | Increment: 84 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.21 s | Percent of total time: 16.8%
#
# Step: Actuate | Increment: 85 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.2125 s | Percent of total time: 17.0%
#
# Step: Actuate | Increment: 86 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.215 s | Percent of total time: 17.2%
#
# Step: Actuate | Increment: 87 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.2175 s | Percent of total time: 17.4%
#
# Step: Actuate | Increment: 88 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.22 s | Percent of total time: 17.6%
#
# Step: Actuate | Increment: 89 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.2225 s | Percent of total time: 17.8%
#
# Step: Actuate | Increment: 90 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.225 s | Percent of total time: 18.0%
#
# Step: Actuate | Increment: 91 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.2275 s | Percent of total time: 18.2%
#
# Step: Actuate | Increment: 92 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.23 s | Percent of total time: 18.4%
#
# Step: Actuate | Increment: 93 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.2325 s | Percent of total time: 18.6%
#
# Step: Actuate | Increment: 94 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.235 s | Percent of total time: 18.8%
#
# Step: Actuate | Increment: 95 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.2375 s | Percent of total time: 19.0%
#
# Step: Actuate | Increment: 96 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.24 s | Percent of total time: 19.2%
#
# Step: Actuate | Increment: 97 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.2425 s | Percent of total time: 19.4%
#
# Step: Actuate | Increment: 98 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.245 s | Percent of total time: 19.6%
#
# Step: Actuate | Increment: 99 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.2475 s | Percent of total time: 19.8%
#
# Step: Actuate | Increment: 100 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.25 s | Percent of total time: 20.0%
#
# Step: Actuate | Increment: 101 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.2525 s | Percent of total time: 20.2%
#
# Step: Actuate | Increment: 102 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.255 s | Percent of total time: 20.4%
#
# Step: Actuate | Increment: 103 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.2575 s | Percent of total time: 20.6%
#
# Step: Actuate | Increment: 104 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.26 s | Percent of total time: 20.8%
#
# Step: Actuate | Increment: 105 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.2625 s | Percent of total time: 21.0%
#
# Step: Actuate | Increment: 106 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.265 s | Percent of total time: 21.2%
#
# Step: Actuate | Increment: 107 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.2675 s | Percent of total time: 21.4%
#
# Step: Actuate | Increment: 108 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.27 s | Percent of total time: 21.6%
#
# Step: Actuate | Increment: 109 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.2725 s | Percent of total time: 21.8%
#
# Step: Actuate | Increment: 110 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.275 s | Percent of total time: 22.0%
#
# Step: Actuate | Increment: 111 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.2775 s | Percent of total time: 22.2%
#
# Step: Actuate | Increment: 112 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.28 s | Percent of total time: 22.4%
#
# Step: Actuate | Increment: 113 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.2825 s | Percent of total time: 22.6%
#
# Step: Actuate | Increment: 114 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.285 s | Percent of total time: 22.8%
#
# Step: Actuate | Increment: 115 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.2875 s | Percent of total time: 23.0%
#
# Step: Actuate | Increment: 116 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.29 s | Percent of total time: 23.2%
#
# Step: Actuate | Increment: 117 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.2925 s | Percent of total time: 23.4%
#
# Step: Actuate | Increment: 118 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.295 s | Percent of total time: 23.6%
#
# Step: Actuate | Increment: 119 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.2975 s | Percent of total time: 23.8%
#
# Step: Actuate | Increment: 120 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.3 s | Percent of total time: 24.0%
#
# Step: Actuate | Increment: 121 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.3025 s | Percent of total time: 24.2%
#
# Step: Actuate | Increment: 122 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.305 s | Percent of total time: 24.4%
#
# Step: Actuate | Increment: 123 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.3075 s | Percent of total time: 24.6%
#
# Step: Actuate | Increment: 124 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.31 s | Percent of total time: 24.8%
#
# Step: Actuate | Increment: 125 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.3125 s | Percent of total time: 25.0%
#
# Step: Actuate | Increment: 126 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.315 s | Percent of total time: 25.2%
#
# Step: Actuate | Increment: 127 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.3175 s | Percent of total time: 25.4%
#
# Step: Actuate | Increment: 128 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.32 s | Percent of total time: 25.6%
#
# Step: Actuate | Increment: 129 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.3225 s | Percent of total time: 25.8%
#
# Step: Actuate | Increment: 130 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.325 s | Percent of total time: 26.0%
#
# Step: Actuate | Increment: 131 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.3275 s | Percent of total time: 26.2%
#
# Step: Actuate | Increment: 132 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.33 s | Percent of total time: 26.4%
#
# Step: Actuate | Increment: 133 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.3325 s | Percent of total time: 26.6%
#
# Step: Actuate | Increment: 134 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.335 s | Percent of total time: 26.8%
#
# Step: Actuate | Increment: 135 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.3375 s | Percent of total time: 27.0%
#
# Step: Actuate | Increment: 136 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.34 s | Percent of total time: 27.2%
#
# Step: Actuate | Increment: 137 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.3425 s | Percent of total time: 27.4%
#
# Step: Actuate | Increment: 138 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.345 s | Percent of total time: 27.6%
#
# Step: Actuate | Increment: 139 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.3475 s | Percent of total time: 27.8%
#
# Step: Actuate | Increment: 140 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.35 s | Percent of total time: 28.0%
#
# Step: Actuate | Increment: 141 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.3525 s | Percent of total time: 28.2%
#
# Step: Actuate | Increment: 142 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.355 s | Percent of total time: 28.4%
#
# Step: Actuate | Increment: 143 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.3575 s | Percent of total time: 28.6%
#
# Step: Actuate | Increment: 144 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.36 s | Percent of total time: 28.8%
#
# Step: Actuate | Increment: 145 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.3625 s | Percent of total time: 29.0%
#
# Step: Actuate | Increment: 146 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.365 s | Percent of total time: 29.2%
#
# Step: Actuate | Increment: 147 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.3675 s | Percent of total time: 29.4%
#
# Step: Actuate | Increment: 148 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.37 s | Percent of total time: 29.6%
#
# Step: Actuate | Increment: 149 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.3725 s | Percent of total time: 29.8%
#
# Step: Actuate | Increment: 150 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.375 s | Percent of total time: 30.0%
#
# Step: Actuate | Increment: 151 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.3775 s | Percent of total time: 30.2%
#
# Step: Actuate | Increment: 152 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.38 s | Percent of total time: 30.4%
#
# Step: Actuate | Increment: 153 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.3825 s | Percent of total time: 30.6%
#
# Step: Actuate | Increment: 154 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.385 s | Percent of total time: 30.8%
#
# Step: Actuate | Increment: 155 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.3875 s | Percent of total time: 31.0%
#
# Step: Actuate | Increment: 156 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.39 s | Percent of total time: 31.2%
#
# Step: Actuate | Increment: 157 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.3925 s | Percent of total time: 31.4%
#
# Step: Actuate | Increment: 158 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.395 s | Percent of total time: 31.6%
#
# Step: Actuate | Increment: 159 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.3975 s | Percent of total time: 31.8%
#
# Step: Actuate | Increment: 160 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.4 s | Percent of total time: 32.0%
#
# Step: Actuate | Increment: 161 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.4025 s | Percent of total time: 32.2%
#
# Step: Actuate | Increment: 162 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.405 s | Percent of total time: 32.4%
#
# Step: Actuate | Increment: 163 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.4075 s | Percent of total time: 32.6%
#
# Step: Actuate | Increment: 164 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.41 s | Percent of total time: 32.8%
#
# Step: Actuate | Increment: 165 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.4125 s | Percent of total time: 33.0%
#
# Step: Actuate | Increment: 166 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.415 s | Percent of total time: 33.2%
#
# Step: Actuate | Increment: 167 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.4175 s | Percent of total time: 33.4%
#
# Step: Actuate | Increment: 168 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.42 s | Percent of total time: 33.6%
#
# Step: Actuate | Increment: 169 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.4225 s | Percent of total time: 33.8%
#
# Step: Actuate | Increment: 170 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.425 s | Percent of total time: 34.0%
#
# Step: Actuate | Increment: 171 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.4275 s | Percent of total time: 34.2%
#
# Step: Actuate | Increment: 172 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.43 s | Percent of total time: 34.4%
#
# Step: Actuate | Increment: 173 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.4325 s | Percent of total time: 34.6%
#
# Step: Actuate | Increment: 174 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.435 s | Percent of total time: 34.8%
#
# Step: Actuate | Increment: 175 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.4375 s | Percent of total time: 35.0%
#
# Step: Actuate | Increment: 176 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.44 s | Percent of total time: 35.2%
#
# Step: Actuate | Increment: 177 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.4425 s | Percent of total time: 35.4%
#
# Step: Actuate | Increment: 178 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.445 s | Percent of total time: 35.6%
#
# Step: Actuate | Increment: 179 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.4475 s | Percent of total time: 35.8%
#
# Step: Actuate | Increment: 180 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.45 s | Percent of total time: 36.0%
#
# Step: Actuate | Increment: 181 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.4525 s | Percent of total time: 36.2%
#
# Step: Actuate | Increment: 182 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.455 s | Percent of total time: 36.4%
#
# Step: Actuate | Increment: 183 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.4575 s | Percent of total time: 36.6%
#
# Step: Actuate | Increment: 184 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.46 s | Percent of total time: 36.8%
#
# Step: Actuate | Increment: 185 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.4625 s | Percent of total time: 37.0%
#
# Step: Actuate | Increment: 186 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.465 s | Percent of total time: 37.2%
#
# Step: Actuate | Increment: 187 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.4675 s | Percent of total time: 37.4%
#
# Step: Actuate | Increment: 188 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.47 s | Percent of total time: 37.6%
#
# Step: Actuate | Increment: 189 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.4725 s | Percent of total time: 37.8%
#
# Step: Actuate | Increment: 190 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.475 s | Percent of total time: 38.0%
#
# Step: Actuate | Increment: 191 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.4775 s | Percent of total time: 38.2%
#
# Step: Actuate | Increment: 192 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.48 s | Percent of total time: 38.4%
#
# Step: Actuate | Increment: 193 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.4825 s | Percent of total time: 38.6%
#
# Step: Actuate | Increment: 194 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.485 s | Percent of total time: 38.8%
#
# Step: Actuate | Increment: 195 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.4875 s | Percent of total time: 39.0%
#
# Step: Actuate | Increment: 196 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.49 s | Percent of total time: 39.2%
#
# Step: Actuate | Increment: 197 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.4925 s | Percent of total time: 39.4%
#
# Step: Actuate | Increment: 198 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.495 s | Percent of total time: 39.6%
#
# Step: Actuate | Increment: 199 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.4975 s | Percent of total time: 39.8%
#
# Step: Actuate | Increment: 200 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.5 s | Percent of total time: 40.0%
#
# Step: Actuate | Increment: 201 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.5025 s | Percent of total time: 40.2%
#
# Step: Actuate | Increment: 202 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.505 s | Percent of total time: 40.4%
#
# Step: Actuate | Increment: 203 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.5075 s | Percent of total time: 40.6%
#
# Step: Actuate | Increment: 204 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.51 s | Percent of total time: 40.8%
#
# Step: Actuate | Increment: 205 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.5125 s | Percent of total time: 41.0%
#
# Step: Actuate | Increment: 206 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.515 s | Percent of total time: 41.2%
#
# Step: Actuate | Increment: 207 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.5175 s | Percent of total time: 41.4%
#
# Step: Actuate | Increment: 208 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.52 s | Percent of total time: 41.6%
#
# Step: Actuate | Increment: 209 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.5225 s | Percent of total time: 41.8%
#
# Step: Actuate | Increment: 210 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.525 s | Percent of total time: 42.0%
#
# Step: Actuate | Increment: 211 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.5275 s | Percent of total time: 42.2%
#
# Step: Actuate | Increment: 212 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.53 s | Percent of total time: 42.4%
#
# Step: Actuate | Increment: 213 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.5325 s | Percent of total time: 42.6%
#
# Step: Actuate | Increment: 214 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.535 s | Percent of total time: 42.8%
#
# Step: Actuate | Increment: 215 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.5375 s | Percent of total time: 43.0%
#
# Step: Actuate | Increment: 216 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.54 s | Percent of total time: 43.2%
#
# Step: Actuate | Increment: 217 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.5425 s | Percent of total time: 43.4%
#
# Step: Actuate | Increment: 218 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.545 s | Percent of total time: 43.6%
#
# Step: Actuate | Increment: 219 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.5475 s | Percent of total time: 43.8%
#
# Step: Actuate | Increment: 220 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.55 s | Percent of total time: 44.0%
#
# Step: Actuate | Increment: 221 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.5525 s | Percent of total time: 44.2%
#
# Step: Actuate | Increment: 222 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.555 s | Percent of total time: 44.4%
#
# Step: Actuate | Increment: 223 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.5575 s | Percent of total time: 44.6%
#
# Step: Actuate | Increment: 224 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.56 s | Percent of total time: 44.8%
#
# Step: Actuate | Increment: 225 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.5625 s | Percent of total time: 45.0%
#
# Step: Actuate | Increment: 226 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.565 s | Percent of total time: 45.2%
#
# Step: Actuate | Increment: 227 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.5675 s | Percent of total time: 45.4%
#
# Step: Actuate | Increment: 228 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.57 s | Percent of total time: 45.6%
#
# Step: Actuate | Increment: 229 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.5725 s | Percent of total time: 45.8%
#
# Step: Actuate | Increment: 230 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.575 s | Percent of total time: 46.0%
#
# Step: Actuate | Increment: 231 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.5775 s | Percent of total time: 46.2%
#
# Step: Actuate | Increment: 232 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.58 s | Percent of total time: 46.4%
#
# Step: Actuate | Increment: 233 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.5825 s | Percent of total time: 46.6%
#
# Step: Actuate | Increment: 234 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.585 s | Percent of total time: 46.8%
#
# Step: Actuate | Increment: 235 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.5875 s | Percent of total time: 47.0%
#
# Step: Actuate | Increment: 236 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.59 s | Percent of total time: 47.2%
#
# Step: Actuate | Increment: 237 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.5925 s | Percent of total time: 47.4%
#
# Step: Actuate | Increment: 238 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.595 s | Percent of total time: 47.6%
#
# Step: Actuate | Increment: 239 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.5975 s | Percent of total time: 47.8%
#
# Step: Actuate | Increment: 240 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.6 s | Percent of total time: 48.0%
#
# Step: Actuate | Increment: 241 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.6025 s | Percent of total time: 48.2%
#
# Step: Actuate | Increment: 242 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.605 s | Percent of total time: 48.4%
#
# Step: Actuate | Increment: 243 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.6075 s | Percent of total time: 48.6%
#
# Step: Actuate | Increment: 244 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.61 s | Percent of total time: 48.8%
#
# Step: Actuate | Increment: 245 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.6125 s | Percent of total time: 49.0%
#
# Step: Actuate | Increment: 246 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.615 s | Percent of total time: 49.2%
#
# Step: Actuate | Increment: 247 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.6175 s | Percent of total time: 49.4%
#
# Step: Actuate | Increment: 248 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.62 s | Percent of total time: 49.6%
#
# Step: Actuate | Increment: 249 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.6225 s | Percent of total time: 49.8%
#
# Step: Actuate | Increment: 250 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.625 s | Percent of total time: 50.0%
#
# Step: Actuate | Increment: 251 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.6275 s | Percent of total time: 50.2%
#
# Step: Actuate | Increment: 252 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.63 s | Percent of total time: 50.4%
#
# Step: Actuate | Increment: 253 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.6325 s | Percent of total time: 50.6%
#
# Step: Actuate | Increment: 254 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.635 s | Percent of total time: 50.8%
#
# Step: Actuate | Increment: 255 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.6375 s | Percent of total time: 51.0%
#
# Step: Actuate | Increment: 256 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.64 s | Percent of total time: 51.2%
#
# Step: Actuate | Increment: 257 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.6425 s | Percent of total time: 51.4%
#
# Step: Actuate | Increment: 258 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.645 s | Percent of total time: 51.6%
#
# Step: Actuate | Increment: 259 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.6475 s | Percent of total time: 51.8%
#
# Step: Actuate | Increment: 260 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.65 s | Percent of total time: 52.0%
#
# Step: Actuate | Increment: 261 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.6525 s | Percent of total time: 52.2%
#
# Step: Actuate | Increment: 262 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.655 s | Percent of total time: 52.4%
#
# Step: Actuate | Increment: 263 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.6575 s | Percent of total time: 52.6%
#
# Step: Actuate | Increment: 264 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.66 s | Percent of total time: 52.8%
#
# Step: Actuate | Increment: 265 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.6625 s | Percent of total time: 53.0%
#
# Step: Actuate | Increment: 266 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.665 s | Percent of total time: 53.2%
#
# Step: Actuate | Increment: 267 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.6675 s | Percent of total time: 53.4%
#
# Step: Actuate | Increment: 268 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.67 s | Percent of total time: 53.6%
#
# Step: Actuate | Increment: 269 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.6725 s | Percent of total time: 53.8%
#
# Step: Actuate | Increment: 270 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.675 s | Percent of total time: 54.0%
#
# Step: Actuate | Increment: 271 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.6775 s | Percent of total time: 54.2%
#
# Step: Actuate | Increment: 272 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.68 s | Percent of total time: 54.4%
#
# Step: Actuate | Increment: 273 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.6825 s | Percent of total time: 54.6%
#
# Step: Actuate | Increment: 274 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.685 s | Percent of total time: 54.8%
#
# Step: Actuate | Increment: 275 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.6875 s | Percent of total time: 55.0%
#
# Step: Actuate | Increment: 276 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.69 s | Percent of total time: 55.2%
#
# Step: Actuate | Increment: 277 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.6925 s | Percent of total time: 55.4%
#
# Step: Actuate | Increment: 278 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.695 s | Percent of total time: 55.6%
#
# Step: Actuate | Increment: 279 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.6975 s | Percent of total time: 55.8%
#
# Step: Actuate | Increment: 280 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.7 s | Percent of total time: 56.0%
#
# Step: Actuate | Increment: 281 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.7025 s | Percent of total time: 56.2%
#
# Step: Actuate | Increment: 282 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.705 s | Percent of total time: 56.4%
#
# Step: Actuate | Increment: 283 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.7075 s | Percent of total time: 56.6%
#
# Step: Actuate | Increment: 284 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.71 s | Percent of total time: 56.8%
#
# Step: Actuate | Increment: 285 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.7125 s | Percent of total time: 57.0%
#
# Step: Actuate | Increment: 286 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.715 s | Percent of total time: 57.2%
#
# Step: Actuate | Increment: 287 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.7175 s | Percent of total time: 57.4%
#
# Step: Actuate | Increment: 288 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.72 s | Percent of total time: 57.6%
#
# Step: Actuate | Increment: 289 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.7225 s | Percent of total time: 57.8%
#
# Step: Actuate | Increment: 290 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.725 s | Percent of total time: 58.0%
#
# Step: Actuate | Increment: 291 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.7275 s | Percent of total time: 58.2%
#
# Step: Actuate | Increment: 292 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.73 s | Percent of total time: 58.4%
#
# Step: Actuate | Increment: 293 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.7325 s | Percent of total time: 58.6%
#
# Step: Actuate | Increment: 294 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.735 s | Percent of total time: 58.8%
#
# Step: Actuate | Increment: 295 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.7375 s | Percent of total time: 59.0%
#
# Step: Actuate | Increment: 296 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.74 s | Percent of total time: 59.2%
#
# Step: Actuate | Increment: 297 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.7425 s | Percent of total time: 59.4%
#
# Step: Actuate | Increment: 298 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.745 s | Percent of total time: 59.6%
#
# Step: Actuate | Increment: 299 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.7475 s | Percent of total time: 59.8%
#
# Step: Actuate | Increment: 300 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.75 s | Percent of total time: 60.0%
#
# Step: Actuate | Increment: 301 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.7525 s | Percent of total time: 60.2%
#
# Step: Actuate | Increment: 302 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.755 s | Percent of total time: 60.4%
#
# Step: Actuate | Increment: 303 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.7575 s | Percent of total time: 60.6%
#
# Step: Actuate | Increment: 304 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.76 s | Percent of total time: 60.8%
#
# Step: Actuate | Increment: 305 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.7625 s | Percent of total time: 61.0%
#
# Step: Actuate | Increment: 306 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.765 s | Percent of total time: 61.2%
#
# Step: Actuate | Increment: 307 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.7675 s | Percent of total time: 61.4%
#
# Step: Actuate | Increment: 308 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.77 s | Percent of total time: 61.6%
#
# Step: Actuate | Increment: 309 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.7725 s | Percent of total time: 61.8%
#
# Step: Actuate | Increment: 310 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.775 s | Percent of total time: 62.0%
#
# Step: Actuate | Increment: 311 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.7775 s | Percent of total time: 62.2%
#
# Step: Actuate | Increment: 312 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.78 s | Percent of total time: 62.4%
#
# Step: Actuate | Increment: 313 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.7825 s | Percent of total time: 62.6%
#
# Step: Actuate | Increment: 314 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.785 s | Percent of total time: 62.8%
#
# Step: Actuate | Increment: 315 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.7875 s | Percent of total time: 63.0%
#
# Step: Actuate | Increment: 316 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.79 s | Percent of total time: 63.2%
#
# Step: Actuate | Increment: 317 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.7925 s | Percent of total time: 63.4%
#
# Step: Actuate | Increment: 318 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.795 s | Percent of total time: 63.6%
#
# Step: Actuate | Increment: 319 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.7975 s | Percent of total time: 63.8%
#
# Step: Actuate | Increment: 320 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.8 s | Percent of total time: 64.0%
#
# Step: Actuate | Increment: 321 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.8025 s | Percent of total time: 64.2%
#
# Step: Actuate | Increment: 322 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.805 s | Percent of total time: 64.4%
#
# Step: Actuate | Increment: 323 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.8075 s | Percent of total time: 64.6%
#
# Step: Actuate | Increment: 324 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.81 s | Percent of total time: 64.8%
#
# Step: Actuate | Increment: 325 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.8125 s | Percent of total time: 65.0%
#
# Step: Actuate | Increment: 326 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.815 s | Percent of total time: 65.2%
#
# Step: Actuate | Increment: 327 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.8175 s | Percent of total time: 65.4%
#
# Step: Actuate | Increment: 328 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.82 s | Percent of total time: 65.6%
#
# Step: Actuate | Increment: 329 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.8225 s | Percent of total time: 65.8%
#
# Step: Actuate | Increment: 330 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.825 s | Percent of total time: 66.0%
#
# Step: Actuate | Increment: 331 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.8275 s | Percent of total time: 66.2%
#
# Step: Actuate | Increment: 332 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.83 s | Percent of total time: 66.4%
#
# Step: Actuate | Increment: 333 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.8325 s | Percent of total time: 66.6%
#
# Step: Actuate | Increment: 334 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.835 s | Percent of total time: 66.8%
#
# Step: Actuate | Increment: 335 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.8375 s | Percent of total time: 67.0%
#
# Step: Actuate | Increment: 336 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.84 s | Percent of total time: 67.2%
#
# Step: Actuate | Increment: 337 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.8425 s | Percent of total time: 67.4%
#
# Step: Actuate | Increment: 338 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.845 s | Percent of total time: 67.6%
#
# Step: Actuate | Increment: 339 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.8475 s | Percent of total time: 67.8%
#
# Step: Actuate | Increment: 340 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.85 s | Percent of total time: 68.0%
#
# Step: Actuate | Increment: 341 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.8525 s | Percent of total time: 68.2%
#
# Step: Actuate | Increment: 342 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.855 s | Percent of total time: 68.4%
#
# Step: Actuate | Increment: 343 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.8575 s | Percent of total time: 68.6%
#
# Step: Actuate | Increment: 344 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.86 s | Percent of total time: 68.8%
#
# Step: Actuate | Increment: 345 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.8625 s | Percent of total time: 69.0%
#
# Step: Actuate | Increment: 346 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.865 s | Percent of total time: 69.2%
#
# Step: Actuate | Increment: 347 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.8675 s | Percent of total time: 69.4%
#
# Step: Actuate | Increment: 348 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.87 s | Percent of total time: 69.6%
#
# Step: Actuate | Increment: 349 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.8725 s | Percent of total time: 69.8%
#
# Step: Actuate | Increment: 350 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.875 s | Percent of total time: 70.0%
#
# Step: Actuate | Increment: 351 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.8775 s | Percent of total time: 70.2%
#
# Step: Actuate | Increment: 352 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.88 s | Percent of total time: 70.4%
#
# Step: Actuate | Increment: 353 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.8825 s | Percent of total time: 70.6%
#
# Step: Actuate | Increment: 354 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.885 s | Percent of total time: 70.8%
#
# Step: Actuate | Increment: 355 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.8875 s | Percent of total time: 71.0%
#
# Step: Actuate | Increment: 356 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.89 s | Percent of total time: 71.2%
#
# Step: Actuate | Increment: 357 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.8925 s | Percent of total time: 71.4%
#
# Step: Actuate | Increment: 358 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.895 s | Percent of total time: 71.6%
#
# Step: Actuate | Increment: 359 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.8975 s | Percent of total time: 71.8%
#
# Step: Actuate | Increment: 360 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.9 s | Percent of total time: 72.0%
#
# Step: Actuate | Increment: 361 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.9025 s | Percent of total time: 72.2%
#
# Step: Actuate | Increment: 362 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.905 s | Percent of total time: 72.4%
#
# Step: Actuate | Increment: 363 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.9075 s | Percent of total time: 72.6%
#
# Step: Actuate | Increment: 364 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.91 s | Percent of total time: 72.8%
#
# Step: Actuate | Increment: 365 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.9125 s | Percent of total time: 73.0%
#
# Step: Actuate | Increment: 366 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.915 s | Percent of total time: 73.2%
#
# Step: Actuate | Increment: 367 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.9175 s | Percent of total time: 73.4%
#
# Step: Actuate | Increment: 368 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.92 s | Percent of total time: 73.6%
#
# Step: Actuate | Increment: 369 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.9225 s | Percent of total time: 73.8%
#
# Step: Actuate | Increment: 370 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.925 s | Percent of total time: 74.0%
#
# Step: Actuate | Increment: 371 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.9275 s | Percent of total time: 74.2%
#
# Step: Actuate | Increment: 372 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.93 s | Percent of total time: 74.4%
#
# Step: Actuate | Increment: 373 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.9325 s | Percent of total time: 74.6%
#
# Step: Actuate | Increment: 374 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.935 s | Percent of total time: 74.8%
#
# Step: Actuate | Increment: 375 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.9375 s | Percent of total time: 75.0%
#
# Step: Actuate | Increment: 376 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.94 s | Percent of total time: 75.2%
#
# Step: Actuate | Increment: 377 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.9425 s | Percent of total time: 75.4%
#
# Step: Actuate | Increment: 378 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.945 s | Percent of total time: 75.6%
#
# Step: Actuate | Increment: 379 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.9475 s | Percent of total time: 75.8%
#
# Step: Actuate | Increment: 380 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.95 s | Percent of total time: 76.0%
#
# Step: Actuate | Increment: 381 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.9525 s | Percent of total time: 76.2%
#
# Step: Actuate | Increment: 382 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.955 s | Percent of total time: 76.4%
#
# Step: Actuate | Increment: 383 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.9575 s | Percent of total time: 76.6%
#
# Step: Actuate | Increment: 384 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.96 s | Percent of total time: 76.8%
#
# Step: Actuate | Increment: 385 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.9625 s | Percent of total time: 77.0%
#
# Step: Actuate | Increment: 386 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.965 s | Percent of total time: 77.2%
#
# Step: Actuate | Increment: 387 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.9675 s | Percent of total time: 77.4%
#
# Step: Actuate | Increment: 388 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.97 s | Percent of total time: 77.6%
#
# Step: Actuate | Increment: 389 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.9725 s | Percent of total time: 77.8%
#
# Step: Actuate | Increment: 390 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.975 s | Percent of total time: 78.0%
#
# Step: Actuate | Increment: 391 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.9775 s | Percent of total time: 78.2%
#
# Step: Actuate | Increment: 392 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.98 s | Percent of total time: 78.4%
#
# Step: Actuate | Increment: 393 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.9825 s | Percent of total time: 78.6%
#
# Step: Actuate | Increment: 394 | Iterations: 4
# dt: 0.0025 | Simulation Time: 0.985 s | Percent of total time: 78.8%
#
# Step: Actuate | Increment: 395 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.9875 s | Percent of total time: 79.0%
#
# Step: Actuate | Increment: 396 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.99 s | Percent of total time: 79.2%
#
# Step: Actuate | Increment: 397 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.9925 s | Percent of total time: 79.4%
#
# Step: Actuate | Increment: 398 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.995 s | Percent of total time: 79.6%
#
# Step: Actuate | Increment: 399 | Iterations: 5
# dt: 0.0025 | Simulation Time: 0.9975 s | Percent of total time: 79.8%
#
# Step: Actuate | Increment: 400 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.0 s | Percent of total time: 80.0%
#
# Step: Actuate | Increment: 401 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.0025 s | Percent of total time: 80.2%
#
# Step: Actuate | Increment: 402 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.005 s | Percent of total time: 80.4%
#
# Step: Actuate | Increment: 403 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.0075 s | Percent of total time: 80.6%
#
# Step: Actuate | Increment: 404 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.01 s | Percent of total time: 80.8%
#
# Step: Actuate | Increment: 405 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.0125 s | Percent of total time: 81.0%
#
# Step: Actuate | Increment: 406 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.015 s | Percent of total time: 81.2%
#
# Step: Actuate | Increment: 407 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.0175 s | Percent of total time: 81.4%
#
# Step: Actuate | Increment: 408 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.02 s | Percent of total time: 81.6%
#
# Step: Actuate | Increment: 409 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.0225 s | Percent of total time: 81.8%
#
# Step: Actuate | Increment: 410 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.025 s | Percent of total time: 82.0%
#
# Step: Actuate | Increment: 411 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.0275 s | Percent of total time: 82.2%
#
# Step: Actuate | Increment: 412 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.03 s | Percent of total time: 82.4%
#
# Step: Actuate | Increment: 413 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.0325 s | Percent of total time: 82.6%
#
# Step: Actuate | Increment: 414 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.035 s | Percent of total time: 82.8%
#
# Step: Actuate | Increment: 415 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.0375 s | Percent of total time: 83.0%
#
# Step: Actuate | Increment: 416 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.04 s | Percent of total time: 83.2%
#
# Step: Actuate | Increment: 417 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.0425 s | Percent of total time: 83.4%
#
# Step: Actuate | Increment: 418 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.045 s | Percent of total time: 83.6%
#
# Step: Actuate | Increment: 419 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.0475 s | Percent of total time: 83.8%
#
# Step: Actuate | Increment: 420 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.05 s | Percent of total time: 84.0%
#
# Step: Actuate | Increment: 421 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.0525 s | Percent of total time: 84.2%
#
# Step: Actuate | Increment: 422 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.055 s | Percent of total time: 84.4%
#
# Step: Actuate | Increment: 423 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.0575 s | Percent of total time: 84.6%
#
# Step: Actuate | Increment: 424 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.06 s | Percent of total time: 84.8%
#
# Step: Actuate | Increment: 425 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.0625 s | Percent of total time: 85.0%
#
# Step: Actuate | Increment: 426 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.065 s | Percent of total time: 85.2%
#
# Step: Actuate | Increment: 427 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.0675 s | Percent of total time: 85.4%
#
# Step: Actuate | Increment: 428 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.07 s | Percent of total time: 85.6%
#
# Step: Actuate | Increment: 429 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.0725 s | Percent of total time: 85.8%
#
# Step: Actuate | Increment: 430 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.075 s | Percent of total time: 86.0%
#
# Step: Actuate | Increment: 431 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.0775 s | Percent of total time: 86.2%
#
# Step: Actuate | Increment: 432 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.08 s | Percent of total time: 86.4%
#
# Step: Actuate | Increment: 433 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.0825 s | Percent of total time: 86.6%
#
# Step: Actuate | Increment: 434 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.085 s | Percent of total time: 86.8%
#
# Step: Actuate | Increment: 435 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.0875 s | Percent of total time: 87.0%
#
# Step: Actuate | Increment: 436 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.09 s | Percent of total time: 87.2%
#
# Step: Actuate | Increment: 437 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.0925 s | Percent of total time: 87.4%
#
# Step: Actuate | Increment: 438 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.095 s | Percent of total time: 87.6%
#
# Step: Actuate | Increment: 439 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.0975 s | Percent of total time: 87.8%
#
# Step: Actuate | Increment: 440 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.1 s | Percent of total time: 88.0%
#
# Step: Actuate | Increment: 441 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.1025 s | Percent of total time: 88.2%
#
# Step: Actuate | Increment: 442 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.105 s | Percent of total time: 88.4%
#
# Step: Actuate | Increment: 443 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.1075 s | Percent of total time: 88.6%
#
# Step: Actuate | Increment: 444 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.11 s | Percent of total time: 88.8%
#
# Step: Actuate | Increment: 445 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.1125 s | Percent of total time: 89.0%
#
# Step: Actuate | Increment: 446 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.115 s | Percent of total time: 89.2%
#
# Step: Actuate | Increment: 447 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.1175 s | Percent of total time: 89.4%
#
# Step: Actuate | Increment: 448 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.12 s | Percent of total time: 89.6%
#
# Step: Actuate | Increment: 449 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.1225 s | Percent of total time: 89.8%
#
# Step: Actuate | Increment: 450 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.125 s | Percent of total time: 90.0%
#
# Step: Actuate | Increment: 451 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.1275 s | Percent of total time: 90.2%
#
# Step: Actuate | Increment: 452 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.13 s | Percent of total time: 90.4%
#
# Step: Actuate | Increment: 453 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.1325 s | Percent of total time: 90.6%
#
# Step: Actuate | Increment: 454 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.135 s | Percent of total time: 90.8%
#
# Step: Actuate | Increment: 455 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.1375 s | Percent of total time: 91.0%
#
# Step: Actuate | Increment: 456 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.14 s | Percent of total time: 91.2%
#
# Step: Actuate | Increment: 457 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.1425 s | Percent of total time: 91.4%
#
# Step: Actuate | Increment: 458 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.145 s | Percent of total time: 91.6%
#
# Step: Actuate | Increment: 459 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.1475 s | Percent of total time: 91.8%
#
# Step: Actuate | Increment: 460 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.15 s | Percent of total time: 92.0%
#
# Step: Actuate | Increment: 461 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.1525 s | Percent of total time: 92.2%
#
# Step: Actuate | Increment: 462 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.155 s | Percent of total time: 92.4%
#
# Step: Actuate | Increment: 463 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.1575 s | Percent of total time: 92.6%
#
# Step: Actuate | Increment: 464 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.16 s | Percent of total time: 92.8%
#
# Step: Actuate | Increment: 465 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.1625 s | Percent of total time: 93.0%
#
# Step: Actuate | Increment: 466 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.165 s | Percent of total time: 93.2%
#
# Step: Actuate | Increment: 467 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.1675 s | Percent of total time: 93.4%
#
# Step: Actuate | Increment: 468 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.17 s | Percent of total time: 93.6%
#
# Step: Actuate | Increment: 469 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.1725 s | Percent of total time: 93.8%
#
# Step: Actuate | Increment: 470 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.175 s | Percent of total time: 94.0%
#
# Step: Actuate | Increment: 471 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.1775 s | Percent of total time: 94.2%
#
# Step: Actuate | Increment: 472 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.18 s | Percent of total time: 94.4%
#
# Step: Actuate | Increment: 473 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.1825 s | Percent of total time: 94.6%
#
# Step: Actuate | Increment: 474 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.185 s | Percent of total time: 94.8%
#
# Step: Actuate | Increment: 475 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.1875 s | Percent of total time: 95.0%
#
# Step: Actuate | Increment: 476 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.19 s | Percent of total time: 95.2%
#
# Step: Actuate | Increment: 477 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.1925 s | Percent of total time: 95.4%
#
# Step: Actuate | Increment: 478 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.195 s | Percent of total time: 95.6%
#
# Step: Actuate | Increment: 479 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.1975 s | Percent of total time: 95.8%
#
# Step: Actuate | Increment: 480 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.2 s | Percent of total time: 96.0%
#
# Step: Actuate | Increment: 481 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.2025 s | Percent of total time: 96.2%
#
# Step: Actuate | Increment: 482 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.205 s | Percent of total time: 96.4%
#
# Step: Actuate | Increment: 483 | Iterations: 4
# dt: 0.0025 | Simulation Time: 1.2075 s | Percent of total time: 96.6%
#
# Step: Actuate | Increment: 484 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.21 s | Percent of total time: 96.8%
#
# Step: Actuate | Increment: 485 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.2125 s | Percent of total time: 97.0%
#
# Step: Actuate | Increment: 486 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.215 s | Percent of total time: 97.2%
#
# Step: Actuate | Increment: 487 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.2175 s | Percent of total time: 97.4%
#
# Step: Actuate | Increment: 488 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.22 s | Percent of total time: 97.6%
#
# Step: Actuate | Increment: 489 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.2225 s | Percent of total time: 97.8%
#
# Step: Actuate | Increment: 490 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.225 s | Percent of total time: 98.0%
#
# Step: Actuate | Increment: 491 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.2275 s | Percent of total time: 98.2%
#
# Step: Actuate | Increment: 492 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.23 s | Percent of total time: 98.4%
#
# Step: Actuate | Increment: 493 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.2325 s | Percent of total time: 98.6%
#
# Step: Actuate | Increment: 494 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.235 s | Percent of total time: 98.8%
#
# Step: Actuate | Increment: 495 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.2375 s | Percent of total time: 99.0%
#
# Step: Actuate | Increment: 496 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.24 s | Percent of total time: 99.2%
#
# Step: Actuate | Increment: 497 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.2425 s | Percent of total time: 99.4%
#
# Step: Actuate | Increment: 498 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.245 s | Percent of total time: 99.6%
#
# Step: Actuate | Increment: 499 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.2475 s | Percent of total time: 99.8%
#
# Step: Actuate | Increment: 500 | Iterations: 5
# dt: 0.0025 | Simulation Time: 1.25 s | Percent of total time: 100.0%
#
# -----------------------------------------
# End computation
# ------------------------------------------
# Elapsed real time:  0:23:26.341015
# ------------------------------------------

# %% [markdown]
# # Plot results

# %%
# set plot font to size 18
font = {'size'   : 18}
plt.rc('font', **font)

# Get array of default plot colors
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']


# Only plot as far as we have time history data
ind = np.argmax(timeHist0) + 1


# Two-axis plotting
fig, (ax1, ax2) = plt.subplots(2,1, sharex='col')

ax1.plot(timeHist0[0:ind], timeHist1[0:ind], c=colors[3], linewidth=1.0, marker='.')
ax1.grid(linestyle="--", linewidth=0.5, color='b')
ax1.set_ylabel('Electric potential (kV)')
# ax1.set_xlim([0,5])
from matplotlib.ticker import AutoMinorLocator,FormatStrFormatter
ax1.xaxis.set_minor_locator(AutoMinorLocator())
ax1.yaxis.set_minor_locator(AutoMinorLocator())

ax2.plot(timeHist0[0:ind], timeHist2[0:ind], c=colors[0], linewidth=1.0, marker='.')
ax2.grid(linestyle="--", linewidth=0.5, color='b')
ax2.set_xlabel('Time (s)')
ax2.set_ylabel('Displacement (mm)')
from matplotlib.ticker import AutoMinorLocator,FormatStrFormatter
ax2.xaxis.set_minor_locator(AutoMinorLocator())
ax2.yaxis.set_minor_locator(AutoMinorLocator())


# fig = plt.gcf()
# fig.set_size_inches(7,5)
# plt.tight_layout()
# plt.savefig("results/electro-viscoelastic_six_arm_gripper_actuation.png", dpi=600)


plt.figure()

# Two-axis plotting
fig, (ax1, ax2, ax3) = plt.subplots(3,1, sharex='col')

ax1.plot(timeHist0[0:ind], timeHist1[0:ind], c=colors[0], linewidth=2.0)
ax1.grid(linestyle="--", linewidth=0.5, color='b')
ax1.set_ylabel(r'$\phi$ (kV)')

ax2.plot(timeHist0[0:ind], timeHist2[0:ind], c=colors[1], linewidth=2.0)
ax2.grid(linestyle="--", linewidth=0.5, color='b')
# ax2.set_xlabel(r'Time (s)')
ax2.set_ylabel(r'Disp. (mm)')

ax3.plot(timeHist0[0:ind], timeHist3[0:ind], c=colors[1], linewidth=2.0)
ax3.grid(linestyle="--", linewidth=0.5, color='b')
ax3.set_xlabel(r'Time (s)')
ax3.set_ylabel(r'Disp. (mm)')
#plt.show()

# ax1.set_ylim([-1.1*phiTot,1.1*phiTot])
ax1.set_xlim([0.0,Ttot])
# ax2.set_ylim([0.35,1.05])
ax2.set_xlim([0.0,Ttot])


fig = plt.gcf()
fig.set_size_inches(7,5)
plt.tight_layout()
# plt.savefig("results/electro-viscoelastic_six_arm_gripper_actuation.png", dpi=600)

# %% [markdown]
# # Saving data and making plots below, not part of the actual simulation, just for the plots in the book

# %%
# np.savetxt('GripperData4Hz.csv', np.vstack((timeHist0[0:ind],timeHist1[0:ind],\
#     timeHist2[0:ind],timeHist3[0:ind])).T, delimiter=',')

# %%
# # retrieve data from prior runs
# FourHz = np.genfromtxt('GripperData4Hz.csv', delimiter=',')
# OneFourthHz = np.genfromtxt('GripperDataOneFourthHz.csv', delimiter=',')

# FourHzPeriod = 1.0/4.0
# OneFourthHzPeriod = 1.0/0.25




# plt.figure()

# # Two-axis plotting
# fig, (ax1, ax2) = plt.subplots(2,1, sharex='col')

# ax1.plot(FourHz[:,0]/FourHzPeriod, FourHz[:,1], c=colors[0], linewidth=2.0)
# ax1.grid(linestyle="--", linewidth=0.5, color='b')
# ax1.set_ylabel(r'$\phi$ (kV)')



# ax2.plot(FourHz[:,0]/FourHzPeriod, FourHz[:,2], c=colors[0], linewidth=2.0, label='4Hz')
# ax2.grid(linestyle="--", linewidth=0.5, color='b')
# # ax2.set_xlabel(r'Time (s)')
# ax2.set_xlabel(r'Cycle')
# ax2.set_ylabel(r'Disp. (mm)')

# ax3 = ax2.twinx()  # instantiate a second Axes that shares the same x-axis

# ax3.plot(OneFourthHz[:,0]/OneFourthHzPeriod, OneFourthHz[:,2], c=colors[1], linewidth=2.0, label='0.25Hz')
# ax3.grid(linestyle="--", linewidth=0.5, color='b')
# ax3.set_axis_off()
# # ax3.set_ylabel(r'Disp. (mm)')
# #plt.show()


# # ax1.set_ylim([-1.1*phiTot,1.1*phiTot])
# ax1.set_xlim([0.0,ncycles])
# ax2.set_ylim([-18,1])
# ax3.set_ylim([-18,1])
# ax2.set_xlim([0.0,ncycles])

# ax2.legend(loc='lower left')
# ax3.legend(loc='lower center')

# fig = plt.gcf()
# fig.set_size_inches(7,5)
# plt.tight_layout()
# plt.savefig("results/electro-viscoelastic_six_arm_gripper_actuation.png", dpi=600)
