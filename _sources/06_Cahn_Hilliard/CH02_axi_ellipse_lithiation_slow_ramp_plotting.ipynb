# %% [markdown]
# # Code for Cahn-Hilliard phase separation with mechanical coupling
#
# - This is a two-dimensional  axisymmetric simulation
# - Slow ramp lithiation

# %% [markdown]
# # Degrees of freedom
# - mechanical dispalcement: u
# - chemical potential: mu
# - concentration: c

# %% [markdown]
# # Units
# - Length: um
# - Mass: kg
# - Time: s
# - Amount of substance: pmol
# - Temperature: K
#
# - Mass density: kg/um^3
# - Force: uN
# - Stress: MPa
# - Energy: pJ
# - Species concentration: pmol/um^3
# - Chemical potential: pJ/pmol
# - Molar volume: um^3/pmol
# - Species diffusivity: um^2/s
# - Boltzmann Constant: 1.38E-11 pJ/K
# - Gas constant: 8.3145  pJ/(pmol K)
#
#
# ### Software:
# - Dolfinx v0.8.0
#
# Eric Stewart and Lallit Anand
#
# ericstew@mit.edu and anand@mit.edu
#
# June 2024

# %% [markdown]
# # Import modules

# %%
# Import FEnicSx/dolfinx
import dolfinx

# For numerical arrays
import numpy as np

# For MPI-based parallelization
from mpi4py import MPI
comm = MPI.COMM_WORLD
rank = comm.Get_rank()

# PETSc solvers
from petsc4py import PETSc

# specific functions from dolfinx modules
from dolfinx import fem, mesh, io, plot, log
from dolfinx.fem import (Constant, dirichletbc, Function, functionspace, Expression )
from dolfinx.fem.petsc import NonlinearProblem
from dolfinx.nls.petsc import NewtonSolver
from dolfinx.io import VTXWriter, XDMFFile

# specific functions from ufl modules
import ufl
from ufl import (TestFunctions, TrialFunction, Identity, grad, det, div, dev, inv, tr, sqrt, conditional ,\
                 lt, gt, dx, inner, derivative, dot, ln, split, exp, eq, cos, sin, acos, ge, le, outer, tanh,\
                 cosh, atan, atan2)

# basix finite elements (necessary for dolfinx v0.8.0)
import basix
from basix.ufl import element, mixed_element

# Matplotlib for plotting
import matplotlib.pyplot as plt
plt.close('all')

# For timing the code
from datetime import datetime

# Set level of detail for log messages (integer)
# Guide:
# CRITICAL  = 50, // errors that may lead to data corruption
# ERROR     = 40, // things that HAVE gone wrong
# WARNING   = 30, // things that MAY go wrong later
# INFO      = 20, // information of general interest (includes solver info)
# PROGRESS  = 16, // what's happening (broadly)
# TRACE     = 13, // what's happening (in detail)
# DBG       = 10  // sundry
#
log.set_log_level(log.LogLevel.WARNING)

# %% [markdown]
# # Define geometry

# %%
# Ellipse major axis
a0 = 0.5 # um 
# Ellipse minor axis
b0 = 0.3 #um

# Read in the 2D mesh and cell tags
with XDMFFile(MPI.COMM_WORLD,"meshes/axi_ellipse.xdmf",'r') as infile:
    domain = infile.read_mesh(name="Grid",xpath="/Xdmf/Domain")
    cell_tags = infile.read_meshtags(domain,name="Grid")
domain.topology.create_connectivity(domain.topology.dim, domain.topology.dim-1)

# Also read in 1D facets for applying BCs
with XDMFFile(MPI.COMM_WORLD,"meshes/facet_axi_ellipse.xdmf",'r') as infile:
    facet_tags = infile.read_meshtags(domain,name="Grid")

# A single point at the center of the inclusion for "grounding" the displacement of the inclusion
def ground(x):
    return np.logical_and(np.isclose(x[0], 0), np.isclose(x[1], 0))

x = ufl.SpatialCoordinate(domain)

# %% [markdown]
# **Print out the unique cell number indices**

# %%
top_imap = domain.topology.index_map(2)      # index map of 2D entities in domain
values = np.zeros(top_imap.size_global)      # an array of zeros of the same size as number of 2D entities
values[cell_tags.indices]=cell_tags.values   # populating the array with facet tag index numbers
print(np.unique(cell_tags.values))           # printing the unique indices

# Gmsh numbering
# Physical Surface("particle", 8)
# Out:
# [8]

# %% [markdown]
# **Print out the unique edge index numbers**

# %%
top_imap = domain.topology.index_map(1)      # index map of 1D entities in domain
values = np.zeros(top_imap.size_global)      # an array of zeros of the same size as number of 2D entities
values[facet_tags.indices]=facet_tags.values # populating the array with facet tag index numbers
print(np.unique(facet_tags.values))          # printing the unique indices

# Curve labels from Gmsh
#
# //+
# Physical Curve("left", 5)  
# //+
# Physical Curve("bottom", 6)  
# //+
# Physical Curve("outer", 7)
# Out:
# [5 6 7]

# %% [markdown]
# ## Define boundary and volume integration measure

# %%
# Define the boundary integration measure "ds" using the facet tags,
# also specify the number of surface quadrature points.
ds = ufl.Measure('ds', domain=domain, subdomain_data=facet_tags, metadata={'quadrature_degree':4})

# Define the volume integration measure "dx" 
# also specify the number of volume quadrature points.
dx = ufl.Measure('dx', domain=domain, metadata={'quadrature_degree': 4})

# Create facet to cell connectivity required to determine boundary facets.
domain.topology.create_connectivity(domain.topology.dim, domain.topology.dim)
domain.topology.create_connectivity(domain.topology.dim, domain.topology.dim-1)
domain.topology.create_connectivity(domain.topology.dim-1, domain.topology.dim)

# #  Define facet normal
n2D = ufl.FacetNormal(domain)
n = ufl.as_vector([n2D[0], n2D[1], 0.0]) # define n as a 3D vector for later use

# %%
for factor in [1.0, 0.2, 0.1]:

    # Material parameters after Di Leo et al. (2014)
    #
    Gshear   = Constant(domain,PETSc.ScalarType(49.8e3*factor))    # Shear modulus, MPa
    Kbulk    = Constant(domain,PETSc.ScalarType(83e3*factor))      # Bulk modulus, MPa
    #
    Omega    = Constant(domain,PETSc.ScalarType(4.05))      # Molar volume, um^3/pmol 
    D        = Constant(domain,PETSc.ScalarType(1e-2))      # Diffusivity, um^2/s 
    chi      = Constant(domain,PETSc.ScalarType(3))         # Phase parameter, (-)
    cMax     = Constant(domain,PETSc.ScalarType(2.29e-2))   # Saturation concentration, pmol/um^3
    lam      = Constant(domain,PETSc.ScalarType(5.5749e-1)) # Interface parameter, (pJ/pmol) um^2
    #
    theta0   = Constant(domain,PETSc.ScalarType(298))        # Reference temperature, K
    R_gas    = Constant(domain,PETSc.ScalarType(8.3145))    # Gas constant, pJ/(pmol K)
    RT       = Constant(domain,PETSc.ScalarType(R_gas*theta0))


    # %%
    t     = 0.0   # initialization of time
    Ttot  = 1800  # Total time, s
    dt    = 0.01   # Initial time step size, here we will use adaptive time-stepping

    # Time step field, constant within body
    dk = Constant(domain, PETSc.ScalarType(dt))

    # Initial and final cBar values
    cBar_i = Constant(domain, PETSc.ScalarType(0.005))
    cBar_f = Constant(domain, PETSc.ScalarType(0.995))

    # Corresponding (normalized) chemical potential values
    mu_i =   Constant(domain, PETSc.ScalarType(ln(cBar_i/(1-cBar_i)) + float(chi)*(1-2*cBar_i)))
    mu_f =   Constant(domain, PETSc.ScalarType(ln(cBar_f/(1-cBar_f)) + float(chi)*(1-2*cBar_f)))

    def muRamp(t):
        return mu_i + (mu_f - mu_i)*(t/Ttot)

    # %% [markdown]
    # # Function spaces

    # %%
    # Define function space, both vectorial and scalar
    U2 = element("Lagrange", domain.basix_cell(), 2, shape=(2,)) # For displacement
    P1 = element("Lagrange", domain.basix_cell(), 1) # Forchemical potential and species concentration 
    #                                      
    TH = mixed_element([U2, P1, P1])     # Mixed element
    ME = functionspace(domain, TH)    # Total space for all DOFs

    # Define actual functions with the required DOFs
    w = Function(ME)
    u, mu, c = split(w)  # chemical potential mu and concentration c

    # A copy of functions to store values in the previous step for time-stepping
    w_old = Function(ME)
    u_old, mu_old, c_old = split(w_old)   

    # Define test functions    
    u_test, mu_test, c_test  = TestFunctions(ME)  

    # Define trial functions needed for automatic differentiation
    dw = TrialFunction(ME)                  

    # %% [markdown]
    # # Initial conditions

    # %%
    # Assign initial  normalized chemical potential  mu_i to the domain
    w.sub(1).interpolate(lambda x: np.full((x.shape[1],),  mu_i))
    w_old.sub(1).interpolate(lambda x: np.full((x.shape[1],), mu_i))  


    # Assign initial  normalized concentration   c_i to the domain
    c_i = Constant(domain, PETSc.ScalarType(cBar_i*cMax*Omega))
    # 
    w.sub(2).interpolate(lambda x: np.full((x.shape[1],),  c_i))
    w_old.sub(2).interpolate(lambda x: np.full((x.shape[1],), c_i)) 

    # %% [markdown]
    # # Subroutines for kinematics and constitutive equations

    # %%
    # Special gradient operators for axisymmetric functions 
    #
    #---------------------------------------------------
    # Gradient of vector field u   
    #---------------------------------------------------
    def axi_grad_vector(u):
        
        grad_u = grad(u)
        
        axi_grad_33_exp = conditional(eq(x[0], 0), 0.0, u[0]/x[0])
        
        axi_grad_u = ufl.as_tensor([[grad_u[0,0], grad_u[0,1], 0],
                    [grad_u[1,0], grad_u[1,1], 0],
                    [0, 0, axi_grad_33_exp]]) 
        
        return axi_grad_u

    #---------------------------------------------------
    # Gradient of scalar field y
    # (just need an extra zero for dimensions to work out)
    #---------------------------------------------------
    def axi_grad_scalar(y):
        
        grad_y = grad(y)
        
        axi_grad_y = ufl.as_vector([grad_y[0], grad_y[1], 0.])
        
        return axi_grad_y
    #---------------------------------------------------
    # Axisymmetric deformation gradient 
    #---------------------------------------------------
    def F_axi_calc(u):
        
        dim = len(u)                # dimension of problem (2)
        
        Id = Identity(dim)          # 2D Identity tensor
        
        F = Id + grad(u)            # 2D Deformation gradient
        
        F33_exp =  1.0 + u[0]/x[0]  # axisymmetric F33, R/R0 
        
        F33 = conditional(eq(x[0], 0.0), 1.0, F33_exp) # avoid divide by zero at r=0
        
        F_axi =  ufl.as_tensor([[F[0,0], F[0,1], 0],
                    [F[1,0], F[1,1], 0],
                    [0, 0, F33]]) # Full axisymmetric F
        
        return F_axi



    #  Elastic deformation gradient Fe
    def Fe_calc(u,c):
        F = F_axi_calc(u)      # = F
        J = det(F)            # = J
        #
        Js = 1.0 + c          #  what about (c-c_i)?
        Fs = Js**(1/3)*Identity(3) 
        #
        Fe = F*inv(Fs)
        return   Fe    

    # The elastic second Piola stress
    def Te_calc(u, c):
        Id = Identity(3)
        #
        Fe = Fe_calc(u, c)
        Je = det(Fe)
        Ce = Fe.T*Fe
        #
        Cebar = Je**(-2/3)*Ce
        #
        Te = Je**(-2/3)*Gshear*(Id - (1/3)*tr(Cebar)*inv(Cebar))\
            + Kbulk*Je*(Je-1)*inv(Cebar)
        #
        return Te

    # The elastic Mandel stress
    def Me_calc(u, c):
        Fe = Fe_calc(u, c)
        Je = det(Fe)
        Ce = Fe.T*Fe
        #
        Te = Te_calc(u, c)
        #
        Me = Ce*Te
        #
        return Me
    
    # The first Piola stress     
    def Piola_calc(u,c):
        #
        F = F_axi_calc(u)
        J = det(F)
        #
        Fe = Fe_calc(u, c)
        Je = det(Fe)
        #
        Te = Te_calc(u,c)
        #
        T  = Je**(-1)*Fe*Te*inv(Fe)
        #
        Piola  = J*T*inv(F.T)/Gshear 
        return Piola

    #------------------------------------------------------------------------------  
    # Species flux
    def Flux_calc(u, mu, c):
        F = F_axi_calc(u) 
        #
        Cinv = inv(F.T*F) 
        #
        cBar = c/(Omega*cMax) # normalized concentration
        #
        Mob = (D*c)/(Omega*RT)*(1-cBar)*Cinv
        #
        Jmat = - RT* Mob * axi_grad_scalar(mu)
        #
        return Jmat

    # Calculate the f^c term
    def fc_calc(u, c):
        #
        cBar = c/(Omega*cMax) # normalized concentration
        #
        Me = Me_calc(u,c)
        #
        fc   = RT*(ln(cBar/(1-cBar)) + chi*(1-2*cBar) ) - Omega*((1/3)*tr(Me))
        #
        return fc


    # Calculate  principal Cauchy stresses for visualization only
    def tensor_eigs(T):
        # invariants of T
        I1 = tr(T) 
        I2 = (1/2)*(tr(T)**2 - tr(T*T))
        I3 = det(T)
        
        # Intermediate quantities b, c, d
        b = -I1
        c = I2
        d = -I3
        
        # intermediate quantities E, F, G
        E = (3*c - b*b)/3
        F = (2*(b**3) - 9*b*c + 27*d)/27
        G = (F**2)/4 + (E**3)/27
        
        # Intermediate quantities H, I, J, K, L
        H = sqrt(-(E**3)/27)
        I = H**(1/3)
        J = acos(-F/(2*H))
        K = cos(J/3)
        L = sqrt(3)*sin(J/3)
        
        # Finally, the (not necessarily ordered) eigenvalues
        t1 = 2*I*K - b/3
        t2 = -I*(K+L) - b/3
        t3 = -I*(K-L) - b/3
        
        # Order the eigenvalues using conditionals
        #
        T1_temp = conditional(lt(t1, t3), t3, t1 ) # returns the larger of t1 and t3.
        T1 = conditional(lt(T1_temp, t2), t2, T1_temp ) # returns the larger of T1_temp and t2.
        #
        T3_temp = conditional(gt(t3, t1), t1, t3 ) # returns the smaller of t1 and t3.
        T3 = conditional(gt(T3_temp, t2), t2, T1_temp ) # returns the smaller of T3_temp and t2.
        #
        # use the trace to report the middle eigenvalue.
        T2 = I1 - T1 - T3
        
        return T1, T2, T3


    # %% [markdown]
    # # Evaluate kinematics and constitutive relations

    # %%
    # Kinematics
    F = F_axi_calc(u)
    J = det(F) 

    # Calculate the normalized concentration cBar
    cBar = c/(Omega*cMax) # normalized concentration

    # Calculate the Piola stress
    Piola = Piola_calc(u,c)

    # Calculate the Species flux
    Jmat = Flux_calc(u, mu, c)

    # Calculate the f^c term 
    fc = fc_calc(u, c)


    # %% [markdown]
    # # Weak forms

    # %%
    # Residuals:
    # Res_0: Equation of motion (test fxn: u)
    # Res_1: Balance of mass   (test fxn: mu)
    # Res_2: chemical potential (test fxn: c)

    #
    mu_ext_cons = Constant(domain,PETSc.ScalarType(muRamp(0)))

    # Calculate the  spatial species boundary flux:
    j_spat_flux = mu - mu_ext_cons
    #
    Fcof = J*inv(F.T)                 # Cofactor of F
    nvec  =  dot(Fcof,n)              # Recall that we had defined: n = ufl.as_vector([n2D[0], n2D[1], 0.0])
    da_mat  = sqrt(inner(nvec, nvec)) # Areal jacobian
    #
    # Calculate the configuration-dependent referential spcies flux:
    jBar =  j_spat_flux * da_mat

    # The weak form for the equation of motion
    Res_0 = inner(Piola, axi_grad_vector(u_test))*x[0]*dx

    # The weak form for the mass balance of mobile species    
    Res_1 = dot((c - c_old)/dk, mu_test)*x[0]*dx \
            -  Omega*dot(Jmat , axi_grad_scalar(mu_test) )*x[0]*dx \
            + Omega*dot(jBar, mu_test)*x[0]*ds(7)

    # The weak form for the mass balance of mobile species    
    # Res_1 = dot((c - c_old)/dk, mu_test)*x[0]*dx \
    #         -  Omega*dot(Jmat , axi_grad_scalar(mu_test) )*x[0]*dx \
    #         + Omega*dot(jBar, mu_test)*x[0]*ds(7)

    # The weak form for the concentration
    Res_2 = dot(mu - fc/RT, c_test)*x[0]*dx \
            -  dot( (lam/RT)*axi_grad_scalar(cBar), axi_grad_scalar(c_test))*x[0]*dx
            
    # Total weak form
    Res = Res_0 + Res_1 + Res_2

    # Automatic differentiation tangent:
    a = derivative(Res, w, dw)

    # %% [markdown]
    # # # Set-up output files

    # # %%
    # # Set up projection problem for fixing visualization issues
    # # of fields in  the axisymmetric simulation
    # #
    # def setup_projection(u, V):

    #     trial = ufl.TrialFunction(V)
    #     test  = ufl.TestFunction(V)   

    #     a = ufl.inner(trial, test)*x[0]*dx
    #     L = ufl.inner(u, test)*x[0]*dx

    #     projection_problem = dolfinx.fem.petsc.LinearProblem(a, L, [], \
    #         petsc_options={"ksp_type": "cg", "ksp_rtol": 1e-16, "ksp_atol": 1e-16, "ksp_max_it": 1000})
        
    #     return projection_problem

    # # %%
    # # results file name
    # results_name = "axi_ellipse_lithiation_step"

    # # Function space for projection of results
    # U1 = element("DG", domain.basix_cell(), 1, shape=(2,))  # For 2d vector
    # P0 = element("DG", domain.basix_cell(), 1)              # For  scalar 
    # T1 = element("DG", domain.basix_cell(), 1, shape=(3,3)) # For stress tensor

    # V1 = fem.functionspace(domain, P0) # Scalar function space
    # V2 = fem.functionspace(domain, U1) # Vector function space
    # V3 = fem.functionspace(domain, T1) # Tensor function space

    # # basic fields to write to output file
    # u_vis = Function(V2)
    # u_vis.name = "disp"

    # mu_vis = Function(V1)
    # mu_vis.name = "mu"

    # c_vis = Function(V1)
    # c_vis.name = "c"

    # # Project cBar for visualization
    # #
    # cBar_projection = setup_projection(cBar, V1)
    # cBar_vis = cBar_projection.solve()
    # cBar_vis.name = "cBar"

    # # Project the volumetric Jacobian J for visualization
    # #
    # J_projection = setup_projection(J, V1)
    # J_vis = J_projection.solve()
    # J_vis.name = "J"
    
    # # Project the Piola stress tensor for visualization
    # #
    # Piola_projection = setup_projection(Piola, V3)
    # Piola_temp = Piola_projection.solve()

    # T   = Gshear*Piola_temp*F.T/J
    # T0   = T - (1/3)*tr(T)*Identity(3)
    # Mises = sqrt((3/2)*inner(T0, T0))
    # Mises_projection = setup_projection(Mises, V1)
    # Mises_vis = Mises_projection.solve()
    # Mises_vis.name = "Mises"

    # sig1, sig2, sig3 = tensor_eigs(T)
    # #
    # sig1_projection = setup_projection(sig1, V1)
    # sig1_vis = sig1_projection.solve()
    # sig1_vis.name = "sig1"
    # #
    # sig2_projection = setup_projection(sig2, V1)
    # sig2_vis = sig2_projection.solve()
    # sig2_vis.name = "sig2"
    # #
    # sig3_projection = setup_projection(sig3, V1)
    # sig3_vis = sig3_projection.solve()
    # sig3_vis.name = "sig3"
    # # #
    # # sig1_vis = Function(V1)
    # # sig1_vis.name = "sig1"
    # # sig1_expr = Expression(sig1, V1.element.interpolation_points())
    # # #
    # # sig2_vis = Function(V1)
    # # sig2_vis.name = "sig2"
    # # sig2_expr = Expression(sig2, V1.element.interpolation_points())

    # P11 = Function(V1)
    # P11.name = "P11"
    # P11_expr = Expression(Gshear*Piola_temp[0,0],V1.element.interpolation_points())
    # #
    # P22 = Function(V1)
    # P22.name = "P22"
    # P22_expr = Expression(Gshear*Piola_temp[1,1],V1.element.interpolation_points())
    # #
    # P33 = Function(V1)
    # P33.name = "P33"
    # P33_expr = Expression(Gshear*Piola_temp[2,2],V1.element.interpolation_points())

    # # set up the output VTX files.
    # file_results = VTXWriter(
    #     MPI.COMM_WORLD,
    #     "results/" + results_name + ".bp",
    #     [  # put the functions here you wish to write to output
    #         u_vis, mu_vis, c_vis, cBar_vis, J_vis, 
    #         P11, P22, P33, sig1_vis, sig2_vis, sig3_vis, Mises_vis,
    #     ],
    #     engine="BP4",
    # )

    # def writeResults(t):
        
    #     # Re-project some fields. This is necessary here to remove visual artifacts which arise
    #     # due to the axisymmetric formulation as r -> 0
    #     #
    #     Piola_temp     = Piola_projection.solve()
    #     Mises_vis      = Mises_projection.solve()
    #     J_vis          = J_projection.solve()
    #     cBar_vis       = cBar_projection.solve()
    #     sig1_vis       = sig1_projection.solve()
    #     sig2_vis       = sig2_projection.solve()
    #     sig3_vis       = sig3_projection.solve()

    #     # Output field interpolation 
    #     u_vis.interpolate(w.sub(0))
    #     mu_vis.interpolate(w.sub(1))
    #     c_vis.interpolate(w.sub(2))
    #     P11.interpolate(P11_expr)
    #     P22.interpolate(P22_expr)
    #     P33.interpolate(P33_expr)
    #     #    #
    #     #    sig1_vis.interpolate(sig1_expr)
    #     #    sig2_vis.interpolate(sig2_expr)

    #     # Write output fields
    #     file_results.write(t) 
            

    # %% [markdown]
    # # Infrastructure for pulling out time history data (displacement, force, etc.)

    # %%

    # # Identify point for reporting temperature
    # pointForDisp = np.array([r_out,L0/2,0.0])

    # bb_tree = dolfinx.geometry.bb_tree(domain,domain.topology.dim)
    # cell_candidates = dolfinx.geometry.compute_collisions_points(bb_tree, pointForDisp)
    # colliding_cells = dolfinx.geometry.compute_colliding_cells(domain, cell_candidates, pointForDisp).array

    # Form for evaluating the state of charge  SOC at each step
    # ( SOC = Tot_chg / Tot_vol )
    #
    Tot_chg = fem.form(2.0*np.pi* cBar *x[0]*dx)
    #
    Tot_vol = fem.form(2.0*np.pi*x[0]*dx)

    # The (referential) volume is constant, so just evaluate it once before running the simulation:
    #
    Tot_vol_val = domain.comm.gather(fem.assemble_scalar(Tot_vol))[0]

    # %% [markdown]
    # # Analysis Step 

    # %%
    # Give the step a descriptive name
    step = "Lithiate"

    # %% [markdown]
    # ## Boundary conditions

    # %%
    # Constant for applied chemical potential
    mu_cons = Constant(domain,PETSc.ScalarType(muRamp(0)))

    # Recall gmsh curve  names and numbers
    # Physical Curve("left", 5)  
    # //+
    # Physical Curve("bottom", 6)  
    # //+
    # Physical Curve("outer", 7)   


    # Find the specific DOFs which will be constrained
    xBot_u1_dofs = fem.locate_dofs_topological(ME.sub(0).sub(0), facet_tags.dim, facet_tags.find(5))
    yBot_u2_dofs = fem.locate_dofs_topological(ME.sub(0).sub(1), facet_tags.dim, facet_tags.find(6))
    #
    #outer_mu_dofs = fem.locate_dofs_topological(ME.sub(1), facet_tags.dim, facet_tags.find(7))

    # Build Dirichlet BCs
    bcs_1 = dirichletbc(0.0, xBot_u1_dofs, ME.sub(0).sub(0)) # u1 fix -  left
    bcs_2 = dirichletbc(0.0, yBot_u2_dofs, ME.sub(0).sub(1)) # u2 fix - bottom
    #

    bcs = [bcs_1,bcs_2]

    # %% [markdown]
    # ## Define the nonlinear variational problem

    # %%
    # Set up nonlinear problem
    problem = NonlinearProblem(Res, w, bcs, a)

    # The global newton solver and params
    solver = NewtonSolver(MPI.COMM_WORLD, problem)
    solver.convergence_criterion = "incremental"
    solver.rtol = 1e-8
    solver.atol = 1e-8
    solver.max_it = 50
    solver.report = True
    solver.error_on_nonconvergence = False

    #  The Krylov solver parameters.
    ksp = solver.krylov_solver
    opts = PETSc.Options()
    option_prefix = ksp.getOptionsPrefix()
    opts[f"{option_prefix}ksp_type"] = "preonly"  
    opts[f"{option_prefix}pc_type"] = "lu" # do not use 'gamg' pre-conditioner
    opts[f"{option_prefix}pc_factor_mat_solver_type"] = "mumps"
    opts[f"{option_prefix}ksp_max_it"] = 30
    ksp.setFromOptions()

    # %% [markdown]
    # # Initialize arrays for storing output history

    # %%
    #Arrays for storing output history
    totSteps = 100000
    timeHist0 = np.zeros(shape=[totSteps])
    timeHist1 = np.zeros(shape=[totSteps]) 
    # # timeHist2 = np.zeros(shape=[totSteps]) 
    # # timeHist3 = np.zeros(shape=[totSteps])
    # # #
    # # timeHist3[0] = mu0 # Initialize the chemical potential

    # Initialize a counter for reporting data
    ii = 0

    # # Write initial state to file
    # writeResults(t=0.0) 

    # %% [markdown]
    # ##  Start calculation loop

    # %%
    print("------------------------------------")
    print("Simulation start")
    print("------------------------------------")
    # Store start time 
    startTime = datetime.now()

    # Time-stepping solution procedure loop
    while (round(t, 9) <= Ttot):
        
        # increment time
        t += dt 
        
        # update time variables in time-dependent BCs 
        mu_ext_cons.value = float(muRamp(t))
        
    # Solve the problem
        (iter, converged) = solver.solve(w)
        
        # Now we start the adaptive time-stepping and output storage procedure.
        #
        # First, we check if the newton solver actually converged.
        if converged: 

            # Collect results from MPI ghost processes
            w.x.scatter_forward()
            
            # Write output to file
            # writeResults(t)

            # If the solver converged, we print the status of the solver, 
            # perform adaptive time-stepping updates, output results, and 
            # update degrees of freedom for the next step, w_old <- w.
            
            # print progress of calculation periodically
            if ii%1 == 0:      
                now = datetime.now()
                current_time = now.strftime("%H:%M:%S")
                print("Step: {} |   Increment: {} | Iterations: {}".format(step, ii, iter))
                print("Simulation Time: {} s | dt: {} s".format(round(t,2), round(dt, 3)))
                print()   
            
            # Iteration-based adaptive time-stepping
            #
            # If the newton solver takes 2 or less iterations, 
            # increase the time step by a factor of 1.5:
            if ((iter<=4) and (dt<1)):
                dt = 1.5*dt
                dk.value = dt
            # If the newton solver takes 5 or more iterations, 
            # decrease the time step by a factor of 2:
            elif iter>=6:
                dt = dt/2
                dk.value = dt
            # otherwise the newton solver took 3-4 iterations,
            # in which case leave the time step alone.

            # update the DOFs for the next step.
            w_old.x.array[:] = w.x.array
            
            # Increment counter
            ii += 1
            
            # Store time history variables
            timeHist0[ii] = t # current time
            timeHist1[ii] = domain.comm.gather(fem.assemble_scalar(Tot_chg))[0] / Tot_vol_val # time history of State of charge
        
        # If solver doesn't converge we have to back up in time,
        # cut the size of the time step, and try solving again.
        else: # not(converged)
            
            # first, we back up in time
            # ( to un-do the current time step )
            t = t - float(dk)
            
            # Then, we cut back on the time step we're attempting.
            # (by a factor of 2)
            dt = dt/2
            dk.value = dt 

            # Re-set the DOFs to their value before the failed step.
            w.x.array[:] = w_old.x.array

            # Set up nonlinear problem
            problem = NonlinearProblem(Res, w, bcs, a)

            # The global newton solver and params
            solver = NewtonSolver(MPI.COMM_WORLD, problem)
            solver.convergence_criterion = "incremental"
            solver.rtol = 1e-8
            solver.atol = 1e-8
            solver.max_it = 50
            solver.report = True
            solver.error_on_nonconvergence = False
    


    # close the output file.
    # file_results.close()
            
            
    # End analysis
    print("-----------------------------------------")
    print("End computation")                 
    # Report elapsed real time for the analysis
    endTime = datetime.now()
    elapseTime = endTime - startTime
    print("------------------------------------------")
    print("Elapsed real time:  {}".format(elapseTime))
    print("------------------------------------------")


    # %%
    # set plot font to size 14
    font = {'size'   : 14}
    plt.rc('font', **font)

    # Only plot as far as we have time history data
    ind = np.argmax(timeHist0)

    # Get array of default plot colors
    prop_cycle = plt.rcParams['axes.prop_cycle']
    colors = prop_cycle.by_key()['color']
    # Create figure  
    #-------------------------------------------------------------
    plt.plot(timeHist0[0:ind], timeHist1[0:ind], linewidth=2.0,\
        #   color='r', marker='o', markersize=3)
          label=r"$E/E_0 = $ {}".format(factor) )
    #-------------------------------------------------------------
    plt.axis('tight')
    plt.ylabel(r"State of Charge")
    plt.xlabel(r"Time (s)")
    plt.grid(linestyle="--", linewidth=0.5, color='b')
    plt.ylim(0,1.01)
    plt.xlim(0,1800)

     
plt.legend()
fig = plt.gcf()
fig.set_size_inches(7,5)
plt.tight_layout()
plt.savefig("results/ellipse_lithiation_slow_ramp_curves.png", dpi=600)
# Out:
# ------------------------------------
# Simulation start
# ------------------------------------
# Step: Lithiate |   Increment: 0 | Iterations: 3
# Simulation Time: 0.01 s | dt: 0.01 s
#
# Step: Lithiate |   Increment: 1 | Iterations: 2
# Simulation Time: 0.03 s | dt: 0.015 s
#
# Step: Lithiate |   Increment: 2 | Iterations: 2
# Simulation Time: 0.05 s | dt: 0.022 s
#
# Step: Lithiate |   Increment: 3 | Iterations: 2
# Simulation Time: 0.08 s | dt: 0.034 s
#
# Step: Lithiate |   Increment: 4 | Iterations: 2
# Simulation Time: 0.13 s | dt: 0.051 s
#
# Step: Lithiate |   Increment: 5 | Iterations: 3
# Simulation Time: 0.21 s | dt: 0.076 s
#
# Step: Lithiate |   Increment: 6 | Iterations: 3
# Simulation Time: 0.32 s | dt: 0.114 s
#
# Step: Lithiate |   Increment: 7 | Iterations: 3
# Simulation Time: 0.49 s | dt: 0.171 s
#
# Step: Lithiate |   Increment: 8 | Iterations: 3
# Simulation Time: 0.75 s | dt: 0.256 s
#
# Step: Lithiate |   Increment: 9 | Iterations: 3
# Simulation Time: 1.13 s | dt: 0.384 s
#
# Step: Lithiate |   Increment: 10 | Iterations: 3
# Simulation Time: 1.71 s | dt: 0.577 s
#
# Step: Lithiate |   Increment: 11 | Iterations: 3
# Simulation Time: 2.57 s | dt: 0.865 s
#
# Step: Lithiate |   Increment: 12 | Iterations: 3
# Simulation Time: 3.87 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 13 | Iterations: 3
# Simulation Time: 5.17 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 14 | Iterations: 3
# Simulation Time: 6.47 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 15 | Iterations: 3
# Simulation Time: 7.76 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 16 | Iterations: 3
# Simulation Time: 9.06 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 17 | Iterations: 3
# Simulation Time: 10.36 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 18 | Iterations: 3
# Simulation Time: 11.66 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 19 | Iterations: 3
# Simulation Time: 12.95 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 20 | Iterations: 3
# Simulation Time: 14.25 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 21 | Iterations: 3
# Simulation Time: 15.55 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 22 | Iterations: 3
# Simulation Time: 16.85 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 23 | Iterations: 3
# Simulation Time: 18.14 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 24 | Iterations: 3
# Simulation Time: 19.44 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 25 | Iterations: 3
# Simulation Time: 20.74 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 26 | Iterations: 3
# Simulation Time: 22.04 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 27 | Iterations: 3
# Simulation Time: 23.33 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 28 | Iterations: 3
# Simulation Time: 24.63 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 29 | Iterations: 3
# Simulation Time: 25.93 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 30 | Iterations: 3
# Simulation Time: 27.23 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 31 | Iterations: 3
# Simulation Time: 28.52 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 32 | Iterations: 3
# Simulation Time: 29.82 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 33 | Iterations: 3
# Simulation Time: 31.12 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 34 | Iterations: 3
# Simulation Time: 32.42 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 35 | Iterations: 3
# Simulation Time: 33.71 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 36 | Iterations: 3
# Simulation Time: 35.01 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 37 | Iterations: 3
# Simulation Time: 36.31 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 38 | Iterations: 3
# Simulation Time: 37.61 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 39 | Iterations: 3
# Simulation Time: 38.9 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 40 | Iterations: 3
# Simulation Time: 40.2 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 41 | Iterations: 3
# Simulation Time: 41.5 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 42 | Iterations: 3
# Simulation Time: 42.8 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 43 | Iterations: 3
# Simulation Time: 44.09 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 44 | Iterations: 3
# Simulation Time: 45.39 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 45 | Iterations: 3
# Simulation Time: 46.69 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 46 | Iterations: 3
# Simulation Time: 47.99 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 47 | Iterations: 3
# Simulation Time: 49.28 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 48 | Iterations: 3
# Simulation Time: 50.58 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 49 | Iterations: 3
# Simulation Time: 51.88 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 50 | Iterations: 3
# Simulation Time: 53.18 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 51 | Iterations: 3
# Simulation Time: 54.47 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 52 | Iterations: 3
# Simulation Time: 55.77 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 53 | Iterations: 3
# Simulation Time: 57.07 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 54 | Iterations: 3
# Simulation Time: 58.37 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 55 | Iterations: 3
# Simulation Time: 59.66 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 56 | Iterations: 3
# Simulation Time: 60.96 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 57 | Iterations: 3
# Simulation Time: 62.26 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 58 | Iterations: 3
# Simulation Time: 63.56 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 59 | Iterations: 3
# Simulation Time: 64.85 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 60 | Iterations: 3
# Simulation Time: 66.15 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 61 | Iterations: 3
# Simulation Time: 67.45 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 62 | Iterations: 3
# Simulation Time: 68.75 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 63 | Iterations: 3
# Simulation Time: 70.04 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 64 | Iterations: 3
# Simulation Time: 71.34 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 65 | Iterations: 3
# Simulation Time: 72.64 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 66 | Iterations: 3
# Simulation Time: 73.94 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 67 | Iterations: 3
# Simulation Time: 75.23 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 68 | Iterations: 3
# Simulation Time: 76.53 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 69 | Iterations: 3
# Simulation Time: 77.83 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 70 | Iterations: 3
# Simulation Time: 79.13 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 71 | Iterations: 3
# Simulation Time: 80.42 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 72 | Iterations: 3
# Simulation Time: 81.72 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 73 | Iterations: 3
# Simulation Time: 83.02 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 74 | Iterations: 3
# Simulation Time: 84.32 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 75 | Iterations: 3
# Simulation Time: 85.61 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 76 | Iterations: 3
# Simulation Time: 86.91 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 77 | Iterations: 3
# Simulation Time: 88.21 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 78 | Iterations: 3
# Simulation Time: 89.5 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 79 | Iterations: 3
# Simulation Time: 90.8 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 80 | Iterations: 3
# Simulation Time: 92.1 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 81 | Iterations: 3
# Simulation Time: 93.4 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 82 | Iterations: 3
# Simulation Time: 94.69 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 83 | Iterations: 3
# Simulation Time: 95.99 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 84 | Iterations: 3
# Simulation Time: 97.29 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 85 | Iterations: 3
# Simulation Time: 98.59 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 86 | Iterations: 3
# Simulation Time: 99.88 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 87 | Iterations: 3
# Simulation Time: 101.18 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 88 | Iterations: 3
# Simulation Time: 102.48 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 89 | Iterations: 3
# Simulation Time: 103.78 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 90 | Iterations: 3
# Simulation Time: 105.07 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 91 | Iterations: 3
# Simulation Time: 106.37 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 92 | Iterations: 3
# Simulation Time: 107.67 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 93 | Iterations: 3
# Simulation Time: 108.97 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 94 | Iterations: 3
# Simulation Time: 110.26 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 95 | Iterations: 3
# Simulation Time: 111.56 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 96 | Iterations: 3
# Simulation Time: 112.86 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 97 | Iterations: 3
# Simulation Time: 114.16 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 98 | Iterations: 3
# Simulation Time: 115.45 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 99 | Iterations: 3
# Simulation Time: 116.75 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 100 | Iterations: 3
# Simulation Time: 118.05 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 101 | Iterations: 3
# Simulation Time: 119.35 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 102 | Iterations: 3
# Simulation Time: 120.64 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 103 | Iterations: 3
# Simulation Time: 121.94 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 104 | Iterations: 3
# Simulation Time: 123.24 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 105 | Iterations: 3
# Simulation Time: 124.54 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 106 | Iterations: 3
# Simulation Time: 125.83 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 107 | Iterations: 3
# Simulation Time: 127.13 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 108 | Iterations: 3
# Simulation Time: 128.43 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 109 | Iterations: 3
# Simulation Time: 129.73 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 110 | Iterations: 3
# Simulation Time: 131.02 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 111 | Iterations: 3
# Simulation Time: 132.32 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 112 | Iterations: 3
# Simulation Time: 133.62 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 113 | Iterations: 3
# Simulation Time: 134.92 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 114 | Iterations: 3
# Simulation Time: 136.21 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 115 | Iterations: 3
# Simulation Time: 137.51 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 116 | Iterations: 3
# Simulation Time: 138.81 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 117 | Iterations: 3
# Simulation Time: 140.11 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 118 | Iterations: 3
# Simulation Time: 141.4 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 119 | Iterations: 3
# Simulation Time: 142.7 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 120 | Iterations: 3
# Simulation Time: 144.0 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 121 | Iterations: 3
# Simulation Time: 145.3 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 122 | Iterations: 3
# Simulation Time: 146.59 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 123 | Iterations: 3
# Simulation Time: 147.89 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 124 | Iterations: 3
# Simulation Time: 149.19 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 125 | Iterations: 3
# Simulation Time: 150.49 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 126 | Iterations: 3
# Simulation Time: 151.78 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 127 | Iterations: 3
# Simulation Time: 153.08 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 128 | Iterations: 3
# Simulation Time: 154.38 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 129 | Iterations: 3
# Simulation Time: 155.68 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 130 | Iterations: 3
# Simulation Time: 156.97 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 131 | Iterations: 3
# Simulation Time: 158.27 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 132 | Iterations: 3
# Simulation Time: 159.57 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 133 | Iterations: 3
# Simulation Time: 160.87 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 134 | Iterations: 3
# Simulation Time: 162.16 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 135 | Iterations: 3
# Simulation Time: 163.46 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 136 | Iterations: 3
# Simulation Time: 164.76 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 137 | Iterations: 3
# Simulation Time: 166.06 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 138 | Iterations: 3
# Simulation Time: 167.35 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 139 | Iterations: 3
# Simulation Time: 168.65 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 140 | Iterations: 3
# Simulation Time: 169.95 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 141 | Iterations: 3
# Simulation Time: 171.25 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 142 | Iterations: 3
# Simulation Time: 172.54 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 143 | Iterations: 3
# Simulation Time: 173.84 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 144 | Iterations: 3
# Simulation Time: 175.14 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 145 | Iterations: 3
# Simulation Time: 176.44 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 146 | Iterations: 3
# Simulation Time: 177.73 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 147 | Iterations: 3
# Simulation Time: 179.03 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 148 | Iterations: 3
# Simulation Time: 180.33 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 149 | Iterations: 3
# Simulation Time: 181.62 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 150 | Iterations: 3
# Simulation Time: 182.92 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 151 | Iterations: 3
# Simulation Time: 184.22 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 152 | Iterations: 3
# Simulation Time: 185.52 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 153 | Iterations: 3
# Simulation Time: 186.81 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 154 | Iterations: 3
# Simulation Time: 188.11 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 155 | Iterations: 3
# Simulation Time: 189.41 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 156 | Iterations: 3
# Simulation Time: 190.71 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 157 | Iterations: 3
# Simulation Time: 192.0 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 158 | Iterations: 3
# Simulation Time: 193.3 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 159 | Iterations: 3
# Simulation Time: 194.6 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 160 | Iterations: 3
# Simulation Time: 195.9 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 161 | Iterations: 3
# Simulation Time: 197.19 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 162 | Iterations: 3
# Simulation Time: 198.49 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 163 | Iterations: 3
# Simulation Time: 199.79 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 164 | Iterations: 3
# Simulation Time: 201.09 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 165 | Iterations: 3
# Simulation Time: 202.38 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 166 | Iterations: 3
# Simulation Time: 203.68 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 167 | Iterations: 3
# Simulation Time: 204.98 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 168 | Iterations: 3
# Simulation Time: 206.28 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 169 | Iterations: 3
# Simulation Time: 207.57 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 170 | Iterations: 3
# Simulation Time: 208.87 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 171 | Iterations: 3
# Simulation Time: 210.17 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 172 | Iterations: 3
# Simulation Time: 211.47 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 173 | Iterations: 3
# Simulation Time: 212.76 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 174 | Iterations: 3
# Simulation Time: 214.06 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 175 | Iterations: 3
# Simulation Time: 215.36 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 176 | Iterations: 3
# Simulation Time: 216.66 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 177 | Iterations: 3
# Simulation Time: 217.95 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 178 | Iterations: 3
# Simulation Time: 219.25 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 179 | Iterations: 3
# Simulation Time: 220.55 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 180 | Iterations: 3
# Simulation Time: 221.85 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 181 | Iterations: 3
# Simulation Time: 223.14 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 182 | Iterations: 3
# Simulation Time: 224.44 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 183 | Iterations: 3
# Simulation Time: 225.74 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 184 | Iterations: 3
# Simulation Time: 227.04 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 185 | Iterations: 3
# Simulation Time: 228.33 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 186 | Iterations: 3
# Simulation Time: 229.63 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 187 | Iterations: 3
# Simulation Time: 230.93 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 188 | Iterations: 3
# Simulation Time: 232.23 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 189 | Iterations: 3
# Simulation Time: 233.52 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 190 | Iterations: 3
# Simulation Time: 234.82 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 191 | Iterations: 3
# Simulation Time: 236.12 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 192 | Iterations: 3
# Simulation Time: 237.42 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 193 | Iterations: 3
# Simulation Time: 238.71 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 194 | Iterations: 3
# Simulation Time: 240.01 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 195 | Iterations: 3
# Simulation Time: 241.31 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 196 | Iterations: 3
# Simulation Time: 242.61 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 197 | Iterations: 3
# Simulation Time: 243.9 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 198 | Iterations: 3
# Simulation Time: 245.2 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 199 | Iterations: 3
# Simulation Time: 246.5 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 200 | Iterations: 3
# Simulation Time: 247.8 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 201 | Iterations: 3
# Simulation Time: 249.09 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 202 | Iterations: 3
# Simulation Time: 250.39 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 203 | Iterations: 3
# Simulation Time: 251.69 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 204 | Iterations: 3
# Simulation Time: 252.99 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 205 | Iterations: 3
# Simulation Time: 254.28 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 206 | Iterations: 3
# Simulation Time: 255.58 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 207 | Iterations: 3
# Simulation Time: 256.88 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 208 | Iterations: 3
# Simulation Time: 258.18 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 209 | Iterations: 3
# Simulation Time: 259.47 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 210 | Iterations: 3
# Simulation Time: 260.77 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 211 | Iterations: 3
# Simulation Time: 262.07 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 212 | Iterations: 3
# Simulation Time: 263.37 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 213 | Iterations: 3
# Simulation Time: 264.66 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 214 | Iterations: 3
# Simulation Time: 265.96 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 215 | Iterations: 3
# Simulation Time: 267.26 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 216 | Iterations: 3
# Simulation Time: 268.55 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 217 | Iterations: 3
# Simulation Time: 269.85 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 218 | Iterations: 3
# Simulation Time: 271.15 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 219 | Iterations: 3
# Simulation Time: 272.45 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 220 | Iterations: 3
# Simulation Time: 273.74 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 221 | Iterations: 3
# Simulation Time: 275.04 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 222 | Iterations: 3
# Simulation Time: 276.34 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 223 | Iterations: 3
# Simulation Time: 277.64 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 224 | Iterations: 3
# Simulation Time: 278.93 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 225 | Iterations: 3
# Simulation Time: 280.23 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 226 | Iterations: 3
# Simulation Time: 281.53 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 227 | Iterations: 3
# Simulation Time: 282.83 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 228 | Iterations: 3
# Simulation Time: 284.12 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 229 | Iterations: 3
# Simulation Time: 285.42 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 230 | Iterations: 3
# Simulation Time: 286.72 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 231 | Iterations: 3
# Simulation Time: 288.02 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 232 | Iterations: 3
# Simulation Time: 289.31 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 233 | Iterations: 3
# Simulation Time: 290.61 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 234 | Iterations: 3
# Simulation Time: 291.91 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 235 | Iterations: 3
# Simulation Time: 293.21 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 236 | Iterations: 3
# Simulation Time: 294.5 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 237 | Iterations: 3
# Simulation Time: 295.8 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 238 | Iterations: 3
# Simulation Time: 297.1 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 239 | Iterations: 3
# Simulation Time: 298.4 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 240 | Iterations: 3
# Simulation Time: 299.69 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 241 | Iterations: 3
# Simulation Time: 300.99 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 242 | Iterations: 3
# Simulation Time: 302.29 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 243 | Iterations: 3
# Simulation Time: 303.59 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 244 | Iterations: 3
# Simulation Time: 304.88 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 245 | Iterations: 3
# Simulation Time: 306.18 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 246 | Iterations: 3
# Simulation Time: 307.48 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 247 | Iterations: 3
# Simulation Time: 308.78 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 248 | Iterations: 3
# Simulation Time: 310.07 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 249 | Iterations: 3
# Simulation Time: 311.37 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 250 | Iterations: 3
# Simulation Time: 312.67 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 251 | Iterations: 3
# Simulation Time: 313.97 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 252 | Iterations: 3
# Simulation Time: 315.26 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 253 | Iterations: 3
# Simulation Time: 316.56 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 254 | Iterations: 3
# Simulation Time: 317.86 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 255 | Iterations: 3
# Simulation Time: 319.16 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 256 | Iterations: 3
# Simulation Time: 320.45 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 257 | Iterations: 3
# Simulation Time: 321.75 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 258 | Iterations: 3
# Simulation Time: 323.05 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 259 | Iterations: 3
# Simulation Time: 324.35 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 260 | Iterations: 3
# Simulation Time: 325.64 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 261 | Iterations: 3
# Simulation Time: 326.94 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 262 | Iterations: 3
# Simulation Time: 328.24 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 263 | Iterations: 3
# Simulation Time: 329.54 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 264 | Iterations: 3
# Simulation Time: 330.83 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 265 | Iterations: 3
# Simulation Time: 332.13 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 266 | Iterations: 3
# Simulation Time: 333.43 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 267 | Iterations: 3
# Simulation Time: 334.73 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 268 | Iterations: 3
# Simulation Time: 336.02 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 269 | Iterations: 3
# Simulation Time: 337.32 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 270 | Iterations: 3
# Simulation Time: 338.62 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 271 | Iterations: 3
# Simulation Time: 339.92 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 272 | Iterations: 3
# Simulation Time: 341.21 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 273 | Iterations: 3
# Simulation Time: 342.51 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 274 | Iterations: 3
# Simulation Time: 343.81 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 275 | Iterations: 3
# Simulation Time: 345.11 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 276 | Iterations: 3
# Simulation Time: 346.4 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 277 | Iterations: 3
# Simulation Time: 347.7 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 278 | Iterations: 3
# Simulation Time: 349.0 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 279 | Iterations: 3
# Simulation Time: 350.3 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 280 | Iterations: 3
# Simulation Time: 351.59 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 281 | Iterations: 3
# Simulation Time: 352.89 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 282 | Iterations: 3
# Simulation Time: 354.19 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 283 | Iterations: 3
# Simulation Time: 355.48 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 284 | Iterations: 3
# Simulation Time: 356.78 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 285 | Iterations: 3
# Simulation Time: 358.08 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 286 | Iterations: 3
# Simulation Time: 359.38 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 287 | Iterations: 3
# Simulation Time: 360.67 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 288 | Iterations: 3
# Simulation Time: 361.97 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 289 | Iterations: 3
# Simulation Time: 363.27 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 290 | Iterations: 3
# Simulation Time: 364.57 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 291 | Iterations: 3
# Simulation Time: 365.86 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 292 | Iterations: 3
# Simulation Time: 367.16 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 293 | Iterations: 3
# Simulation Time: 368.46 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 294 | Iterations: 3
# Simulation Time: 369.76 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 295 | Iterations: 3
# Simulation Time: 371.05 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 296 | Iterations: 3
# Simulation Time: 372.35 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 297 | Iterations: 3
# Simulation Time: 373.65 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 298 | Iterations: 3
# Simulation Time: 374.95 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 299 | Iterations: 3
# Simulation Time: 376.24 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 300 | Iterations: 3
# Simulation Time: 377.54 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 301 | Iterations: 3
# Simulation Time: 378.84 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 302 | Iterations: 3
# Simulation Time: 380.14 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 303 | Iterations: 3
# Simulation Time: 381.43 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 304 | Iterations: 3
# Simulation Time: 382.73 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 305 | Iterations: 3
# Simulation Time: 384.03 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 306 | Iterations: 3
# Simulation Time: 385.33 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 307 | Iterations: 3
# Simulation Time: 386.62 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 308 | Iterations: 3
# Simulation Time: 387.92 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 309 | Iterations: 3
# Simulation Time: 389.22 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 310 | Iterations: 3
# Simulation Time: 390.52 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 311 | Iterations: 3
# Simulation Time: 391.81 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 312 | Iterations: 3
# Simulation Time: 393.11 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 313 | Iterations: 3
# Simulation Time: 394.41 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 314 | Iterations: 3
# Simulation Time: 395.71 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 315 | Iterations: 3
# Simulation Time: 397.0 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 316 | Iterations: 3
# Simulation Time: 398.3 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 317 | Iterations: 3
# Simulation Time: 399.6 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 318 | Iterations: 3
# Simulation Time: 400.9 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 319 | Iterations: 3
# Simulation Time: 402.19 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 320 | Iterations: 3
# Simulation Time: 403.49 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 321 | Iterations: 3
# Simulation Time: 404.79 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 322 | Iterations: 3
# Simulation Time: 406.09 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 323 | Iterations: 3
# Simulation Time: 407.38 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 324 | Iterations: 3
# Simulation Time: 408.68 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 325 | Iterations: 3
# Simulation Time: 409.98 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 326 | Iterations: 3
# Simulation Time: 411.28 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 327 | Iterations: 3
# Simulation Time: 412.57 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 328 | Iterations: 3
# Simulation Time: 413.87 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 329 | Iterations: 3
# Simulation Time: 415.17 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 330 | Iterations: 3
# Simulation Time: 416.47 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 331 | Iterations: 3
# Simulation Time: 417.76 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 332 | Iterations: 3
# Simulation Time: 419.06 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 333 | Iterations: 3
# Simulation Time: 420.36 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 334 | Iterations: 3
# Simulation Time: 421.66 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 335 | Iterations: 3
# Simulation Time: 422.95 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 336 | Iterations: 3
# Simulation Time: 424.25 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 337 | Iterations: 3
# Simulation Time: 425.55 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 338 | Iterations: 3
# Simulation Time: 426.85 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 339 | Iterations: 3
# Simulation Time: 428.14 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 340 | Iterations: 3
# Simulation Time: 429.44 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 341 | Iterations: 3
# Simulation Time: 430.74 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 342 | Iterations: 3
# Simulation Time: 432.04 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 343 | Iterations: 3
# Simulation Time: 433.33 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 344 | Iterations: 3
# Simulation Time: 434.63 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 345 | Iterations: 3
# Simulation Time: 435.93 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 346 | Iterations: 3
# Simulation Time: 437.23 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 347 | Iterations: 3
# Simulation Time: 438.52 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 348 | Iterations: 3
# Simulation Time: 439.82 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 349 | Iterations: 3
# Simulation Time: 441.12 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 350 | Iterations: 3
# Simulation Time: 442.42 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 351 | Iterations: 3
# Simulation Time: 443.71 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 352 | Iterations: 3
# Simulation Time: 445.01 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 353 | Iterations: 3
# Simulation Time: 446.31 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 354 | Iterations: 3
# Simulation Time: 447.6 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 355 | Iterations: 3
# Simulation Time: 448.9 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 356 | Iterations: 3
# Simulation Time: 450.2 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 357 | Iterations: 3
# Simulation Time: 451.5 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 358 | Iterations: 3
# Simulation Time: 452.79 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 359 | Iterations: 3
# Simulation Time: 454.09 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 360 | Iterations: 3
# Simulation Time: 455.39 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 361 | Iterations: 3
# Simulation Time: 456.69 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 362 | Iterations: 3
# Simulation Time: 457.98 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 363 | Iterations: 3
# Simulation Time: 459.28 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 364 | Iterations: 3
# Simulation Time: 460.58 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 365 | Iterations: 3
# Simulation Time: 461.88 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 366 | Iterations: 3
# Simulation Time: 463.17 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 367 | Iterations: 3
# Simulation Time: 464.47 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 368 | Iterations: 3
# Simulation Time: 465.77 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 369 | Iterations: 3
# Simulation Time: 467.07 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 370 | Iterations: 3
# Simulation Time: 468.36 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 371 | Iterations: 3
# Simulation Time: 469.66 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 372 | Iterations: 3
# Simulation Time: 470.96 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 373 | Iterations: 3
# Simulation Time: 472.26 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 374 | Iterations: 3
# Simulation Time: 473.55 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 375 | Iterations: 3
# Simulation Time: 474.85 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 376 | Iterations: 3
# Simulation Time: 476.15 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 377 | Iterations: 3
# Simulation Time: 477.45 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 378 | Iterations: 3
# Simulation Time: 478.74 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 379 | Iterations: 3
# Simulation Time: 480.04 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 380 | Iterations: 3
# Simulation Time: 481.34 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 381 | Iterations: 3
# Simulation Time: 482.64 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 382 | Iterations: 3
# Simulation Time: 483.93 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 383 | Iterations: 3
# Simulation Time: 485.23 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 384 | Iterations: 3
# Simulation Time: 486.53 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 385 | Iterations: 3
# Simulation Time: 487.83 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 386 | Iterations: 3
# Simulation Time: 489.12 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 387 | Iterations: 3
# Simulation Time: 490.42 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 388 | Iterations: 3
# Simulation Time: 491.72 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 389 | Iterations: 3
# Simulation Time: 493.02 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 390 | Iterations: 3
# Simulation Time: 494.31 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 391 | Iterations: 3
# Simulation Time: 495.61 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 392 | Iterations: 3
# Simulation Time: 496.91 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 393 | Iterations: 3
# Simulation Time: 498.21 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 394 | Iterations: 3
# Simulation Time: 499.5 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 395 | Iterations: 3
# Simulation Time: 500.8 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 396 | Iterations: 3
# Simulation Time: 502.1 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 397 | Iterations: 3
# Simulation Time: 503.4 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 398 | Iterations: 3
# Simulation Time: 504.69 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 399 | Iterations: 3
# Simulation Time: 505.99 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 400 | Iterations: 3
# Simulation Time: 507.29 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 401 | Iterations: 3
# Simulation Time: 508.59 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 402 | Iterations: 3
# Simulation Time: 509.88 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 403 | Iterations: 3
# Simulation Time: 511.18 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 404 | Iterations: 3
# Simulation Time: 512.48 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 405 | Iterations: 3
# Simulation Time: 513.78 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 406 | Iterations: 3
# Simulation Time: 515.07 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 407 | Iterations: 3
# Simulation Time: 516.37 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 408 | Iterations: 3
# Simulation Time: 517.67 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 409 | Iterations: 3
# Simulation Time: 518.97 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 410 | Iterations: 3
# Simulation Time: 520.26 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 411 | Iterations: 3
# Simulation Time: 521.56 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 412 | Iterations: 3
# Simulation Time: 522.86 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 413 | Iterations: 3
# Simulation Time: 524.16 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 414 | Iterations: 3
# Simulation Time: 525.45 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 415 | Iterations: 3
# Simulation Time: 526.75 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 416 | Iterations: 3
# Simulation Time: 528.05 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 417 | Iterations: 3
# Simulation Time: 529.35 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 418 | Iterations: 3
# Simulation Time: 530.64 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 419 | Iterations: 3
# Simulation Time: 531.94 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 420 | Iterations: 3
# Simulation Time: 533.24 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 421 | Iterations: 3
# Simulation Time: 534.53 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 422 | Iterations: 3
# Simulation Time: 535.83 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 423 | Iterations: 3
# Simulation Time: 537.13 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 424 | Iterations: 3
# Simulation Time: 538.43 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 425 | Iterations: 3
# Simulation Time: 539.72 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 426 | Iterations: 3
# Simulation Time: 541.02 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 427 | Iterations: 3
# Simulation Time: 542.32 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 428 | Iterations: 3
# Simulation Time: 543.62 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 429 | Iterations: 3
# Simulation Time: 544.91 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 430 | Iterations: 3
# Simulation Time: 546.21 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 431 | Iterations: 3
# Simulation Time: 547.51 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 432 | Iterations: 3
# Simulation Time: 548.81 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 433 | Iterations: 3
# Simulation Time: 550.1 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 434 | Iterations: 3
# Simulation Time: 551.4 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 435 | Iterations: 3
# Simulation Time: 552.7 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 436 | Iterations: 3
# Simulation Time: 554.0 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 437 | Iterations: 3
# Simulation Time: 555.29 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 438 | Iterations: 3
# Simulation Time: 556.59 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 439 | Iterations: 3
# Simulation Time: 557.89 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 440 | Iterations: 3
# Simulation Time: 559.19 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 441 | Iterations: 3
# Simulation Time: 560.48 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 442 | Iterations: 3
# Simulation Time: 561.78 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 443 | Iterations: 3
# Simulation Time: 563.08 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 444 | Iterations: 3
# Simulation Time: 564.38 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 445 | Iterations: 3
# Simulation Time: 565.67 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 446 | Iterations: 3
# Simulation Time: 566.97 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 447 | Iterations: 3
# Simulation Time: 568.27 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 448 | Iterations: 3
# Simulation Time: 569.57 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 449 | Iterations: 3
# Simulation Time: 570.86 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 450 | Iterations: 3
# Simulation Time: 572.16 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 451 | Iterations: 3
# Simulation Time: 573.46 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 452 | Iterations: 3
# Simulation Time: 574.76 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 453 | Iterations: 3
# Simulation Time: 576.05 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 454 | Iterations: 3
# Simulation Time: 577.35 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 455 | Iterations: 3
# Simulation Time: 578.65 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 456 | Iterations: 3
# Simulation Time: 579.95 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 457 | Iterations: 3
# Simulation Time: 581.24 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 458 | Iterations: 3
# Simulation Time: 582.54 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 459 | Iterations: 3
# Simulation Time: 583.84 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 460 | Iterations: 3
# Simulation Time: 585.14 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 461 | Iterations: 3
# Simulation Time: 586.43 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 462 | Iterations: 3
# Simulation Time: 587.73 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 463 | Iterations: 3
# Simulation Time: 589.03 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 464 | Iterations: 3
# Simulation Time: 590.33 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 465 | Iterations: 3
# Simulation Time: 591.62 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 466 | Iterations: 3
# Simulation Time: 592.92 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 467 | Iterations: 3
# Simulation Time: 594.22 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 468 | Iterations: 3
# Simulation Time: 595.52 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 469 | Iterations: 3
# Simulation Time: 596.81 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 470 | Iterations: 3
# Simulation Time: 598.11 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 471 | Iterations: 3
# Simulation Time: 599.41 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 472 | Iterations: 3
# Simulation Time: 600.71 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 473 | Iterations: 3
# Simulation Time: 602.0 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 474 | Iterations: 3
# Simulation Time: 603.3 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 475 | Iterations: 3
# Simulation Time: 604.6 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 476 | Iterations: 3
# Simulation Time: 605.9 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 477 | Iterations: 3
# Simulation Time: 607.19 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 478 | Iterations: 3
# Simulation Time: 608.49 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 479 | Iterations: 3
# Simulation Time: 609.79 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 480 | Iterations: 3
# Simulation Time: 611.09 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 481 | Iterations: 3
# Simulation Time: 612.38 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 482 | Iterations: 3
# Simulation Time: 613.68 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 483 | Iterations: 3
# Simulation Time: 614.98 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 484 | Iterations: 3
# Simulation Time: 616.28 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 485 | Iterations: 3
# Simulation Time: 617.57 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 486 | Iterations: 3
# Simulation Time: 618.87 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 487 | Iterations: 3
# Simulation Time: 620.17 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 488 | Iterations: 3
# Simulation Time: 621.46 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 489 | Iterations: 3
# Simulation Time: 622.76 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 490 | Iterations: 3
# Simulation Time: 624.06 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 491 | Iterations: 3
# Simulation Time: 625.36 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 492 | Iterations: 3
# Simulation Time: 626.65 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 493 | Iterations: 3
# Simulation Time: 627.95 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 494 | Iterations: 3
# Simulation Time: 629.25 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 495 | Iterations: 3
# Simulation Time: 630.55 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 496 | Iterations: 3
# Simulation Time: 631.84 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 497 | Iterations: 3
# Simulation Time: 633.14 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 498 | Iterations: 3
# Simulation Time: 634.44 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 499 | Iterations: 3
# Simulation Time: 635.74 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 500 | Iterations: 3
# Simulation Time: 637.03 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 501 | Iterations: 3
# Simulation Time: 638.33 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 502 | Iterations: 3
# Simulation Time: 639.63 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 503 | Iterations: 3
# Simulation Time: 640.93 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 504 | Iterations: 3
# Simulation Time: 642.22 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 505 | Iterations: 3
# Simulation Time: 643.52 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 506 | Iterations: 3
# Simulation Time: 644.82 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 507 | Iterations: 3
# Simulation Time: 646.12 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 508 | Iterations: 3
# Simulation Time: 647.41 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 509 | Iterations: 3
# Simulation Time: 648.71 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 510 | Iterations: 3
# Simulation Time: 650.01 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 511 | Iterations: 3
# Simulation Time: 651.31 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 512 | Iterations: 3
# Simulation Time: 652.6 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 513 | Iterations: 3
# Simulation Time: 653.9 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 514 | Iterations: 3
# Simulation Time: 655.2 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 515 | Iterations: 3
# Simulation Time: 656.5 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 516 | Iterations: 3
# Simulation Time: 657.79 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 517 | Iterations: 3
# Simulation Time: 659.09 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 518 | Iterations: 3
# Simulation Time: 660.39 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 519 | Iterations: 3
# Simulation Time: 661.69 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 520 | Iterations: 3
# Simulation Time: 662.98 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 521 | Iterations: 3
# Simulation Time: 664.28 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 522 | Iterations: 3
# Simulation Time: 665.58 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 523 | Iterations: 3
# Simulation Time: 666.88 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 524 | Iterations: 3
# Simulation Time: 668.17 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 525 | Iterations: 3
# Simulation Time: 669.47 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 526 | Iterations: 3
# Simulation Time: 670.77 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 527 | Iterations: 3
# Simulation Time: 672.07 s | dt: 1.297 s
#
# Step: Lithiate |   Increment: 528 | Iterations: 3
# Simulation Time: 673.36 s | dt: 1.297 s
#
# ...
#
# Step: Lithiate |   Increment: 1589 | Iterations: 3
# Simulation Time: 1610.26 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1590 | Iterations: 3
# Simulation Time: 1611.39 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1591 | Iterations: 3
# Simulation Time: 1612.51 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1592 | Iterations: 3
# Simulation Time: 1613.64 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1593 | Iterations: 3
# Simulation Time: 1614.76 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1594 | Iterations: 3
# Simulation Time: 1615.89 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1595 | Iterations: 3
# Simulation Time: 1617.01 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1596 | Iterations: 3
# Simulation Time: 1618.14 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1597 | Iterations: 3
# Simulation Time: 1619.26 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1598 | Iterations: 3
# Simulation Time: 1620.39 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1599 | Iterations: 3
# Simulation Time: 1621.51 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1600 | Iterations: 3
# Simulation Time: 1622.64 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1601 | Iterations: 3
# Simulation Time: 1623.76 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1602 | Iterations: 3
# Simulation Time: 1624.89 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1603 | Iterations: 3
# Simulation Time: 1626.01 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1604 | Iterations: 3
# Simulation Time: 1627.14 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1605 | Iterations: 3
# Simulation Time: 1628.26 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1606 | Iterations: 3
# Simulation Time: 1629.39 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1607 | Iterations: 3
# Simulation Time: 1630.51 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1608 | Iterations: 3
# Simulation Time: 1631.63 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1609 | Iterations: 3
# Simulation Time: 1632.76 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1610 | Iterations: 3
# Simulation Time: 1633.88 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1611 | Iterations: 3
# Simulation Time: 1635.01 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1612 | Iterations: 3
# Simulation Time: 1636.13 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1613 | Iterations: 3
# Simulation Time: 1637.26 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1614 | Iterations: 3
# Simulation Time: 1638.38 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1615 | Iterations: 3
# Simulation Time: 1639.51 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1616 | Iterations: 3
# Simulation Time: 1640.63 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1617 | Iterations: 3
# Simulation Time: 1641.76 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1618 | Iterations: 3
# Simulation Time: 1642.88 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1619 | Iterations: 3
# Simulation Time: 1644.01 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1620 | Iterations: 3
# Simulation Time: 1645.13 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1621 | Iterations: 3
# Simulation Time: 1646.26 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1622 | Iterations: 3
# Simulation Time: 1647.38 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1623 | Iterations: 3
# Simulation Time: 1648.51 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1624 | Iterations: 3
# Simulation Time: 1649.63 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1625 | Iterations: 3
# Simulation Time: 1650.76 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1626 | Iterations: 3
# Simulation Time: 1651.88 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1627 | Iterations: 3
# Simulation Time: 1653.01 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1628 | Iterations: 3
# Simulation Time: 1654.13 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1629 | Iterations: 3
# Simulation Time: 1655.26 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1630 | Iterations: 3
# Simulation Time: 1656.38 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1631 | Iterations: 3
# Simulation Time: 1657.51 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1632 | Iterations: 3
# Simulation Time: 1658.63 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1633 | Iterations: 3
# Simulation Time: 1659.76 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1634 | Iterations: 3
# Simulation Time: 1660.88 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1635 | Iterations: 3
# Simulation Time: 1662.0 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1636 | Iterations: 3
# Simulation Time: 1663.13 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1637 | Iterations: 3
# Simulation Time: 1664.25 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1638 | Iterations: 3
# Simulation Time: 1665.38 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1639 | Iterations: 3
# Simulation Time: 1666.5 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1640 | Iterations: 3
# Simulation Time: 1667.63 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1641 | Iterations: 3
# Simulation Time: 1668.75 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1642 | Iterations: 3
# Simulation Time: 1669.88 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1643 | Iterations: 3
# Simulation Time: 1671.0 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1644 | Iterations: 3
# Simulation Time: 1672.13 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1645 | Iterations: 3
# Simulation Time: 1673.25 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1646 | Iterations: 3
# Simulation Time: 1674.38 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1647 | Iterations: 3
# Simulation Time: 1675.5 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1648 | Iterations: 3
# Simulation Time: 1676.63 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1649 | Iterations: 3
# Simulation Time: 1677.75 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1650 | Iterations: 3
# Simulation Time: 1678.88 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1651 | Iterations: 3
# Simulation Time: 1680.0 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1652 | Iterations: 3
# Simulation Time: 1681.13 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1653 | Iterations: 3
# Simulation Time: 1682.25 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1654 | Iterations: 3
# Simulation Time: 1683.38 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1655 | Iterations: 3
# Simulation Time: 1684.5 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1656 | Iterations: 3
# Simulation Time: 1685.63 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1657 | Iterations: 3
# Simulation Time: 1686.75 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1658 | Iterations: 3
# Simulation Time: 1687.88 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1659 | Iterations: 3
# Simulation Time: 1689.0 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1660 | Iterations: 3
# Simulation Time: 1690.12 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1661 | Iterations: 3
# Simulation Time: 1691.25 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1662 | Iterations: 3
# Simulation Time: 1692.37 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1663 | Iterations: 3
# Simulation Time: 1693.5 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1664 | Iterations: 3
# Simulation Time: 1694.62 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1665 | Iterations: 3
# Simulation Time: 1695.75 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1666 | Iterations: 3
# Simulation Time: 1696.87 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1667 | Iterations: 3
# Simulation Time: 1698.0 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1668 | Iterations: 3
# Simulation Time: 1699.12 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1669 | Iterations: 3
# Simulation Time: 1700.25 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1670 | Iterations: 3
# Simulation Time: 1701.37 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1671 | Iterations: 3
# Simulation Time: 1702.5 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1672 | Iterations: 3
# Simulation Time: 1703.62 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1673 | Iterations: 3
# Simulation Time: 1704.75 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1674 | Iterations: 3
# Simulation Time: 1705.87 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1675 | Iterations: 3
# Simulation Time: 1707.0 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1676 | Iterations: 3
# Simulation Time: 1708.12 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1677 | Iterations: 3
# Simulation Time: 1709.25 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1678 | Iterations: 3
# Simulation Time: 1710.37 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1679 | Iterations: 3
# Simulation Time: 1711.5 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1680 | Iterations: 3
# Simulation Time: 1712.62 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1681 | Iterations: 3
# Simulation Time: 1713.75 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1682 | Iterations: 3
# Simulation Time: 1714.87 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1683 | Iterations: 3
# Simulation Time: 1716.0 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1684 | Iterations: 3
# Simulation Time: 1717.12 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1685 | Iterations: 3
# Simulation Time: 1718.25 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1686 | Iterations: 3
# Simulation Time: 1719.37 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1687 | Iterations: 3
# Simulation Time: 1720.49 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1688 | Iterations: 3
# Simulation Time: 1721.62 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1689 | Iterations: 3
# Simulation Time: 1722.74 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1690 | Iterations: 3
# Simulation Time: 1723.87 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1691 | Iterations: 3
# Simulation Time: 1724.99 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1692 | Iterations: 3
# Simulation Time: 1726.12 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1693 | Iterations: 3
# Simulation Time: 1727.24 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1694 | Iterations: 3
# Simulation Time: 1728.37 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1695 | Iterations: 3
# Simulation Time: 1729.49 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1696 | Iterations: 3
# Simulation Time: 1730.62 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1697 | Iterations: 3
# Simulation Time: 1731.74 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1698 | Iterations: 3
# Simulation Time: 1732.87 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1699 | Iterations: 3
# Simulation Time: 1733.99 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1700 | Iterations: 3
# Simulation Time: 1735.12 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1701 | Iterations: 3
# Simulation Time: 1736.24 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1702 | Iterations: 3
# Simulation Time: 1737.37 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1703 | Iterations: 3
# Simulation Time: 1738.49 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1704 | Iterations: 3
# Simulation Time: 1739.62 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1705 | Iterations: 3
# Simulation Time: 1740.74 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1706 | Iterations: 3
# Simulation Time: 1741.87 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1707 | Iterations: 3
# Simulation Time: 1742.99 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1708 | Iterations: 3
# Simulation Time: 1744.12 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1709 | Iterations: 3
# Simulation Time: 1745.24 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1710 | Iterations: 3
# Simulation Time: 1746.37 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1711 | Iterations: 3
# Simulation Time: 1747.49 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1712 | Iterations: 3
# Simulation Time: 1748.62 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1713 | Iterations: 3
# Simulation Time: 1749.74 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1714 | Iterations: 3
# Simulation Time: 1750.86 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1715 | Iterations: 3
# Simulation Time: 1751.99 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1716 | Iterations: 3
# Simulation Time: 1753.11 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1717 | Iterations: 3
# Simulation Time: 1754.24 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1718 | Iterations: 3
# Simulation Time: 1755.36 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1719 | Iterations: 3
# Simulation Time: 1756.49 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1720 | Iterations: 3
# Simulation Time: 1757.61 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1721 | Iterations: 3
# Simulation Time: 1758.74 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1722 | Iterations: 3
# Simulation Time: 1759.86 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1723 | Iterations: 3
# Simulation Time: 1760.99 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1724 | Iterations: 3
# Simulation Time: 1762.11 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1725 | Iterations: 3
# Simulation Time: 1763.24 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1726 | Iterations: 3
# Simulation Time: 1764.36 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1727 | Iterations: 3
# Simulation Time: 1765.49 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1728 | Iterations: 3
# Simulation Time: 1766.61 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1729 | Iterations: 3
# Simulation Time: 1767.74 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1730 | Iterations: 3
# Simulation Time: 1768.86 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1731 | Iterations: 3
# Simulation Time: 1769.99 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1732 | Iterations: 3
# Simulation Time: 1771.11 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1733 | Iterations: 3
# Simulation Time: 1772.24 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1734 | Iterations: 3
# Simulation Time: 1773.36 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1735 | Iterations: 3
# Simulation Time: 1774.49 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1736 | Iterations: 3
# Simulation Time: 1775.61 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1737 | Iterations: 3
# Simulation Time: 1776.74 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1738 | Iterations: 3
# Simulation Time: 1777.86 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1739 | Iterations: 3
# Simulation Time: 1778.98 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1740 | Iterations: 3
# Simulation Time: 1780.11 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1741 | Iterations: 3
# Simulation Time: 1781.23 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1742 | Iterations: 3
# Simulation Time: 1782.36 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1743 | Iterations: 3
# Simulation Time: 1783.48 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1744 | Iterations: 3
# Simulation Time: 1784.61 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1745 | Iterations: 3
# Simulation Time: 1785.73 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1746 | Iterations: 3
# Simulation Time: 1786.86 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1747 | Iterations: 3
# Simulation Time: 1787.98 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1748 | Iterations: 3
# Simulation Time: 1789.11 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1749 | Iterations: 3
# Simulation Time: 1790.23 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1750 | Iterations: 3
# Simulation Time: 1791.36 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1751 | Iterations: 3
# Simulation Time: 1792.48 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1752 | Iterations: 3
# Simulation Time: 1793.61 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1753 | Iterations: 3
# Simulation Time: 1794.73 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1754 | Iterations: 3
# Simulation Time: 1795.86 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1755 | Iterations: 3
# Simulation Time: 1796.98 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1756 | Iterations: 3
# Simulation Time: 1798.11 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1757 | Iterations: 3
# Simulation Time: 1799.23 s | dt: 1.125 s
#
# Step: Lithiate |   Increment: 1758 | Iterations: 3
# Simulation Time: 1800.36 s | dt: 1.125 s
#
# -----------------------------------------
# End computation
# ------------------------------------------
# Elapsed real time:  0:06:45.572384
# ------------------------------------------
