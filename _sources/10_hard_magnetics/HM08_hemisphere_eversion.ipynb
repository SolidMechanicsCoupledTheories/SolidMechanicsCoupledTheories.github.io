# %% [markdown]
# # Hemisphere eversion snap-through
#
# - Dynamic snap-through of a hemispherical shell.
# - Since this simulation can take a long time to complete, we have also provided a python script version of the simulation which is meant to be run with MPI parallelization. To run this script in parallel on e.g. four cores use the following command syntax in the terminal:
#
# ```
# mpirun -n 4 python3 HM08_hemisphere_eversion_mpi.py
# ```

# %% [markdown]
# # Units
#
# - Basic units:
#     - Length: mm
#     - Time: s
#     - Mass: kg
#     - Charge: kC
#
#
# - Derived units:
#     - Force: mN
#     - Pressure: kPa
#     - Current: kA
#     - Mag. flux density: mT
#
#
# In the collection "Example Codes for Coupled Theories in Solid Mechanics,"
#
# By Eric M. Stewart, Shawn A. Chester, and Lallit Anand.
#
# https://solidmechanicscoupledtheories.github.io/

# %% [markdown]
# # Import modules

# %%
# Import FEnicSx/dolfinx
import dolfinx

# For numerical arrays
import numpy as np

# For MPI-based parallelization
from mpi4py import MPI
comm = MPI.COMM_WORLD
rank = comm.Get_rank()

# PETSc solvers
from petsc4py import PETSc

# specific functions from dolfinx modules
from dolfinx import fem, mesh, io, plot, log
from dolfinx.fem import (Constant, dirichletbc, Function, functionspace, Expression )
from dolfinx.fem.petsc import NonlinearProblem
from dolfinx.nls.petsc import NewtonSolver
from dolfinx.io import VTXWriter, XDMFFile


# specific functions from ufl modules
import ufl
from ufl import (TestFunctions, TrialFunction, Identity, grad, det, div, dev, inv, tr, sqrt, conditional ,\
                 gt, dx, inner, derivative, dot, ln, split, outer, cos, acos, lt, eq, ge, le)

# basix finite elements
import basix
from basix.ufl import element, mixed_element, quadrature_element

# Matplotlib for plotting
import matplotlib.pyplot as plt
plt.close('all')

# For timing the code
from datetime import datetime


# Set level of detail for log messages (integer)
# Guide:
# CRITICAL  = 50, // errors that may lead to data corruption
# ERROR     = 40, // things that HAVE gone wrong
# WARNING   = 30, // things that MAY go wrong later
# INFO      = 20, // information of general interest (includes solver info)
# PROGRESS  = 16, // what's happening (broadly)
# TRACE     = 13, // what's happening (in detail)
# DBG       = 10  // sundry
#
log.set_log_level(log.LogLevel.WARNING)

# %% [markdown]
# # Define geometry

# %%
# Overall dimensions of the device
scaleX = 30.0 # Radius of outer flange
scaleY = 18.0 # Radius of hemispherical shell itself

# Pull in the mesh *.xdmf file and read any named domains in the mesh.
with XDMFFile(MPI.COMM_WORLD,"meshes/hemisphere_fine.xdmf",'r') as infile:
    domain = infile.read_mesh(name="Grid")
    
# Create facet to cell connectivity required to determine boundary facets.
domain.topology.create_connectivity(domain.topology.dim, domain.topology.dim-1)
    
# This says "spatial coordinates" but is really the referential coordinates,
# since the mesh does not convect in FEniCS.
x = ufl.SpatialCoordinate(domain)

# %% [markdown]
# **Identify boundaries of the domain**

# %%
# For identifying the facets, we want to be able to set tolerances based on the minimum element size in the mesh.
#
# First, determine the minimum element size hmin:
tdim = domain.topology.dim
num_cells = domain.topology.index_map(tdim).size_local
hmin = domain.comm.allreduce(min(domain.h(tdim, np.array(range(num_cells)))), op=MPI.MIN) 
#
# Now, set a tolerance 1/10 as wide as the smallest element in the mesh,
# So that e.g. the outer circular facet is always within tol of the radius,
# regardless of the effects of mesh discretization.
tol = 0.1*hmin

# %%
# Identify the outer edge circular surface
#
def OuterEdge(x):
    return np.isclose( np.sqrt(x[0]*x[0] + x[2]*x[2]), scaleX, atol=tol)
    
# Mark the sub-domain
boundaries = [(1, OuterEdge)]

# build collections of facets on each subdomain and mark them appropriately.
facet_indices, facet_markers = [], [] # initalize empty collections of indices and markers.
fdim = domain.topology.dim - 1 # geometric dimension of the facet (mesh dimension - 1)
for (marker, locator) in boundaries:
    facets = mesh.locate_entities(domain, fdim, locator) # an array of all the facets in a 
                                                         # given subdomain ("locator")
    facet_indices.append(facets)                         # add these facets to the collection.
    facet_markers.append(np.full_like(facets, marker))   # mark them with the appropriate index.

# Format the facet indices and markers as required for use in dolfinx.
facet_indices = np.hstack(facet_indices).astype(np.int32)
facet_markers = np.hstack(facet_markers).astype(np.int32)
sorted_facets = np.argsort(facet_indices)
# 
# Add these marked facets as "mesh tags" for later use in BCs.
facet_tags = mesh.meshtags(domain, fdim, facet_indices[sorted_facets], facet_markers[sorted_facets])

# %% [markdown]
# **Print out the unique facet index numbers**

# %%
top_imap = domain.topology.index_map(2)      # index map of 2D entities in domain (facets)
values = np.zeros(top_imap.size_global)      # an array of zeros of the same size as number of 2D entities
values[facet_tags.indices]=facet_tags.values # populating the array with facet tag index numbers
print(np.unique(facet_tags.values))          # printing the unique indices
# Out:
# [1]

# %% [markdown]
# **Visualize reference configuration and boundary facets**

# %%
import pyvista
pyvista.set_jupyter_backend('html')
from dolfinx.plot import vtk_mesh
pyvista.start_xvfb()

# initialize a plotter
plotter = pyvista.Plotter()

# Add the mesh -- I make the 3D mesh opaque, so that 2D surfaces stand out.
topology, cell_types, geometry = plot.vtk_mesh(domain, domain.topology.dim)
grid = pyvista.UnstructuredGrid(topology, cell_types, geometry)
plotter.add_mesh(grid, show_edges=True, opacity=0.5) 

# Add colored 2D surfaces for the named surfaces
outer_surf = pyvista.UnstructuredGrid(*vtk_mesh(domain, domain.topology.dim-1,facet_tags.indices[facet_tags.values==1]) )
#
actor = plotter.add_mesh(outer_surf, show_edges=True,color="red") # outer surface is red

labels = dict(zlabel='Z', xlabel='X', ylabel='Y')
plotter.add_axes(**labels)

plotter.screenshot("results/mesh.png")

from IPython.display import Image
Image(filename='results/mesh.png') 

# if not pyvista.OFF_SCREEN:
#     plotter.show()
# else:
#     plotter.screenshot("mesh.png")

# %% [markdown]
# ## Define boundary and volume integration measure

# %%
# Define the boundary integration measure "ds" using the facet tags,
# also specify the number of surface quadrature points.
ds = ufl.Measure('ds', domain=domain, subdomain_data=facet_tags, metadata={'quadrature_degree':2})

# Define the volume integration measure "dx" 
# also specify the number of volume quadrature points.
dx = ufl.Measure('dx', domain=domain, metadata={'quadrature_degree': 2})

#  Define facet normal
n = ufl.FacetNormal(domain)

# %% [markdown]
# # Material parameters

# %%
# Neo-Hookean elasticity
Gshear0 = Constant(domain, PETSc.ScalarType(150.0)) # kPa
Kbulk   = Constant(domain, PETSc.ScalarType(1e3*Gshear0)) # Nearly-incompressible

# Mass density
rho = Constant(domain, PETSc.ScalarType(2.00e-6)) # 2.00e3 kg/m^3 = 2.00e-6 kg/mm^3

# alpha-method parameters
alpha   = Constant(domain, PETSc.ScalarType(0.0))
gamma   = Constant(domain, PETSc.ScalarType(0.5+alpha))
beta    = Constant(domain, PETSc.ScalarType(0.25*(gamma+0.5)**2))

# Visco dissipation switch, 0=dissipative,  1=~lossless
disableDissipation = Constant(domain, PETSc.ScalarType(0.0))
#
# When enabled, this switch sets the relaxation times arbitrarily high, 
# so that the stiffness remains the same but no energy is dissipated 
# because the tensor variables A_i are constant.

# Viscoelasticity parameters
#
Gneq_1  = Constant(domain, PETSc.ScalarType(100.0))    #  Non-equilibrium shear modulus, kPa
tau_1   = Constant(domain, PETSc.ScalarType(0.010))    #  relaxation time, s

# Set relaxation times arbitrarily high if visco dissipation is off
tau_1 = tau_1 + disableDissipation/3e-12

# Vacuum permeability
mu0 = Constant(domain, PETSc.ScalarType(1.256e-6*1e9)) # mN / mA^2

# Remanent magnetic flux density magnitude
b_rem_mag = 80.0*mu0/1e3 # 80 kA/m converted to mT

# Need some extra infrastructure for the spatially-discontinuous material property fields
U0 = element("DG", domain.basix_cell(), 0, shape=(3,))   # For remanent magnetization vector
V0 = functionspace(domain, U0) # create a vector DG0 function space on the domain
#
b_rem = Function(V0) # define a magnetization vector which lives on this function space.

# A function for constructing the desired magnetization distribution:
#
# To use the interpolate() feature, this must be defined as a 
# function of x.
def magnetization(x):
    values = np.zeros((domain.geometry.dim,
                      x.shape[1]), dtype=np.float64)
    #
    # Set vertical magnetization for regions with r < scaleY
    # (everywhere else will have 0)
    values[1, :] = 0
    values[1, ( np.sqrt(x[0]**2 + x[2]**2) < scaleY + 0.75 ) ] = b_rem_mag
    #   
    values[0, :] = 0
    values[2, :] = 0
    #
    return values
        
# interpolate the magnetization distribution onto b_rem
b_rem.interpolate(magnetization)

# %% [markdown]
# ## Showing the material properties in a plotter

# %%
# Prepare the magnetization field for plotting
Up = element("Lagrange", domain.basix_cell(), 1, shape=(3,))  # For visualizing the remanent magnetization vector
Vp = functionspace(domain, Up) # create a vector DG1 function space on the domain
vtkdata = vtk_mesh(Vp)  
grid = pyvista.UnstructuredGrid(*vtkdata)
# 
# Need to interpolate the DG0 b_rem into a DG1 b_rem_temp
# so that Pyvista can visualize it
# (Pyvista is allergic to 0'th order spaces)
b_rem_temp = Function(Vp)
b_rem_expr = Expression(b_rem, Vp.element.interpolation_points())
b_rem_temp.interpolate(b_rem_expr)
#
# Now some data formatting:
num_nodes       = b_rem_temp.function_space.dofmap.index_map.size_global # get the number of nodes on the visualization function space.
b_rem_plot_data = np.reshape(b_rem_temp.x.array[:], (num_nodes, 3)) # reshape the b_rem array into the shape Pyvista expects.

# %%
pyvista.set_jupyter_backend('html')
pyvista.start_xvfb()

# initialize a plotter
plotter = pyvista.Plotter()

# Add the mesh -- I make the 3D mesh opaque, so that 2D surfaces stand out.
topology, cell_types, geometry = plot.vtk_mesh(domain, domain.topology.dim)
grid_msh = pyvista.UnstructuredGrid(topology, cell_types, geometry)
plotter.add_mesh(grid_msh, show_edges=True, opacity=0.75) 

# set up another grid for the vector space
vtkdata = vtk_mesh(Vp)  
grid = pyvista.UnstructuredGrid(*vtkdata)

# Add the b_rem data.
grid["b_rem"] = b_rem_plot_data
#
# Set the b_rem item as the active field to plot.
grid.set_active_vectors("b_rem")

# Add the arrow plot.
mag_arrow = grid.glyph(orient="b_rem", factor=0.05)
actor = plotter.add_mesh(mag_arrow, color="red") # plot magnetization values.

labels = dict(zlabel='Z', xlabel='X', ylabel='Y')
plotter.add_axes(**labels)

plotter.screenshot("results/magnetization.png")

from IPython.display import Image
Image(filename='results/magnetization.png') 

# if not pyvista.OFF_SCREEN:
#    plotter.show()
# else:
#    plotter.screenshot("magnetization.png")

# %% [markdown]
# # Simulation time-control related params

# %%
#Simulation time related params
t = 0.0         # initialization of time  
# total simulation time 
step_time = 0.5 # s
# Float value of time step
dt = 0.003/100 # time step size, seconds
# Compiler variable for time step
dk = Constant(domain, PETSc.ScalarType(dt)) # UFL Constant for the time step, used in time integration.

# Max applied magnetic flux density magnitude
b_app_max = 200
angle_imperf = -1.0*np.pi/180 # imperfection in degrees, converted to radians

# expression for ramping up the b-field
def bRamp(t):
    value = b_app_max
    if t>0.1:
        value = 0.0 # turn off b-field from 0.1 s to 0.2 s
        if t>0.2:
            value = -0.4*b_app_max # reverse b-field after 0.2 s
            if t>0.3:
                value = 0.0 # turn off b-field again after 0.3 s
    return value

# Create a constant for the applied magnetic field
bRampCons = Constant(domain,PETSc.ScalarType(bRamp(0)))

# Vector form of the applied b-field:
#
# Apply imperfection angle
x_mag = np.sin(angle_imperf)
y_mag = np.cos(angle_imperf)
z_mag = 0.0

# The applied field vector:
b_app = ufl.as_vector([-x_mag*bRampCons, -y_mag*bRampCons, 0.0])

# %% [markdown]
# # Function spaces

# %%
# Define desired element types, for scalar vector and tensor functions.
U2 = element("Lagrange", domain.basix_cell(), 2, shape=(3,)) # For displacement
P1 = element("Lagrange", domain.basix_cell(), 1)  # For  pressure  
P0 = quadrature_element(domain.basix_cell(), degree=2, scheme="default") 
# Note: it seems that for the current version of dolfinx, 
# only degree=2 quadrature elements actually function properly 
# for e.g. problem solution and interpolation.
T0 = basix.ufl.blocked_element(P0, shape=(3, 3)) # for A tensors                              

# Set up the mixed function space of degrees of freedom (u,p)
TH = mixed_element([U2, P1])     # Taylor-Hood style mixed element
ME = functionspace(domain, TH)    # Total space for all DOFs

# Define actual functions with the required DOFs
w    = Function(ME)
u, p = split(w)  # displacement u, pressure p

# A copy of functions to store values in the previous step
w_old         = Function(ME)
u_old,  p_old = split(w_old)   

# Define test functions        
u_test, p_test = TestFunctions(ME)    

# Define trial functions needed for automatic differentiation
dw = TrialFunction(ME)   

#  Define vector spaces for storing old values of velocity and acceleration
W2 = functionspace(domain, U2)  # Vector space  

# Functions for storing the velocity and acceleration at prev. step
v_old = Function(W2)
a_old = Function(W2)

# Set up Cv tensor as an internal variable 
#
V3     = functionspace(domain, T0) # Tensor function space
Cv_old = Function(V3)              # initialize the Cv_old tensor

# %% [markdown]
# # Initial conditions
#
# - The initial conditions for degrees of freedom $\mathbf{u}$,  $\mathbf{v}$, $\mathbf{a}$, and $p$ are zero everywhere
# - These are imposed automatically, since we have not specified any non-zero initial conditions.
# - We do, however, need to impose the initial condition that $\mathbf{C}^v = \mathbf{1}$. This is done below.

# %%
# A function for constructing the identity matrix:
#
# To use the interpolate() feature, this must be defined as a 
# function of x.
def identity(x):
    values = np.zeros((domain.geometry.dim*domain.geometry.dim,
                      x.shape[1]), dtype=np.float64)
    values[0] = 1
    values[4] = 1
    values[8] = 1 
    return values

# interpolate the identity onto the tensor-valued Cv function.
Cv_old.interpolate(identity)  

# At each time step, the current Cv tensor will be calculated as a function of Cv_old and 
# other kinematical quantities which are known.

# %% [markdown]
# # Subroutines for kinematics and constitutive equations

# %%
# Deformation gradient 
def F_calc(u):
    Id = Identity(3) 
    F  = Id + grad(u)
    return F

def lambdaBar_calc(u):
    F = F_calc(u)
    C = F.T*F
    Cdis = J**(-2/3)*C
    I1 = tr(Cdis)
    lambdaBar = sqrt(I1/3.0)
    return lambdaBar

def safe_sqrt(x):
    return sqrt(x + 1.0e-16)

#----------------------------------------------------------------------------------------------------
# Subroutine for computing the eigenvalues of a tensor A.
#
# Modeled after Ang et al., 2022. Cf. e.g.:
# https://github.com/idaang267/StabilizedPhaseFieldFracture/blob/main/Code/3D-hybrid-stabilized.py
#----------------------------------------------------------------------------------------------------
def eigenvalues(A):

    # Define identity tensor
    Id = Identity(3)
    
    # Invariants
    I1 = tr(A)
    I2 = ((tr(A))**2-tr(A*A))/2.
    I3 = det(A) # I2 and I3 are not actually used anywhere, but 
                          # are left here for completeness.

    # Define some parameters for the eigenvalues
    d_par = I1/3.
    e_par = safe_sqrt( tr( (A-d_par*Id)*(A-d_par*Id) ) /6. )
    
    # conditional for case of a spherical tensor, 
    # which has all eigenvalues equal.
    #
    zero = 0*Id
    f_par_expr = (1./e_par)*(A-d_par*Id)
    #
    # if e_par=0, f_par = zero tensor, otherwise f_par = (1./e_par)*(A-d_par*Id).
    f_par = conditional(eq(e_par, 0), zero, f_par_expr)

    # g_par is the argument of ’acos’. 
    g_par0 = det(f_par)/2.
    
    # must bound the argument of 'acos' both from above and from below.
    # This accounts for the cases of multiplicity 2.
    #
    tol = 3.e-16 # numerical "epsilon" tolerance for the bounds, same as DOLFIN_EPS
    #
    # First, if g_par0 = 1 subtract the tolerance so that g_par1 < 1.
    g_par1 = conditional(ge(g_par0, 1.-tol), 1.-tol, g_par0)
    #
    # Then, if g_par1 = -1 add the tolerance so that g_par > -1.
    g_par = conditional(le(g_par1, -1.+tol), -1.+tol, g_par1)

    # carry out the arccos operation.
    h_par = acos(g_par)/3.
    
    # Compute the eigenvalues of A such that lmbda1s >= lmbda2s >= lmbda3s
    lmbda3s = d_par + 2.*e_par*cos(h_par + 2.*np.pi/3.)
    lmbda2s = d_par + 2.*e_par*cos(h_par + 4.*np.pi/3.)
    lmbda1s = d_par + 2.*e_par*cos(h_par + 6.*np.pi/3.)
    
    # return an ordered vector of eigenvalues
    return lmbda1s, lmbda2s, lmbda3s

#--------------------------------------------------------------------------------------------
# Subroutine for the right polar decomposition.
# 
# We compute U and R using the methods of Hoger and Carlson (1984) for computing U^{-1}.
#--------------------------------------------------------------------------------------------
def right_decomp(F):
    # Identity tensor.
    Id = Identity(3)

    # invariants of C.
    C = F.T*F
    #
    I1C = tr(C)
    I2C = (1/2)*(tr(C)**2 - tr(C*C))
    I3C = det(C)

    # Compute the maximum eigenvalue of U, using the fact that C = U^2.
    #
    lam1, lam2, lam3 = eigenvalues(C) # get the ordered eigenvalues of C, lam1 > lam2 > lam3.
    #
    lambdaU = safe_sqrt(lam1) # the eigenvalues of U are the sqrt of the eigenvalues of C.
    
    # U invariants:
    I3U = safe_sqrt(I3C)
    I2U = safe_sqrt(I3C)/lambdaU + safe_sqrt(I1C*(lambdaU**2) - lambdaU**4 + 2*safe_sqrt(I3C)*lambdaU)
    I1U = lambdaU + safe_sqrt(I1C - lambdaU**2 + 2*safe_sqrt(I3C)/lambdaU )
    
    # intermediate quantity \Delta:
    deltaU = I1U*I2U - I3U
    
    # final expression for U^{-1} tensor:
    Uinv = ((I3U*deltaU)**(-1))*( \
                    + (I1U)*(C*C) \
                    - ( I3U + I1U**3 - 2*I1U*I2U)*C \
                    + (I1U*(I2U**2)  - I3U*(I1U**2) - I3U*I2U)*Id )
    
    # Finally, compute U and R:
    R = F*Uinv
    U = R.T*F

    return R, U

#------------------------------------------------------------- 
# Subroutines for computing the viscous flow update
#-------------------------------------------------------------

# subroutine for the distortional part / unimodular part of a tensor A
def dist_part(A):

    Abar = A / (det(A)**(1.0/3.0))

    return Abar

# Subroutine for computing the viscous stretch Cv at the end of the step.
def Cv_update(u, Cv_old, tau_r):
    
   F = F_calc(u)
   
   J = det(F)
   
   C = F.T*F
   
   Cv_new = dist_part( Cv_old + ( dk / tau_r ) * J**(-2./3.) * C ) 
    
   return Cv_new


#----------------------------------------------
# Subroutine for calculating the Piola stress
#----------------------------------------------

# Subroutine for the non-equilibrium Cauchy stress.
def T_neq_calc(u, Cv, Gneq):
        
    F  = F_calc(u)
    
    J = det(F)
    
    C = F.T*F
    
    T_neq = J**(-5./3.) * Gneq * (F * inv(Cv) * F.T - (1./3.) * inner(C, inv(Cv)) * Identity(3) ) 
    
    return T_neq
    
    
def Piola_calc(F, R, U, p, b_app, Cv):
    
    Id = Identity(3)
    
    J = det(F)
    C = F.T*F
    Cdis = J**(-2/3)*C
     
    # Calculate the derivative dRdF after Chen and Wheeler (1992)
    #
    Y = tr(U)*Id - U # helper tensor Y 
    #
    Lmat = -outer(b_app, b_rem)/mu0 # dRdF will act on this tensor
    #
    # For the R-based mapping, use the following line:
    T_mag = R*Y*(R.T*Lmat - Lmat.T*R)*Y/det(Y)
    #
    # If using the F-based mapping, the following line is the magnetic 
    #  contribution to the Piola stress:
    #T_mag = -outer(b_app, m_rem)
    
    # The viscous Piola stress
    #
    T_visc = T_neq_calc(u, Cv, Gneq_1)
    
    # Piola stress
    Tmat = J**(-2/3)*Gshear0*(F - 1/3*tr(C)*inv(F.T)) \
        + J*p*inv(F.T) + T_mag + J*T_visc*inv(F.T)
    
    return Tmat

#---------------------------------------------------------------------
# Subroutine for updating  acceleration using the Newmark beta method:
# a = 1/(2*beta)*((u - u0 - v0*dt)/(0.5*dt*dt) - (1-2*beta)*a0)
#---------------------------------------------------------------------
def update_a(u, u_old, v_old, a_old):
    return (u-u_old-dk*v_old)/beta/dk**2 - (1-2*beta)/2/beta*a_old

#---------------------------------------------------------------------
# Subroutine for updating  velocity using the Newmark beta method
# v = dt * ((1-gamma)*a0 + gamma*a) + v0
#---------------------------------------------------------------------
def update_v(a, u_old, v_old, a_old):
    return v_old + dk*((1-gamma)*a_old + gamma*a)

#---------------------------------------------------------------------
# alpha-method averaging function
#---------------------------------------------------------------------
def avg(x_old, x_new, alpha):
    return alpha*x_old + (1-alpha)*x_new

# %% [markdown]
# # Evaluate kinematics and constitutive relations

# %%
# Get acceleration and velocity at end of step
a_new = update_a(u, u_old, v_old, a_old)
v_new = update_v(a_new, u_old, v_old, a_old)

# get avg (u,p) fields for generalized-alpha method
u_avg  = avg(u_old, u, alpha)
p_avg  = avg(p_old, p, alpha)

# Kinematic relations
F =  F_calc(u_avg)  
J = det(F)
lambdaBar = lambdaBar_calc(u_avg)

# Right polar decomposition
R, U = right_decomp(F)

# update the Cv tensor
Cv = Cv_update(u_avg, Cv_old, tau_1)

# Piola stress
Tmat = Piola_calc(F, R, U, p_avg, b_app, Cv)

# %% [markdown]
# # Weak forms

# %%
# Residuals:
# Res_0: Equation of motion (test fxn: u)
# Res_1: Coupling pressure  (test fxn: p)

# The weak form for the equation of motion. No body force.
Res_0 = inner(Tmat , grad(u_test) )*dx \
          + inner(rho * a_new, u_test)*dx 

# The weak form for the pressure
Res_1 = dot( (J-1) - p_avg/Kbulk, p_test)*dx

# Total weak form
Res = (1/Gshear0)*Res_0 +  Res_1 

# Automatic differentiation tangent:
a = derivative(Res, w, dw)

# %% [markdown]
# # Set-up output files

# %%
# results file name
results_name = "hardmagnetic_hemisphere_eversion_Cv"

# Function space for projection of results
U1 = element("Lagrange", domain.basix_cell(), 1, shape=(3,)) # For displacement
V2 = fem.functionspace(domain, U1) #Vector function space
V1 = fem.functionspace(domain, P1) #Scalar function space

# fields to write to output file
u_vis = Function(V2)
u_vis.name = "disp"

p_vis = Function(V1)
p_vis.name = "p"

J_vis = Function(V1)
J_vis.name = "J"
J_expr = Expression(J,V1.element.interpolation_points())

lambdaBar_vis = Function(V1)
lambdaBar_vis.name = "lambdaBar"
lambdaBar_expr = Expression(lambdaBar,V1.element.interpolation_points())

P11 = Function(V1)
P11.name = "P11"
P11_expr = Expression(Tmat[0,0],V1.element.interpolation_points())
P22 = Function(V1)
P22.name = "P22"
P22_expr = Expression(Tmat[1,1],V1.element.interpolation_points())
P33 = Function(V1)
P33.name = "P33"
P33_expr = Expression(Tmat[2,2],V1.element.interpolation_points())

T   = Tmat*F.T/J
T0   = T - (1/3)*tr(T)*Identity(3)
Mises = sqrt((3/2)*inner(T0, T0))
Mises_vis= Function(V1,name="Mises")
Mises_expr = Expression(Mises,V1.element.interpolation_points())

# Write the spatial m_rem
m_rem = R*b_rem/det(F)/mu0*1000 # units of kA/m
#
m_vis = Function(V2, name="m_rem")
m_expr = Expression(m_rem, V2.element.interpolation_points())

# Write the magnitude of R*m^rem_mat
# (this will be a constant if R is computed correctly)
Rm_rem  = R*b_rem/mu0*1000 # units of kA/m
m_mag  = safe_sqrt(dot(Rm_rem, Rm_rem))
m_mag_vis = Function(V1, name="|R m^rem_mat|")
m_mag_expr = Expression(m_mag, V1.element.interpolation_points())
    
# set up the output VTX files.
file_results = VTXWriter(
    MPI.COMM_WORLD,
    "results/" + results_name + ".bp",
    [  # put the functions here you wish to write to output
        u_vis, p_vis, J_vis, P11, P22, P33, lambdaBar_vis,
        Mises_vis, m_vis, m_mag_vis,
    ],
    engine="BP4",
)

def writeResults(t):
       # Output field interpolation 
       u_vis.interpolate(w.sub(0))
       p_vis.interpolate(w.sub(1))
       J_vis.interpolate(J_expr)
       P11.interpolate(P11_expr)
       P22.interpolate(P22_expr)
       P33.interpolate(P33_expr)
       lambdaBar_vis.interpolate(lambdaBar_expr)
       Mises_vis.interpolate(Mises_expr)
       m_vis.interpolate(m_expr)
       m_mag_vis.interpolate(m_mag_expr)
       
       # Write output fields
       file_results.write(t)

# %% [markdown]
# # Infrastructure for pulling out time history data (force, displacement, etc.)

# %%
# infrastructure for evaluating functions at a certain point efficiently
pointForDisp = np.array([0, scaleY, 0])
bb_tree = dolfinx.geometry.bb_tree(domain,domain.topology.dim)
cell_candidates = dolfinx.geometry.compute_collisions_points(bb_tree, pointForDisp)
colliding_cells = dolfinx.geometry.compute_colliding_cells(domain, cell_candidates, pointForDisp).array

# %% [markdown]
# ## Boundary condtions

# %%
# Find the specific DOFs which will be constrained.
#
# Circular outer surface displacement degrees of freedom
edge_dofs_u1 = fem.locate_dofs_topological(ME.sub(0).sub(0), facet_tags.dim, facet_tags.find(1))
edge_dofs_u2 = fem.locate_dofs_topological(ME.sub(0).sub(1), facet_tags.dim, facet_tags.find(1))
edge_dofs_u3 = fem.locate_dofs_topological(ME.sub(0).sub(2), facet_tags.dim, facet_tags.find(1))

# Build the Dirichlet BCs
bcs_0 = dirichletbc(0.0, edge_dofs_u1, ME.sub(0).sub(0))  # u1 fix    - xBtm
bcs_1 = dirichletbc(0.0, edge_dofs_u2, ME.sub(0).sub(1))  # u2 fix    - xBtm
bcs_2 = dirichletbc(0.0, edge_dofs_u3, ME.sub(0).sub(2))  # u3 fix    - xBtm

# collect all BCs in one object.
bcs = [bcs_0, bcs_1, bcs_2]

# %% [markdown]
# ## Define the nonlinear variational problem

# %%
# # Optimization options for the form compiler

# Legacy FEniCS compiler options:
# parameters["form_compiler"]["cpp_optimize"] = True
# parameters["form_compiler"]["representation"] = "uflacs"
# parameters["form_compiler"]["cpp_optimize_flags"] = "-O3 -ffast-math -march=native"

# Analog for some options in dolfinx:
# jit_options ={"cffi_extra_compile_args":["-march=native","-O3","-ffast-math"]}
# problem = NonlinearProblem(Res, w, bcs, a, jit_options=jit_options)
#
# For now, we leave these options out.

# Set up nonlinear problem
problem = NonlinearProblem(Res, w, bcs, a)

# the global newton solver and params
solver = NewtonSolver(MPI.COMM_WORLD, problem)
solver.convergence_criterion = "incremental"
solver.rtol = 1e-8
solver.atol = 1e-8
solver.max_it = 50
solver.report = True

#  The Krylov solver parameters.
ksp = solver.krylov_solver
opts = PETSc.Options()
option_prefix = ksp.getOptionsPrefix()
opts[f"{option_prefix}ksp_type"] = "preonly" # "preonly" works equally well
opts[f"{option_prefix}pc_type"] = "lu" # do not use 'gamg' pre-conditioner
opts[f"{option_prefix}pc_factor_mat_solver_type"] = "mumps"
opts[f"{option_prefix}ksp_max_it"] = 30
ksp.setFromOptions()

# %% [markdown]
# ##  Start calculation loop

# %%
# Variables for storing time history
totSteps = 100000
timeHist0 = np.zeros(shape=[totSteps])
timeHist1 = np.zeros(shape=[totSteps]) 
timeHist2 = np.zeros(shape=[totSteps]) 

#Iinitialize a counter for reporting data
ii=0

#  Set up temporary "helper" functions and expressions 
#  for updating the internal variable Cv tensors. 
Cv_temp = Function(V3)
#
Cv_expr = Expression(Cv,V3.element.interpolation_points())
#
# and also for the velocity and acceleration.
v_temp = Function(W2)
a_temp = Function(W2)
#
v_expr = Expression(v_new,W2.element.interpolation_points())
a_expr = Expression(a_new,W2.element.interpolation_points())

# Write initial state to file
writeResults(t=0.0)  

# Print out message for simulation start
print("------------------------------------")
print("Simulation Start")
print("------------------------------------")
# Store start time 
startTime = datetime.now()  

# Give the step a descriptive name
step = "Eversion"

# Time-stepping solution procedure loop
while (round(t,4) <= round(step_time,4)):

    # increment counter
    ii += 1
    
    # increment time
    t += dt
    
    # update the applied b-field value
    bRampCons.value = bRamp(t)
    
    # Solve the problem
    try:
        (iter, converged) = solver.solve(w)
    except: # Break the loop if solver fails
        file_results.close()
        print("Ended Early")
        break
    
    # Collect results from MPI ghost processes
    w.x.scatter_forward()
    
    # Writing to VTX takes considerable time, so here I have limited the calls
    # to writeResults(t) to once every 50 steps. For the movies included in the paper
    # I called writeResults(t) once every 5 steps.
    #
    if ii%50==0:
        # Write results at current time
        writeResults(t)

    # Store time history variables at this time  
    timeHist0[ii] = t # current time
    #
    timeHist1[ii] =  bRamp(t) # time history of applied b-field
    #
    timeHist2[ii] =  w.sub(0).sub(1).eval(np.array([0, scaleY, 0]),colliding_cells[0])[0] # time history of mid-span displacement
   
    # Then, update state variables for next step
    Cv_temp.interpolate(Cv_expr)
    # 
    # And also the velocity and acceleration
    # ( v -> v_old, a -> a_old )
    v_temp.interpolate(v_expr)
    a_temp.interpolate(a_expr)
    #
    # update DOFs for next step
    w_old.x.array[:] = w.x.array
    #
    # Set "old" values of internal variables for next step 
    Cv_old.x.array[:] = Cv_temp.x.array[:]
    v_old.x.array[:] = v_temp.x.array[:]
    a_old.x.array[:] = a_temp.x.array[:]
    
    # Print progress of calculation
    if ii%5 == 0:      
        now = datetime.now()
        current_time = now.strftime("%H:%M:%S")
        print("Step: {} | Increment: {}, Iterations: {}".\
              format(step, ii, iter))
        print("      Simulation Time: {} s  of  {} s".\
              format(round(t,4), step_time))
        print()   
    

# close the output file.
file_results.close()
         
# End analysis
print("-----------------------------------------")
print("End computation")                 
# Report elapsed real time for the analysis
endTime = datetime.now()
elapseTime = endTime - startTime
print("------------------------------------------")
print("Elapsed real time:  {}".format(elapseTime))
print("------------------------------------------")
# Out:
# ------------------------------------
# Simulation Start
# ------------------------------------
# Step: Eversion | Increment: 5, Iterations: 3
#       Simulation Time: 0.0002 s  of  0.5 s
#
# Step: Eversion | Increment: 10, Iterations: 3
#       Simulation Time: 0.0003 s  of  0.5 s
#
# Step: Eversion | Increment: 15, Iterations: 3
#       Simulation Time: 0.0005 s  of  0.5 s
#
# Step: Eversion | Increment: 20, Iterations: 3
#       Simulation Time: 0.0006 s  of  0.5 s
#
# Step: Eversion | Increment: 25, Iterations: 3
#       Simulation Time: 0.0007 s  of  0.5 s
#
# Step: Eversion | Increment: 30, Iterations: 3
#       Simulation Time: 0.0009 s  of  0.5 s
#
# Step: Eversion | Increment: 35, Iterations: 3
#       Simulation Time: 0.001 s  of  0.5 s
#
# Step: Eversion | Increment: 40, Iterations: 3
#       Simulation Time: 0.0012 s  of  0.5 s
#
# Step: Eversion | Increment: 45, Iterations: 3
#       Simulation Time: 0.0014 s  of  0.5 s
#
# Step: Eversion | Increment: 50, Iterations: 3
#       Simulation Time: 0.0015 s  of  0.5 s
#
# Step: Eversion | Increment: 55, Iterations: 3
#       Simulation Time: 0.0017 s  of  0.5 s
#
# Step: Eversion | Increment: 60, Iterations: 3
#       Simulation Time: 0.0018 s  of  0.5 s
#
# Step: Eversion | Increment: 65, Iterations: 3
#       Simulation Time: 0.002 s  of  0.5 s
#
# Step: Eversion | Increment: 70, Iterations: 3
#       Simulation Time: 0.0021 s  of  0.5 s
#
# Step: Eversion | Increment: 75, Iterations: 3
#       Simulation Time: 0.0023 s  of  0.5 s
#
# Step: Eversion | Increment: 80, Iterations: 3
#       Simulation Time: 0.0024 s  of  0.5 s
#
# Step: Eversion | Increment: 85, Iterations: 3
#       Simulation Time: 0.0026 s  of  0.5 s
#
# Step: Eversion | Increment: 90, Iterations: 3
#       Simulation Time: 0.0027 s  of  0.5 s
#
# Step: Eversion | Increment: 95, Iterations: 3
#       Simulation Time: 0.0029 s  of  0.5 s
#
# Step: Eversion | Increment: 100, Iterations: 3
#       Simulation Time: 0.003 s  of  0.5 s
#
# Step: Eversion | Increment: 105, Iterations: 3
#       Simulation Time: 0.0032 s  of  0.5 s
#
# Step: Eversion | Increment: 110, Iterations: 3
#       Simulation Time: 0.0033 s  of  0.5 s
#
# Step: Eversion | Increment: 115, Iterations: 3
#       Simulation Time: 0.0035 s  of  0.5 s
#
# Step: Eversion | Increment: 120, Iterations: 3
#       Simulation Time: 0.0036 s  of  0.5 s
#
# Step: Eversion | Increment: 125, Iterations: 3
#       Simulation Time: 0.0038 s  of  0.5 s
#
# Step: Eversion | Increment: 130, Iterations: 3
#       Simulation Time: 0.0039 s  of  0.5 s
#
# Step: Eversion | Increment: 135, Iterations: 3
#       Simulation Time: 0.0041 s  of  0.5 s
#
# Step: Eversion | Increment: 140, Iterations: 3
#       Simulation Time: 0.0042 s  of  0.5 s
#
# Step: Eversion | Increment: 145, Iterations: 3
#       Simulation Time: 0.0044 s  of  0.5 s
#
# Step: Eversion | Increment: 150, Iterations: 3
#       Simulation Time: 0.0045 s  of  0.5 s
#
# Step: Eversion | Increment: 155, Iterations: 3
#       Simulation Time: 0.0046 s  of  0.5 s
#
# Step: Eversion | Increment: 160, Iterations: 3
#       Simulation Time: 0.0048 s  of  0.5 s
#
# Step: Eversion | Increment: 165, Iterations: 3
#       Simulation Time: 0.0049 s  of  0.5 s
#
# Step: Eversion | Increment: 170, Iterations: 3
#       Simulation Time: 0.0051 s  of  0.5 s
#
# Step: Eversion | Increment: 175, Iterations: 3
#       Simulation Time: 0.0052 s  of  0.5 s
#
# Step: Eversion | Increment: 180, Iterations: 3
#       Simulation Time: 0.0054 s  of  0.5 s
#
# Step: Eversion | Increment: 185, Iterations: 3
#       Simulation Time: 0.0055 s  of  0.5 s
#
# Step: Eversion | Increment: 190, Iterations: 3
#       Simulation Time: 0.0057 s  of  0.5 s
#
# Step: Eversion | Increment: 195, Iterations: 3
#       Simulation Time: 0.0058 s  of  0.5 s
#
# Step: Eversion | Increment: 200, Iterations: 3
#       Simulation Time: 0.006 s  of  0.5 s
#
# Step: Eversion | Increment: 205, Iterations: 3
#       Simulation Time: 0.0061 s  of  0.5 s
#
# Step: Eversion | Increment: 210, Iterations: 3
#       Simulation Time: 0.0063 s  of  0.5 s
#
# Step: Eversion | Increment: 215, Iterations: 3
#       Simulation Time: 0.0064 s  of  0.5 s
#
# Step: Eversion | Increment: 220, Iterations: 3
#       Simulation Time: 0.0066 s  of  0.5 s
#
# Step: Eversion | Increment: 225, Iterations: 3
#       Simulation Time: 0.0067 s  of  0.5 s
#
# Step: Eversion | Increment: 230, Iterations: 3
#       Simulation Time: 0.0069 s  of  0.5 s
#
# Step: Eversion | Increment: 235, Iterations: 3
#       Simulation Time: 0.007 s  of  0.5 s
#
# Step: Eversion | Increment: 240, Iterations: 3
#       Simulation Time: 0.0072 s  of  0.5 s
#
# Step: Eversion | Increment: 245, Iterations: 3
#       Simulation Time: 0.0073 s  of  0.5 s
#
# Step: Eversion | Increment: 250, Iterations: 3
#       Simulation Time: 0.0075 s  of  0.5 s
#
# Step: Eversion | Increment: 255, Iterations: 3
#       Simulation Time: 0.0076 s  of  0.5 s
#
# Step: Eversion | Increment: 260, Iterations: 3
#       Simulation Time: 0.0078 s  of  0.5 s
#
# Step: Eversion | Increment: 265, Iterations: 3
#       Simulation Time: 0.0079 s  of  0.5 s
#
# Step: Eversion | Increment: 270, Iterations: 3
#       Simulation Time: 0.0081 s  of  0.5 s
#
# Step: Eversion | Increment: 275, Iterations: 3
#       Simulation Time: 0.0082 s  of  0.5 s
#
# Step: Eversion | Increment: 280, Iterations: 3
#       Simulation Time: 0.0084 s  of  0.5 s
#
# Step: Eversion | Increment: 285, Iterations: 3
#       Simulation Time: 0.0085 s  of  0.5 s
#
# Step: Eversion | Increment: 290, Iterations: 3
#       Simulation Time: 0.0087 s  of  0.5 s
#
# Step: Eversion | Increment: 295, Iterations: 3
#       Simulation Time: 0.0088 s  of  0.5 s
#
# Step: Eversion | Increment: 300, Iterations: 3
#       Simulation Time: 0.009 s  of  0.5 s
#
# Step: Eversion | Increment: 305, Iterations: 3
#       Simulation Time: 0.0091 s  of  0.5 s
#
# Step: Eversion | Increment: 310, Iterations: 3
#       Simulation Time: 0.0093 s  of  0.5 s
#
# Step: Eversion | Increment: 315, Iterations: 3
#       Simulation Time: 0.0094 s  of  0.5 s
#
# Step: Eversion | Increment: 320, Iterations: 3
#       Simulation Time: 0.0096 s  of  0.5 s
#
# Step: Eversion | Increment: 325, Iterations: 3
#       Simulation Time: 0.0097 s  of  0.5 s
#
# Step: Eversion | Increment: 330, Iterations: 3
#       Simulation Time: 0.0099 s  of  0.5 s
#
# Step: Eversion | Increment: 335, Iterations: 3
#       Simulation Time: 0.01 s  of  0.5 s
#
# Step: Eversion | Increment: 340, Iterations: 3
#       Simulation Time: 0.0102 s  of  0.5 s
#
# Step: Eversion | Increment: 345, Iterations: 3
#       Simulation Time: 0.0104 s  of  0.5 s
#
# Step: Eversion | Increment: 350, Iterations: 3
#       Simulation Time: 0.0105 s  of  0.5 s
#
# Step: Eversion | Increment: 355, Iterations: 3
#       Simulation Time: 0.0107 s  of  0.5 s
#
# Step: Eversion | Increment: 360, Iterations: 3
#       Simulation Time: 0.0108 s  of  0.5 s
#
# Step: Eversion | Increment: 365, Iterations: 3
#       Simulation Time: 0.011 s  of  0.5 s
#
# Step: Eversion | Increment: 370, Iterations: 3
#       Simulation Time: 0.0111 s  of  0.5 s
#
# Step: Eversion | Increment: 375, Iterations: 3
#       Simulation Time: 0.0113 s  of  0.5 s
#
# Step: Eversion | Increment: 380, Iterations: 3
#       Simulation Time: 0.0114 s  of  0.5 s
#
# Step: Eversion | Increment: 385, Iterations: 3
#       Simulation Time: 0.0116 s  of  0.5 s
#
# Step: Eversion | Increment: 390, Iterations: 3
#       Simulation Time: 0.0117 s  of  0.5 s
#
# Step: Eversion | Increment: 395, Iterations: 3
#       Simulation Time: 0.0119 s  of  0.5 s
#
# Step: Eversion | Increment: 400, Iterations: 3
#       Simulation Time: 0.012 s  of  0.5 s
#
# Step: Eversion | Increment: 405, Iterations: 3
#       Simulation Time: 0.0122 s  of  0.5 s
#
# Step: Eversion | Increment: 410, Iterations: 3
#       Simulation Time: 0.0123 s  of  0.5 s
#
# Step: Eversion | Increment: 415, Iterations: 3
#       Simulation Time: 0.0125 s  of  0.5 s
#
# Step: Eversion | Increment: 420, Iterations: 3
#       Simulation Time: 0.0126 s  of  0.5 s
#
# Step: Eversion | Increment: 425, Iterations: 3
#       Simulation Time: 0.0128 s  of  0.5 s
#
# Step: Eversion | Increment: 430, Iterations: 3
#       Simulation Time: 0.0129 s  of  0.5 s
#
# Step: Eversion | Increment: 435, Iterations: 3
#       Simulation Time: 0.0131 s  of  0.5 s
#
# Step: Eversion | Increment: 440, Iterations: 3
#       Simulation Time: 0.0132 s  of  0.5 s
#
# Step: Eversion | Increment: 445, Iterations: 3
#       Simulation Time: 0.0134 s  of  0.5 s
#
# Step: Eversion | Increment: 450, Iterations: 3
#       Simulation Time: 0.0135 s  of  0.5 s
#
# Step: Eversion | Increment: 455, Iterations: 3
#       Simulation Time: 0.0137 s  of  0.5 s
#
# Step: Eversion | Increment: 460, Iterations: 3
#       Simulation Time: 0.0138 s  of  0.5 s
#
# Step: Eversion | Increment: 465, Iterations: 3
#       Simulation Time: 0.014 s  of  0.5 s
#
# Step: Eversion | Increment: 470, Iterations: 3
#       Simulation Time: 0.0141 s  of  0.5 s
#
# Step: Eversion | Increment: 475, Iterations: 3
#       Simulation Time: 0.0143 s  of  0.5 s
#
# Step: Eversion | Increment: 480, Iterations: 3
#       Simulation Time: 0.0144 s  of  0.5 s
#
# Step: Eversion | Increment: 485, Iterations: 3
#       Simulation Time: 0.0146 s  of  0.5 s
#
# Step: Eversion | Increment: 490, Iterations: 3
#       Simulation Time: 0.0147 s  of  0.5 s
#
# Step: Eversion | Increment: 495, Iterations: 3
#       Simulation Time: 0.0149 s  of  0.5 s
#
# Step: Eversion | Increment: 500, Iterations: 3
#       Simulation Time: 0.015 s  of  0.5 s
#
# Step: Eversion | Increment: 505, Iterations: 3
#       Simulation Time: 0.0152 s  of  0.5 s
#
# Step: Eversion | Increment: 510, Iterations: 3
#       Simulation Time: 0.0153 s  of  0.5 s
#
# Step: Eversion | Increment: 515, Iterations: 3
#       Simulation Time: 0.0155 s  of  0.5 s
#
# Step: Eversion | Increment: 520, Iterations: 3
#       Simulation Time: 0.0156 s  of  0.5 s
#
# Step: Eversion | Increment: 525, Iterations: 3
#       Simulation Time: 0.0158 s  of  0.5 s
#
# Step: Eversion | Increment: 530, Iterations: 3
#       Simulation Time: 0.0159 s  of  0.5 s
#
# Step: Eversion | Increment: 535, Iterations: 3
#       Simulation Time: 0.0161 s  of  0.5 s
#
# Step: Eversion | Increment: 540, Iterations: 3
#       Simulation Time: 0.0162 s  of  0.5 s
#
# Step: Eversion | Increment: 545, Iterations: 3
#       Simulation Time: 0.0164 s  of  0.5 s
#
# Step: Eversion | Increment: 550, Iterations: 3
#       Simulation Time: 0.0165 s  of  0.5 s
#
# Step: Eversion | Increment: 555, Iterations: 3
#       Simulation Time: 0.0167 s  of  0.5 s
#
# Step: Eversion | Increment: 560, Iterations: 3
#       Simulation Time: 0.0168 s  of  0.5 s
#
# Step: Eversion | Increment: 565, Iterations: 3
#       Simulation Time: 0.017 s  of  0.5 s
#
# Step: Eversion | Increment: 570, Iterations: 3
#       Simulation Time: 0.0171 s  of  0.5 s
#
# Step: Eversion | Increment: 575, Iterations: 3
#       Simulation Time: 0.0173 s  of  0.5 s
#
# Step: Eversion | Increment: 580, Iterations: 3
#       Simulation Time: 0.0174 s  of  0.5 s
#
# Step: Eversion | Increment: 585, Iterations: 3
#       Simulation Time: 0.0176 s  of  0.5 s
#
# Step: Eversion | Increment: 590, Iterations: 3
#       Simulation Time: 0.0177 s  of  0.5 s
#
# Step: Eversion | Increment: 595, Iterations: 3
#       Simulation Time: 0.0179 s  of  0.5 s
#
# Step: Eversion | Increment: 600, Iterations: 3
#       Simulation Time: 0.018 s  of  0.5 s
#
# Step: Eversion | Increment: 605, Iterations: 3
#       Simulation Time: 0.0181 s  of  0.5 s
#
# Step: Eversion | Increment: 610, Iterations: 3
#       Simulation Time: 0.0183 s  of  0.5 s
#
# Step: Eversion | Increment: 615, Iterations: 3
#       Simulation Time: 0.0184 s  of  0.5 s
#
# Step: Eversion | Increment: 620, Iterations: 3
#       Simulation Time: 0.0186 s  of  0.5 s
#
# Step: Eversion | Increment: 625, Iterations: 3
#       Simulation Time: 0.0187 s  of  0.5 s
#
# Step: Eversion | Increment: 630, Iterations: 3
#       Simulation Time: 0.0189 s  of  0.5 s
#
# Step: Eversion | Increment: 635, Iterations: 3
#       Simulation Time: 0.019 s  of  0.5 s
#
# Step: Eversion | Increment: 640, Iterations: 3
#       Simulation Time: 0.0192 s  of  0.5 s
#
# Step: Eversion | Increment: 645, Iterations: 3
#       Simulation Time: 0.0193 s  of  0.5 s
#
# Step: Eversion | Increment: 650, Iterations: 3
#       Simulation Time: 0.0195 s  of  0.5 s
#
# Step: Eversion | Increment: 655, Iterations: 3
#       Simulation Time: 0.0196 s  of  0.5 s
#
# Step: Eversion | Increment: 660, Iterations: 3
#       Simulation Time: 0.0198 s  of  0.5 s
#
# Step: Eversion | Increment: 665, Iterations: 3
#       Simulation Time: 0.0199 s  of  0.5 s
#
# Step: Eversion | Increment: 670, Iterations: 3
#       Simulation Time: 0.0201 s  of  0.5 s
#
# Step: Eversion | Increment: 675, Iterations: 3
#       Simulation Time: 0.0202 s  of  0.5 s
#
# Step: Eversion | Increment: 680, Iterations: 3
#       Simulation Time: 0.0204 s  of  0.5 s
#
# Step: Eversion | Increment: 685, Iterations: 3
#       Simulation Time: 0.0205 s  of  0.5 s
#
# Step: Eversion | Increment: 690, Iterations: 3
#       Simulation Time: 0.0207 s  of  0.5 s
#
# Step: Eversion | Increment: 695, Iterations: 3
#       Simulation Time: 0.0208 s  of  0.5 s
#
# Step: Eversion | Increment: 700, Iterations: 3
#       Simulation Time: 0.021 s  of  0.5 s
#
# Step: Eversion | Increment: 705, Iterations: 3
#       Simulation Time: 0.0211 s  of  0.5 s
#
# Step: Eversion | Increment: 710, Iterations: 3
#       Simulation Time: 0.0213 s  of  0.5 s
#
# Step: Eversion | Increment: 715, Iterations: 3
#       Simulation Time: 0.0214 s  of  0.5 s
#
# Step: Eversion | Increment: 720, Iterations: 3
#       Simulation Time: 0.0216 s  of  0.5 s
#
# Step: Eversion | Increment: 725, Iterations: 3
#       Simulation Time: 0.0217 s  of  0.5 s
#
# Step: Eversion | Increment: 730, Iterations: 3
#       Simulation Time: 0.0219 s  of  0.5 s
#
# Step: Eversion | Increment: 735, Iterations: 3
#       Simulation Time: 0.022 s  of  0.5 s
#
# Step: Eversion | Increment: 740, Iterations: 3
#       Simulation Time: 0.0222 s  of  0.5 s
#
# Step: Eversion | Increment: 745, Iterations: 3
#       Simulation Time: 0.0223 s  of  0.5 s
#
# Step: Eversion | Increment: 750, Iterations: 3
#       Simulation Time: 0.0225 s  of  0.5 s
#
# Step: Eversion | Increment: 755, Iterations: 3
#       Simulation Time: 0.0226 s  of  0.5 s
#
# Step: Eversion | Increment: 760, Iterations: 3
#       Simulation Time: 0.0228 s  of  0.5 s
#
# Step: Eversion | Increment: 765, Iterations: 3
#       Simulation Time: 0.0229 s  of  0.5 s
#
# Step: Eversion | Increment: 770, Iterations: 3
#       Simulation Time: 0.0231 s  of  0.5 s
#
# Step: Eversion | Increment: 775, Iterations: 3
#       Simulation Time: 0.0232 s  of  0.5 s
#
# Step: Eversion | Increment: 780, Iterations: 3
#       Simulation Time: 0.0234 s  of  0.5 s
#
# Step: Eversion | Increment: 785, Iterations: 3
#       Simulation Time: 0.0235 s  of  0.5 s
#
# Step: Eversion | Increment: 790, Iterations: 3
#       Simulation Time: 0.0237 s  of  0.5 s
#
# Step: Eversion | Increment: 795, Iterations: 3
#       Simulation Time: 0.0238 s  of  0.5 s
#
# Step: Eversion | Increment: 800, Iterations: 3
#       Simulation Time: 0.024 s  of  0.5 s
#
# Step: Eversion | Increment: 805, Iterations: 3
#       Simulation Time: 0.0241 s  of  0.5 s
#
# Step: Eversion | Increment: 810, Iterations: 3
#       Simulation Time: 0.0243 s  of  0.5 s
#
# Step: Eversion | Increment: 815, Iterations: 3
#       Simulation Time: 0.0244 s  of  0.5 s
#
# Step: Eversion | Increment: 820, Iterations: 3
#       Simulation Time: 0.0246 s  of  0.5 s
#
# Step: Eversion | Increment: 825, Iterations: 3
#       Simulation Time: 0.0247 s  of  0.5 s
#
# Step: Eversion | Increment: 830, Iterations: 3
#       Simulation Time: 0.0249 s  of  0.5 s
#
# Step: Eversion | Increment: 835, Iterations: 3
#       Simulation Time: 0.025 s  of  0.5 s
#
# Step: Eversion | Increment: 840, Iterations: 3
#       Simulation Time: 0.0252 s  of  0.5 s
#
# Step: Eversion | Increment: 845, Iterations: 3
#       Simulation Time: 0.0253 s  of  0.5 s
#
# Step: Eversion | Increment: 850, Iterations: 3
#       Simulation Time: 0.0255 s  of  0.5 s
#
# Step: Eversion | Increment: 855, Iterations: 3
#       Simulation Time: 0.0256 s  of  0.5 s
#
# Step: Eversion | Increment: 860, Iterations: 3
#       Simulation Time: 0.0258 s  of  0.5 s
#
# Step: Eversion | Increment: 865, Iterations: 3
#       Simulation Time: 0.0259 s  of  0.5 s
#
# Step: Eversion | Increment: 870, Iterations: 3
#       Simulation Time: 0.0261 s  of  0.5 s
#
# Step: Eversion | Increment: 875, Iterations: 3
#       Simulation Time: 0.0262 s  of  0.5 s
#
# Step: Eversion | Increment: 880, Iterations: 3
#       Simulation Time: 0.0264 s  of  0.5 s
#
# Step: Eversion | Increment: 885, Iterations: 3
#       Simulation Time: 0.0265 s  of  0.5 s
#
# Step: Eversion | Increment: 890, Iterations: 3
#       Simulation Time: 0.0267 s  of  0.5 s
#
# Step: Eversion | Increment: 895, Iterations: 3
#       Simulation Time: 0.0268 s  of  0.5 s
#
# Step: Eversion | Increment: 900, Iterations: 3
#       Simulation Time: 0.027 s  of  0.5 s
#
# Step: Eversion | Increment: 905, Iterations: 3
#       Simulation Time: 0.0271 s  of  0.5 s
#
# Step: Eversion | Increment: 910, Iterations: 3
#       Simulation Time: 0.0273 s  of  0.5 s
#
# Step: Eversion | Increment: 915, Iterations: 3
#       Simulation Time: 0.0274 s  of  0.5 s
#
# Step: Eversion | Increment: 920, Iterations: 3
#       Simulation Time: 0.0276 s  of  0.5 s
#
# Step: Eversion | Increment: 925, Iterations: 3
#       Simulation Time: 0.0277 s  of  0.5 s
#
# Step: Eversion | Increment: 930, Iterations: 3
#       Simulation Time: 0.0279 s  of  0.5 s
#
# Step: Eversion | Increment: 935, Iterations: 3
#       Simulation Time: 0.028 s  of  0.5 s
#
# Step: Eversion | Increment: 940, Iterations: 3
#       Simulation Time: 0.0282 s  of  0.5 s
#
# Step: Eversion | Increment: 945, Iterations: 3
#       Simulation Time: 0.0283 s  of  0.5 s
#
# Step: Eversion | Increment: 950, Iterations: 3
#       Simulation Time: 0.0285 s  of  0.5 s
#
# Step: Eversion | Increment: 955, Iterations: 3
#       Simulation Time: 0.0286 s  of  0.5 s
#
# Step: Eversion | Increment: 960, Iterations: 3
#       Simulation Time: 0.0288 s  of  0.5 s
#
# Step: Eversion | Increment: 965, Iterations: 3
#       Simulation Time: 0.0289 s  of  0.5 s
#
# Step: Eversion | Increment: 970, Iterations: 3
#       Simulation Time: 0.0291 s  of  0.5 s
#
# Step: Eversion | Increment: 975, Iterations: 3
#       Simulation Time: 0.0292 s  of  0.5 s
#
# Step: Eversion | Increment: 980, Iterations: 3
#       Simulation Time: 0.0294 s  of  0.5 s
#
# Step: Eversion | Increment: 985, Iterations: 3
#       Simulation Time: 0.0295 s  of  0.5 s
#
# Step: Eversion | Increment: 990, Iterations: 3
#       Simulation Time: 0.0297 s  of  0.5 s
#
# Step: Eversion | Increment: 995, Iterations: 3
#       Simulation Time: 0.0298 s  of  0.5 s
#
# Step: Eversion | Increment: 1000, Iterations: 3
#       Simulation Time: 0.03 s  of  0.5 s
#
# Step: Eversion | Increment: 1005, Iterations: 3
#       Simulation Time: 0.0301 s  of  0.5 s
#
# Step: Eversion | Increment: 1010, Iterations: 3
#       Simulation Time: 0.0303 s  of  0.5 s
#
# Step: Eversion | Increment: 1015, Iterations: 3
#       Simulation Time: 0.0304 s  of  0.5 s
#
# Step: Eversion | Increment: 1020, Iterations: 3
#       Simulation Time: 0.0306 s  of  0.5 s
#
# Step: Eversion | Increment: 1025, Iterations: 4
#       Simulation Time: 0.0307 s  of  0.5 s
#
# Step: Eversion | Increment: 1030, Iterations: 4
#       Simulation Time: 0.0309 s  of  0.5 s
#
# Step: Eversion | Increment: 1035, Iterations: 3
#       Simulation Time: 0.031 s  of  0.5 s
#
# Step: Eversion | Increment: 1040, Iterations: 4
#       Simulation Time: 0.0312 s  of  0.5 s
#
# Step: Eversion | Increment: 1045, Iterations: 3
#       Simulation Time: 0.0313 s  of  0.5 s
#
# Step: Eversion | Increment: 1050, Iterations: 3
#       Simulation Time: 0.0315 s  of  0.5 s
#
# Step: Eversion | Increment: 1055, Iterations: 4
#       Simulation Time: 0.0316 s  of  0.5 s
#
# Step: Eversion | Increment: 1060, Iterations: 3
#       Simulation Time: 0.0318 s  of  0.5 s
#
# Step: Eversion | Increment: 1065, Iterations: 4
#       Simulation Time: 0.0319 s  of  0.5 s
#
# Step: Eversion | Increment: 1070, Iterations: 4
#       Simulation Time: 0.0321 s  of  0.5 s
#
# Step: Eversion | Increment: 1075, Iterations: 4
#       Simulation Time: 0.0322 s  of  0.5 s
#
# Step: Eversion | Increment: 1080, Iterations: 4
#       Simulation Time: 0.0324 s  of  0.5 s
#
# Step: Eversion | Increment: 1085, Iterations: 4
#       Simulation Time: 0.0325 s  of  0.5 s
#
# Step: Eversion | Increment: 1090, Iterations: 4
#       Simulation Time: 0.0327 s  of  0.5 s
#
# Step: Eversion | Increment: 1095, Iterations: 4
#       Simulation Time: 0.0328 s  of  0.5 s
#
# Step: Eversion | Increment: 1100, Iterations: 4
#       Simulation Time: 0.033 s  of  0.5 s
#
# Step: Eversion | Increment: 1105, Iterations: 4
#       Simulation Time: 0.0331 s  of  0.5 s
#
# Step: Eversion | Increment: 1110, Iterations: 4
#       Simulation Time: 0.0333 s  of  0.5 s
#
# Step: Eversion | Increment: 1115, Iterations: 4
#       Simulation Time: 0.0334 s  of  0.5 s
#
# Step: Eversion | Increment: 1120, Iterations: 4
#       Simulation Time: 0.0336 s  of  0.5 s
#
# Step: Eversion | Increment: 1125, Iterations: 4
#       Simulation Time: 0.0337 s  of  0.5 s
#
# Step: Eversion | Increment: 1130, Iterations: 4
#       Simulation Time: 0.0339 s  of  0.5 s
#
# Step: Eversion | Increment: 1135, Iterations: 4
#       Simulation Time: 0.034 s  of  0.5 s
#
# Step: Eversion | Increment: 1140, Iterations: 4
#       Simulation Time: 0.0342 s  of  0.5 s
#
# Step: Eversion | Increment: 1145, Iterations: 4
#       Simulation Time: 0.0343 s  of  0.5 s
#
# Step: Eversion | Increment: 1150, Iterations: 4
#       Simulation Time: 0.0345 s  of  0.5 s
#
# Step: Eversion | Increment: 1155, Iterations: 4
#       Simulation Time: 0.0346 s  of  0.5 s
#
# Step: Eversion | Increment: 1160, Iterations: 4
#       Simulation Time: 0.0348 s  of  0.5 s
#
# Step: Eversion | Increment: 1165, Iterations: 4
#       Simulation Time: 0.0349 s  of  0.5 s
#
# Step: Eversion | Increment: 1170, Iterations: 4
#       Simulation Time: 0.0351 s  of  0.5 s
#
# Step: Eversion | Increment: 1175, Iterations: 4
#       Simulation Time: 0.0352 s  of  0.5 s
#
# Step: Eversion | Increment: 1180, Iterations: 4
#       Simulation Time: 0.0354 s  of  0.5 s
#
# Step: Eversion | Increment: 1185, Iterations: 4
#       Simulation Time: 0.0355 s  of  0.5 s
#
# Step: Eversion | Increment: 1190, Iterations: 4
#       Simulation Time: 0.0357 s  of  0.5 s
#
# Step: Eversion | Increment: 1195, Iterations: 4
#       Simulation Time: 0.0358 s  of  0.5 s
#
# Step: Eversion | Increment: 1200, Iterations: 4
#       Simulation Time: 0.036 s  of  0.5 s
#
# Step: Eversion | Increment: 1205, Iterations: 4
#       Simulation Time: 0.0361 s  of  0.5 s
#
# Step: Eversion | Increment: 1210, Iterations: 4
#       Simulation Time: 0.0363 s  of  0.5 s
#
# Step: Eversion | Increment: 1215, Iterations: 4
#       Simulation Time: 0.0364 s  of  0.5 s
#
# Step: Eversion | Increment: 1220, Iterations: 4
#       Simulation Time: 0.0366 s  of  0.5 s
#
# Step: Eversion | Increment: 1225, Iterations: 4
#       Simulation Time: 0.0367 s  of  0.5 s
#
# Step: Eversion | Increment: 1230, Iterations: 4
#       Simulation Time: 0.0369 s  of  0.5 s
#
# Step: Eversion | Increment: 1235, Iterations: 4
#       Simulation Time: 0.037 s  of  0.5 s
#
# Step: Eversion | Increment: 1240, Iterations: 4
#       Simulation Time: 0.0372 s  of  0.5 s
#
# Step: Eversion | Increment: 1245, Iterations: 4
#       Simulation Time: 0.0373 s  of  0.5 s
#
# Step: Eversion | Increment: 1250, Iterations: 4
#       Simulation Time: 0.0375 s  of  0.5 s
#
# Step: Eversion | Increment: 1255, Iterations: 4
#       Simulation Time: 0.0376 s  of  0.5 s
#
# Step: Eversion | Increment: 1260, Iterations: 4
#       Simulation Time: 0.0378 s  of  0.5 s
#
# Step: Eversion | Increment: 1265, Iterations: 4
#       Simulation Time: 0.0379 s  of  0.5 s
#
# Step: Eversion | Increment: 1270, Iterations: 4
#       Simulation Time: 0.0381 s  of  0.5 s
#
# Step: Eversion | Increment: 1275, Iterations: 4
#       Simulation Time: 0.0382 s  of  0.5 s
#
# Step: Eversion | Increment: 1280, Iterations: 4
#       Simulation Time: 0.0384 s  of  0.5 s
#
# Step: Eversion | Increment: 1285, Iterations: 4
#       Simulation Time: 0.0386 s  of  0.5 s
#
# Step: Eversion | Increment: 1290, Iterations: 4
#       Simulation Time: 0.0387 s  of  0.5 s
#
# Step: Eversion | Increment: 1295, Iterations: 4
#       Simulation Time: 0.0389 s  of  0.5 s
#
# Step: Eversion | Increment: 1300, Iterations: 4
#       Simulation Time: 0.039 s  of  0.5 s
#
# Step: Eversion | Increment: 1305, Iterations: 4
#       Simulation Time: 0.0392 s  of  0.5 s
#
# Step: Eversion | Increment: 1310, Iterations: 4
#       Simulation Time: 0.0393 s  of  0.5 s
#
# Step: Eversion | Increment: 1315, Iterations: 4
#       Simulation Time: 0.0395 s  of  0.5 s
#
# Step: Eversion | Increment: 1320, Iterations: 4
#       Simulation Time: 0.0396 s  of  0.5 s
#
# Step: Eversion | Increment: 1325, Iterations: 4
#       Simulation Time: 0.0398 s  of  0.5 s
#
# Step: Eversion | Increment: 1330, Iterations: 4
#       Simulation Time: 0.0399 s  of  0.5 s
#
# Step: Eversion | Increment: 1335, Iterations: 4
#       Simulation Time: 0.0401 s  of  0.5 s
#
# Step: Eversion | Increment: 1340, Iterations: 4
#       Simulation Time: 0.0402 s  of  0.5 s
#
# Step: Eversion | Increment: 1345, Iterations: 4
#       Simulation Time: 0.0404 s  of  0.5 s
#
# Step: Eversion | Increment: 1350, Iterations: 4
#       Simulation Time: 0.0405 s  of  0.5 s
#
# Step: Eversion | Increment: 1355, Iterations: 4
#       Simulation Time: 0.0407 s  of  0.5 s
#
# Step: Eversion | Increment: 1360, Iterations: 4
#       Simulation Time: 0.0408 s  of  0.5 s
#
# Step: Eversion | Increment: 1365, Iterations: 4
#       Simulation Time: 0.041 s  of  0.5 s
#
# Step: Eversion | Increment: 1370, Iterations: 4
#       Simulation Time: 0.0411 s  of  0.5 s
#
# Step: Eversion | Increment: 1375, Iterations: 4
#       Simulation Time: 0.0413 s  of  0.5 s
#
# Step: Eversion | Increment: 1380, Iterations: 4
#       Simulation Time: 0.0414 s  of  0.5 s
#
# Step: Eversion | Increment: 1385, Iterations: 4
#       Simulation Time: 0.0416 s  of  0.5 s
#
# Step: Eversion | Increment: 1390, Iterations: 4
#       Simulation Time: 0.0417 s  of  0.5 s
#
# Step: Eversion | Increment: 1395, Iterations: 4
#       Simulation Time: 0.0419 s  of  0.5 s
#
# Step: Eversion | Increment: 1400, Iterations: 4
#       Simulation Time: 0.042 s  of  0.5 s
#
# Step: Eversion | Increment: 1405, Iterations: 4
#       Simulation Time: 0.0422 s  of  0.5 s
#
# Step: Eversion | Increment: 1410, Iterations: 4
#       Simulation Time: 0.0423 s  of  0.5 s
#
# Step: Eversion | Increment: 1415, Iterations: 4
#       Simulation Time: 0.0425 s  of  0.5 s
#
# Step: Eversion | Increment: 1420, Iterations: 4
#       Simulation Time: 0.0426 s  of  0.5 s
#
# Step: Eversion | Increment: 1425, Iterations: 4
#       Simulation Time: 0.0428 s  of  0.5 s
#
# Step: Eversion | Increment: 1430, Iterations: 4
#       Simulation Time: 0.0429 s  of  0.5 s
#
# Step: Eversion | Increment: 1435, Iterations: 4
#       Simulation Time: 0.0431 s  of  0.5 s
#
# Step: Eversion | Increment: 1440, Iterations: 4
#       Simulation Time: 0.0432 s  of  0.5 s
#
# Step: Eversion | Increment: 1445, Iterations: 4
#       Simulation Time: 0.0434 s  of  0.5 s
#
# Step: Eversion | Increment: 1450, Iterations: 4
#       Simulation Time: 0.0435 s  of  0.5 s
#
# Step: Eversion | Increment: 1455, Iterations: 4
#       Simulation Time: 0.0437 s  of  0.5 s
#
# Step: Eversion | Increment: 1460, Iterations: 4
#       Simulation Time: 0.0438 s  of  0.5 s
#
# Step: Eversion | Increment: 1465, Iterations: 4
#       Simulation Time: 0.044 s  of  0.5 s
#
# Step: Eversion | Increment: 1470, Iterations: 4
#       Simulation Time: 0.0441 s  of  0.5 s
#
# Step: Eversion | Increment: 1475, Iterations: 4
#       Simulation Time: 0.0443 s  of  0.5 s
#
# Step: Eversion | Increment: 1480, Iterations: 4
#       Simulation Time: 0.0444 s  of  0.5 s
#
# Step: Eversion | Increment: 1485, Iterations: 4
#       Simulation Time: 0.0446 s  of  0.5 s
#
# Step: Eversion | Increment: 1490, Iterations: 4
#       Simulation Time: 0.0447 s  of  0.5 s
#
# Step: Eversion | Increment: 1495, Iterations: 4
#       Simulation Time: 0.0449 s  of  0.5 s
#
# Step: Eversion | Increment: 1500, Iterations: 4
#       Simulation Time: 0.045 s  of  0.5 s
#
# Step: Eversion | Increment: 1505, Iterations: 4
#       Simulation Time: 0.0452 s  of  0.5 s
#
# Step: Eversion | Increment: 1510, Iterations: 4
#       Simulation Time: 0.0453 s  of  0.5 s
#
# Step: Eversion | Increment: 1515, Iterations: 4
#       Simulation Time: 0.0455 s  of  0.5 s
#
# Step: Eversion | Increment: 1520, Iterations: 4
#       Simulation Time: 0.0456 s  of  0.5 s
#
# Step: Eversion | Increment: 1525, Iterations: 4
#       Simulation Time: 0.0458 s  of  0.5 s
#
# Step: Eversion | Increment: 1530, Iterations: 4
#       Simulation Time: 0.0459 s  of  0.5 s
#
# Step: Eversion | Increment: 1535, Iterations: 4
#       Simulation Time: 0.0461 s  of  0.5 s
#
# Step: Eversion | Increment: 1540, Iterations: 4
#       Simulation Time: 0.0462 s  of  0.5 s
#
# Step: Eversion | Increment: 1545, Iterations: 4
#       Simulation Time: 0.0464 s  of  0.5 s
#
# Step: Eversion | Increment: 1550, Iterations: 4
#       Simulation Time: 0.0465 s  of  0.5 s
#
# Step: Eversion | Increment: 1555, Iterations: 4
#       Simulation Time: 0.0467 s  of  0.5 s
#
# Step: Eversion | Increment: 1560, Iterations: 4
#       Simulation Time: 0.0468 s  of  0.5 s
#
# Step: Eversion | Increment: 1565, Iterations: 4
#       Simulation Time: 0.047 s  of  0.5 s
#
# Step: Eversion | Increment: 1570, Iterations: 4
#       Simulation Time: 0.0471 s  of  0.5 s
#
# Step: Eversion | Increment: 1575, Iterations: 4
#       Simulation Time: 0.0473 s  of  0.5 s
#
# Step: Eversion | Increment: 1580, Iterations: 4
#       Simulation Time: 0.0474 s  of  0.5 s
#
# Step: Eversion | Increment: 1585, Iterations: 4
#       Simulation Time: 0.0476 s  of  0.5 s
#
# Step: Eversion | Increment: 1590, Iterations: 4
#       Simulation Time: 0.0477 s  of  0.5 s
#
# Step: Eversion | Increment: 1595, Iterations: 4
#       Simulation Time: 0.0479 s  of  0.5 s
#
# Step: Eversion | Increment: 1600, Iterations: 4
#       Simulation Time: 0.048 s  of  0.5 s
#
# Step: Eversion | Increment: 1605, Iterations: 4
#       Simulation Time: 0.0482 s  of  0.5 s
#
# Step: Eversion | Increment: 1610, Iterations: 4
#       Simulation Time: 0.0483 s  of  0.5 s
#
# Step: Eversion | Increment: 1615, Iterations: 4
#       Simulation Time: 0.0485 s  of  0.5 s
#
# Step: Eversion | Increment: 1620, Iterations: 4
#       Simulation Time: 0.0486 s  of  0.5 s
#
# Step: Eversion | Increment: 1625, Iterations: 4
#       Simulation Time: 0.0488 s  of  0.5 s
#
# Step: Eversion | Increment: 1630, Iterations: 4
#       Simulation Time: 0.0489 s  of  0.5 s
#
# Step: Eversion | Increment: 1635, Iterations: 4
#       Simulation Time: 0.0491 s  of  0.5 s
#
# Step: Eversion | Increment: 1640, Iterations: 4
#       Simulation Time: 0.0492 s  of  0.5 s
#
# Step: Eversion | Increment: 1645, Iterations: 4
#       Simulation Time: 0.0494 s  of  0.5 s
#
# Step: Eversion | Increment: 1650, Iterations: 4
#       Simulation Time: 0.0495 s  of  0.5 s
#
# Step: Eversion | Increment: 1655, Iterations: 4
#       Simulation Time: 0.0497 s  of  0.5 s
#
# Step: Eversion | Increment: 1660, Iterations: 4
#       Simulation Time: 0.0498 s  of  0.5 s
#
# Step: Eversion | Increment: 1665, Iterations: 4
#       Simulation Time: 0.05 s  of  0.5 s
#
# Step: Eversion | Increment: 1670, Iterations: 4
#       Simulation Time: 0.0501 s  of  0.5 s
#
# Step: Eversion | Increment: 1675, Iterations: 4
#       Simulation Time: 0.0503 s  of  0.5 s
#
# Step: Eversion | Increment: 1680, Iterations: 4
#       Simulation Time: 0.0504 s  of  0.5 s
#
# Step: Eversion | Increment: 1685, Iterations: 4
#       Simulation Time: 0.0506 s  of  0.5 s
#
# Step: Eversion | Increment: 1690, Iterations: 4
#       Simulation Time: 0.0507 s  of  0.5 s
#
# Step: Eversion | Increment: 1695, Iterations: 4
#       Simulation Time: 0.0509 s  of  0.5 s
#
# Step: Eversion | Increment: 1700, Iterations: 4
#       Simulation Time: 0.051 s  of  0.5 s
#
# Step: Eversion | Increment: 1705, Iterations: 4
#       Simulation Time: 0.0512 s  of  0.5 s
#
# Step: Eversion | Increment: 1710, Iterations: 4
#       Simulation Time: 0.0513 s  of  0.5 s
#
# Step: Eversion | Increment: 1715, Iterations: 4
#       Simulation Time: 0.0515 s  of  0.5 s
#
# Step: Eversion | Increment: 1720, Iterations: 4
#       Simulation Time: 0.0516 s  of  0.5 s
#
# Step: Eversion | Increment: 1725, Iterations: 4
#       Simulation Time: 0.0518 s  of  0.5 s
#
# Step: Eversion | Increment: 1730, Iterations: 4
#       Simulation Time: 0.0519 s  of  0.5 s
#
# Step: Eversion | Increment: 1735, Iterations: 4
#       Simulation Time: 0.0521 s  of  0.5 s
#
# Step: Eversion | Increment: 1740, Iterations: 4
#       Simulation Time: 0.0522 s  of  0.5 s
#
# Step: Eversion | Increment: 1745, Iterations: 4
#       Simulation Time: 0.0524 s  of  0.5 s
#
# Step: Eversion | Increment: 1750, Iterations: 4
#       Simulation Time: 0.0525 s  of  0.5 s
#
# Step: Eversion | Increment: 1755, Iterations: 4
#       Simulation Time: 0.0527 s  of  0.5 s
#
# Step: Eversion | Increment: 1760, Iterations: 4
#       Simulation Time: 0.0528 s  of  0.5 s
#
# Step: Eversion | Increment: 1765, Iterations: 4
#       Simulation Time: 0.053 s  of  0.5 s
#
# Step: Eversion | Increment: 1770, Iterations: 4
#       Simulation Time: 0.0531 s  of  0.5 s
#
# Step: Eversion | Increment: 1775, Iterations: 4
#       Simulation Time: 0.0533 s  of  0.5 s
#
# Step: Eversion | Increment: 1780, Iterations: 4
#       Simulation Time: 0.0534 s  of  0.5 s
#
# Step: Eversion | Increment: 1785, Iterations: 4
#       Simulation Time: 0.0536 s  of  0.5 s
#
# Step: Eversion | Increment: 1790, Iterations: 4
#       Simulation Time: 0.0537 s  of  0.5 s
#
# Step: Eversion | Increment: 1795, Iterations: 4
#       Simulation Time: 0.0539 s  of  0.5 s
#
# Step: Eversion | Increment: 1800, Iterations: 4
#       Simulation Time: 0.054 s  of  0.5 s
#
# Step: Eversion | Increment: 1805, Iterations: 4
#       Simulation Time: 0.0542 s  of  0.5 s
#
# Step: Eversion | Increment: 1810, Iterations: 4
#       Simulation Time: 0.0543 s  of  0.5 s
#
# Step: Eversion | Increment: 1815, Iterations: 4
#       Simulation Time: 0.0545 s  of  0.5 s
#
# Step: Eversion | Increment: 1820, Iterations: 4
#       Simulation Time: 0.0546 s  of  0.5 s
#
# Step: Eversion | Increment: 1825, Iterations: 4
#       Simulation Time: 0.0548 s  of  0.5 s
#
# Step: Eversion | Increment: 1830, Iterations: 4
#       Simulation Time: 0.0549 s  of  0.5 s
#
# Step: Eversion | Increment: 1835, Iterations: 4
#       Simulation Time: 0.0551 s  of  0.5 s
#
# Step: Eversion | Increment: 1840, Iterations: 4
#       Simulation Time: 0.0552 s  of  0.5 s
#
# Step: Eversion | Increment: 1845, Iterations: 4
#       Simulation Time: 0.0554 s  of  0.5 s
#
# Step: Eversion | Increment: 1850, Iterations: 4
#       Simulation Time: 0.0555 s  of  0.5 s
#
# Step: Eversion | Increment: 1855, Iterations: 4
#       Simulation Time: 0.0557 s  of  0.5 s
#
# Step: Eversion | Increment: 1860, Iterations: 4
#       Simulation Time: 0.0558 s  of  0.5 s
#
# Step: Eversion | Increment: 1865, Iterations: 4
#       Simulation Time: 0.056 s  of  0.5 s
#
# Step: Eversion | Increment: 1870, Iterations: 4
#       Simulation Time: 0.0561 s  of  0.5 s
#
# Step: Eversion | Increment: 1875, Iterations: 4
#       Simulation Time: 0.0563 s  of  0.5 s
#
# Step: Eversion | Increment: 1880, Iterations: 4
#       Simulation Time: 0.0564 s  of  0.5 s
#
# Step: Eversion | Increment: 1885, Iterations: 4
#       Simulation Time: 0.0566 s  of  0.5 s
#
# Step: Eversion | Increment: 1890, Iterations: 4
#       Simulation Time: 0.0567 s  of  0.5 s
#
# Step: Eversion | Increment: 1895, Iterations: 4
#       Simulation Time: 0.0569 s  of  0.5 s
#
# Step: Eversion | Increment: 1900, Iterations: 4
#       Simulation Time: 0.057 s  of  0.5 s
#
# Step: Eversion | Increment: 1905, Iterations: 4
#       Simulation Time: 0.0572 s  of  0.5 s
#
# Step: Eversion | Increment: 1910, Iterations: 4
#       Simulation Time: 0.0573 s  of  0.5 s
#
# Step: Eversion | Increment: 1915, Iterations: 4
#       Simulation Time: 0.0575 s  of  0.5 s
#
# Step: Eversion | Increment: 1920, Iterations: 4
#       Simulation Time: 0.0576 s  of  0.5 s
#
# Step: Eversion | Increment: 1925, Iterations: 4
#       Simulation Time: 0.0578 s  of  0.5 s
#
# Step: Eversion | Increment: 1930, Iterations: 4
#       Simulation Time: 0.0579 s  of  0.5 s
#
# Step: Eversion | Increment: 1935, Iterations: 4
#       Simulation Time: 0.0581 s  of  0.5 s
#
# Step: Eversion | Increment: 1940, Iterations: 4
#       Simulation Time: 0.0582 s  of  0.5 s
#
# Step: Eversion | Increment: 1945, Iterations: 4
#       Simulation Time: 0.0584 s  of  0.5 s
#
# Step: Eversion | Increment: 1950, Iterations: 4
#       Simulation Time: 0.0585 s  of  0.5 s
#
# Step: Eversion | Increment: 1955, Iterations: 4
#       Simulation Time: 0.0587 s  of  0.5 s
#
# Step: Eversion | Increment: 1960, Iterations: 4
#       Simulation Time: 0.0588 s  of  0.5 s
#
# Step: Eversion | Increment: 1965, Iterations: 4
#       Simulation Time: 0.059 s  of  0.5 s
#
# Step: Eversion | Increment: 1970, Iterations: 4
#       Simulation Time: 0.0591 s  of  0.5 s
#
# Step: Eversion | Increment: 1975, Iterations: 4
#       Simulation Time: 0.0593 s  of  0.5 s
#
# Step: Eversion | Increment: 1980, Iterations: 4
#       Simulation Time: 0.0594 s  of  0.5 s
#
# Step: Eversion | Increment: 1985, Iterations: 4
#       Simulation Time: 0.0596 s  of  0.5 s
#
# Step: Eversion | Increment: 1990, Iterations: 4
#       Simulation Time: 0.0597 s  of  0.5 s
#
# Step: Eversion | Increment: 1995, Iterations: 4
#       Simulation Time: 0.0599 s  of  0.5 s
#
# Step: Eversion | Increment: 2000, Iterations: 4
#       Simulation Time: 0.06 s  of  0.5 s
#
# Step: Eversion | Increment: 2005, Iterations: 4
#       Simulation Time: 0.0602 s  of  0.5 s
#
# Step: Eversion | Increment: 2010, Iterations: 4
#       Simulation Time: 0.0603 s  of  0.5 s
#
# Step: Eversion | Increment: 2015, Iterations: 4
#       Simulation Time: 0.0605 s  of  0.5 s
#
# Step: Eversion | Increment: 2020, Iterations: 4
#       Simulation Time: 0.0606 s  of  0.5 s
#
# Step: Eversion | Increment: 2025, Iterations: 4
#       Simulation Time: 0.0608 s  of  0.5 s
#
# Step: Eversion | Increment: 2030, Iterations: 4
#       Simulation Time: 0.0609 s  of  0.5 s
#
# Step: Eversion | Increment: 2035, Iterations: 4
#       Simulation Time: 0.0611 s  of  0.5 s
#
# Step: Eversion | Increment: 2040, Iterations: 4
#       Simulation Time: 0.0612 s  of  0.5 s
#
# Step: Eversion | Increment: 2045, Iterations: 4
#       Simulation Time: 0.0614 s  of  0.5 s
#
# Step: Eversion | Increment: 2050, Iterations: 4
#       Simulation Time: 0.0615 s  of  0.5 s
#
# Step: Eversion | Increment: 2055, Iterations: 4
#       Simulation Time: 0.0617 s  of  0.5 s
#
# Step: Eversion | Increment: 2060, Iterations: 4
#       Simulation Time: 0.0618 s  of  0.5 s
#
# Step: Eversion | Increment: 2065, Iterations: 4
#       Simulation Time: 0.062 s  of  0.5 s
#
# Step: Eversion | Increment: 2070, Iterations: 4
#       Simulation Time: 0.0621 s  of  0.5 s
#
# Step: Eversion | Increment: 2075, Iterations: 4
#       Simulation Time: 0.0623 s  of  0.5 s
#
# Step: Eversion | Increment: 2080, Iterations: 4
#       Simulation Time: 0.0624 s  of  0.5 s
#
# Step: Eversion | Increment: 2085, Iterations: 4
#       Simulation Time: 0.0626 s  of  0.5 s
#
# Step: Eversion | Increment: 2090, Iterations: 4
#       Simulation Time: 0.0627 s  of  0.5 s
#
# Step: Eversion | Increment: 2095, Iterations: 4
#       Simulation Time: 0.0629 s  of  0.5 s
#
# Step: Eversion | Increment: 2100, Iterations: 4
#       Simulation Time: 0.063 s  of  0.5 s
#
# Step: Eversion | Increment: 2105, Iterations: 4
#       Simulation Time: 0.0632 s  of  0.5 s
#
# Step: Eversion | Increment: 2110, Iterations: 4
#       Simulation Time: 0.0633 s  of  0.5 s
#
# Step: Eversion | Increment: 2115, Iterations: 4
#       Simulation Time: 0.0635 s  of  0.5 s
#
# Step: Eversion | Increment: 2120, Iterations: 4
#       Simulation Time: 0.0636 s  of  0.5 s
#
# Step: Eversion | Increment: 2125, Iterations: 4
#       Simulation Time: 0.0638 s  of  0.5 s
#
# Step: Eversion | Increment: 2130, Iterations: 4
#       Simulation Time: 0.0639 s  of  0.5 s
#
# Step: Eversion | Increment: 2135, Iterations: 4
#       Simulation Time: 0.0641 s  of  0.5 s
#
# Step: Eversion | Increment: 2140, Iterations: 4
#       Simulation Time: 0.0642 s  of  0.5 s
#
# Step: Eversion | Increment: 2145, Iterations: 4
#       Simulation Time: 0.0644 s  of  0.5 s
#
# Step: Eversion | Increment: 2150, Iterations: 4
#       Simulation Time: 0.0645 s  of  0.5 s
#
# Step: Eversion | Increment: 2155, Iterations: 4
#       Simulation Time: 0.0647 s  of  0.5 s
#
# Step: Eversion | Increment: 2160, Iterations: 4
#       Simulation Time: 0.0648 s  of  0.5 s
#
# Step: Eversion | Increment: 2165, Iterations: 4
#       Simulation Time: 0.065 s  of  0.5 s
#
# Step: Eversion | Increment: 2170, Iterations: 4
#       Simulation Time: 0.0651 s  of  0.5 s
#
# Step: Eversion | Increment: 2175, Iterations: 4
#       Simulation Time: 0.0653 s  of  0.5 s
#
# Step: Eversion | Increment: 2180, Iterations: 4
#       Simulation Time: 0.0654 s  of  0.5 s
#
# Step: Eversion | Increment: 2185, Iterations: 4
#       Simulation Time: 0.0656 s  of  0.5 s
#
# Step: Eversion | Increment: 2190, Iterations: 4
#       Simulation Time: 0.0657 s  of  0.5 s
#
# Step: Eversion | Increment: 2195, Iterations: 4
#       Simulation Time: 0.0659 s  of  0.5 s
#
# Step: Eversion | Increment: 2200, Iterations: 4
#       Simulation Time: 0.066 s  of  0.5 s
#
# Step: Eversion | Increment: 2205, Iterations: 4
#       Simulation Time: 0.0662 s  of  0.5 s
#
# Step: Eversion | Increment: 2210, Iterations: 4
#       Simulation Time: 0.0663 s  of  0.5 s
#
# Step: Eversion | Increment: 2215, Iterations: 4
#       Simulation Time: 0.0665 s  of  0.5 s
#
# Step: Eversion | Increment: 2220, Iterations: 4
#       Simulation Time: 0.0666 s  of  0.5 s
#
# Step: Eversion | Increment: 2225, Iterations: 4
#       Simulation Time: 0.0668 s  of  0.5 s
#
# Step: Eversion | Increment: 2230, Iterations: 4
#       Simulation Time: 0.0669 s  of  0.5 s
#
# Step: Eversion | Increment: 2235, Iterations: 4
#       Simulation Time: 0.0671 s  of  0.5 s
#
# Step: Eversion | Increment: 2240, Iterations: 4
#       Simulation Time: 0.0672 s  of  0.5 s
#
# Step: Eversion | Increment: 2245, Iterations: 4
#       Simulation Time: 0.0674 s  of  0.5 s
#
# Step: Eversion | Increment: 2250, Iterations: 4
#       Simulation Time: 0.0675 s  of  0.5 s
#
# Step: Eversion | Increment: 2255, Iterations: 4
#       Simulation Time: 0.0677 s  of  0.5 s
#
# Step: Eversion | Increment: 2260, Iterations: 4
#       Simulation Time: 0.0678 s  of  0.5 s
#
# Step: Eversion | Increment: 2265, Iterations: 4
#       Simulation Time: 0.068 s  of  0.5 s
#
# Step: Eversion | Increment: 2270, Iterations: 4
#       Simulation Time: 0.0681 s  of  0.5 s
#
# Step: Eversion | Increment: 2275, Iterations: 4
#       Simulation Time: 0.0683 s  of  0.5 s
#
# Step: Eversion | Increment: 2280, Iterations: 4
#       Simulation Time: 0.0684 s  of  0.5 s
#
# Step: Eversion | Increment: 2285, Iterations: 4
#       Simulation Time: 0.0686 s  of  0.5 s
#
# Step: Eversion | Increment: 2290, Iterations: 4
#       Simulation Time: 0.0687 s  of  0.5 s
#
# Step: Eversion | Increment: 2295, Iterations: 4
#       Simulation Time: 0.0689 s  of  0.5 s
#
# Step: Eversion | Increment: 2300, Iterations: 5
#       Simulation Time: 0.069 s  of  0.5 s
#
# Step: Eversion | Increment: 2305, Iterations: 5
#       Simulation Time: 0.0692 s  of  0.5 s
#
# Step: Eversion | Increment: 2310, Iterations: 5
#       Simulation Time: 0.0693 s  of  0.5 s
#
# Step: Eversion | Increment: 2315, Iterations: 5
#       Simulation Time: 0.0695 s  of  0.5 s
#
# Step: Eversion | Increment: 2320, Iterations: 5
#       Simulation Time: 0.0696 s  of  0.5 s
#
# Step: Eversion | Increment: 2325, Iterations: 5
#       Simulation Time: 0.0698 s  of  0.5 s
#
# Step: Eversion | Increment: 2330, Iterations: 5
#       Simulation Time: 0.0699 s  of  0.5 s
#
# Step: Eversion | Increment: 2335, Iterations: 5
#       Simulation Time: 0.0701 s  of  0.5 s
#
# Step: Eversion | Increment: 2340, Iterations: 4
#       Simulation Time: 0.0702 s  of  0.5 s
#
# Step: Eversion | Increment: 2345, Iterations: 4
#       Simulation Time: 0.0704 s  of  0.5 s
#
# Step: Eversion | Increment: 2350, Iterations: 4
#       Simulation Time: 0.0705 s  of  0.5 s
#
# Step: Eversion | Increment: 2355, Iterations: 4
#       Simulation Time: 0.0707 s  of  0.5 s
#
# Step: Eversion | Increment: 2360, Iterations: 4
#       Simulation Time: 0.0708 s  of  0.5 s
#
# Step: Eversion | Increment: 2365, Iterations: 4
#       Simulation Time: 0.071 s  of  0.5 s
#
# Step: Eversion | Increment: 2370, Iterations: 4
#       Simulation Time: 0.0711 s  of  0.5 s
#
# Step: Eversion | Increment: 2375, Iterations: 4
#       Simulation Time: 0.0713 s  of  0.5 s
#
# Step: Eversion | Increment: 2380, Iterations: 4
#       Simulation Time: 0.0714 s  of  0.5 s
#
# Step: Eversion | Increment: 2385, Iterations: 4
#       Simulation Time: 0.0716 s  of  0.5 s
#
# Step: Eversion | Increment: 2390, Iterations: 4
#       Simulation Time: 0.0717 s  of  0.5 s
#
# Step: Eversion | Increment: 2395, Iterations: 4
#       Simulation Time: 0.0719 s  of  0.5 s
#
# Step: Eversion | Increment: 2400, Iterations: 4
#       Simulation Time: 0.072 s  of  0.5 s
#
# Step: Eversion | Increment: 2405, Iterations: 4
#       Simulation Time: 0.0722 s  of  0.5 s
#
# Step: Eversion | Increment: 2410, Iterations: 4
#       Simulation Time: 0.0723 s  of  0.5 s
#
# Step: Eversion | Increment: 2415, Iterations: 4
#       Simulation Time: 0.0725 s  of  0.5 s
#
# Step: Eversion | Increment: 2420, Iterations: 4
#       Simulation Time: 0.0726 s  of  0.5 s
#
# Step: Eversion | Increment: 2425, Iterations: 4
#       Simulation Time: 0.0728 s  of  0.5 s
#
# Step: Eversion | Increment: 2430, Iterations: 4
#       Simulation Time: 0.0729 s  of  0.5 s
#
# Step: Eversion | Increment: 2435, Iterations: 4
#       Simulation Time: 0.0731 s  of  0.5 s
#
# Step: Eversion | Increment: 2440, Iterations: 4
#       Simulation Time: 0.0732 s  of  0.5 s
#
# Step: Eversion | Increment: 2445, Iterations: 4
#       Simulation Time: 0.0734 s  of  0.5 s
#
# Step: Eversion | Increment: 2450, Iterations: 4
#       Simulation Time: 0.0735 s  of  0.5 s
#
# Step: Eversion | Increment: 2455, Iterations: 4
#       Simulation Time: 0.0737 s  of  0.5 s
#
# Step: Eversion | Increment: 2460, Iterations: 4
#       Simulation Time: 0.0738 s  of  0.5 s
#
# Step: Eversion | Increment: 2465, Iterations: 4
#       Simulation Time: 0.074 s  of  0.5 s
#
# Step: Eversion | Increment: 2470, Iterations: 4
#       Simulation Time: 0.0741 s  of  0.5 s
#
# Step: Eversion | Increment: 2475, Iterations: 4
#       Simulation Time: 0.0743 s  of  0.5 s
#
# Step: Eversion | Increment: 2480, Iterations: 4
#       Simulation Time: 0.0744 s  of  0.5 s
#
# Step: Eversion | Increment: 2485, Iterations: 4
#       Simulation Time: 0.0746 s  of  0.5 s
#
# Step: Eversion | Increment: 2490, Iterations: 4
#       Simulation Time: 0.0747 s  of  0.5 s
#
# Step: Eversion | Increment: 2495, Iterations: 4
#       Simulation Time: 0.0749 s  of  0.5 s
#
# Step: Eversion | Increment: 2500, Iterations: 4
#       Simulation Time: 0.075 s  of  0.5 s
#
# Step: Eversion | Increment: 2505, Iterations: 4
#       Simulation Time: 0.0752 s  of  0.5 s
#
# Step: Eversion | Increment: 2510, Iterations: 4
#       Simulation Time: 0.0753 s  of  0.5 s
#
# Step: Eversion | Increment: 2515, Iterations: 4
#       Simulation Time: 0.0755 s  of  0.5 s
#
# Step: Eversion | Increment: 2520, Iterations: 4
#       Simulation Time: 0.0756 s  of  0.5 s
#
# Step: Eversion | Increment: 2525, Iterations: 4
#       Simulation Time: 0.0758 s  of  0.5 s
#
# Step: Eversion | Increment: 2530, Iterations: 4
#       Simulation Time: 0.0759 s  of  0.5 s
#
# Step: Eversion | Increment: 2535, Iterations: 4
#       Simulation Time: 0.0761 s  of  0.5 s
#
# Step: Eversion | Increment: 2540, Iterations: 4
#       Simulation Time: 0.0762 s  of  0.5 s
#
# Step: Eversion | Increment: 2545, Iterations: 4
#       Simulation Time: 0.0764 s  of  0.5 s
#
# Step: Eversion | Increment: 2550, Iterations: 4
#       Simulation Time: 0.0765 s  of  0.5 s
#
# Step: Eversion | Increment: 2555, Iterations: 4
#       Simulation Time: 0.0767 s  of  0.5 s
#
# Step: Eversion | Increment: 2560, Iterations: 4
#       Simulation Time: 0.0768 s  of  0.5 s
#
# Step: Eversion | Increment: 2565, Iterations: 4
#       Simulation Time: 0.077 s  of  0.5 s
#
# Step: Eversion | Increment: 2570, Iterations: 4
#       Simulation Time: 0.0771 s  of  0.5 s
#
# Step: Eversion | Increment: 2575, Iterations: 4
#       Simulation Time: 0.0773 s  of  0.5 s
#
# Step: Eversion | Increment: 2580, Iterations: 4
#       Simulation Time: 0.0774 s  of  0.5 s
#
# Step: Eversion | Increment: 2585, Iterations: 4
#       Simulation Time: 0.0776 s  of  0.5 s
#
# Step: Eversion | Increment: 2590, Iterations: 4
#       Simulation Time: 0.0777 s  of  0.5 s
#
# Step: Eversion | Increment: 2595, Iterations: 4
#       Simulation Time: 0.0779 s  of  0.5 s
#
# Step: Eversion | Increment: 2600, Iterations: 4
#       Simulation Time: 0.078 s  of  0.5 s
#
# Step: Eversion | Increment: 2605, Iterations: 4
#       Simulation Time: 0.0782 s  of  0.5 s
#
# Step: Eversion | Increment: 2610, Iterations: 4
#       Simulation Time: 0.0783 s  of  0.5 s
#
# Step: Eversion | Increment: 2615, Iterations: 4
#       Simulation Time: 0.0785 s  of  0.5 s
#
# Step: Eversion | Increment: 2620, Iterations: 4
# ...
#
# Step: Eversion | Increment: 15820, Iterations: 3
#       Simulation Time: 0.4746 s  of  0.5 s
#
# Step: Eversion | Increment: 15825, Iterations: 3
#       Simulation Time: 0.4747 s  of  0.5 s
#
# Step: Eversion | Increment: 15830, Iterations: 3
#       Simulation Time: 0.4749 s  of  0.5 s
#
# Step: Eversion | Increment: 15835, Iterations: 3
#       Simulation Time: 0.475 s  of  0.5 s
#
# Step: Eversion | Increment: 15840, Iterations: 3
#       Simulation Time: 0.4752 s  of  0.5 s
#
# Step: Eversion | Increment: 15845, Iterations: 3
#       Simulation Time: 0.4753 s  of  0.5 s
#
# Step: Eversion | Increment: 15850, Iterations: 3
#       Simulation Time: 0.4755 s  of  0.5 s
#
# Step: Eversion | Increment: 15855, Iterations: 3
#       Simulation Time: 0.4756 s  of  0.5 s
#
# Step: Eversion | Increment: 15860, Iterations: 3
#       Simulation Time: 0.4758 s  of  0.5 s
#
# Step: Eversion | Increment: 15865, Iterations: 3
#       Simulation Time: 0.4759 s  of  0.5 s
#
# Step: Eversion | Increment: 15870, Iterations: 3
#       Simulation Time: 0.4761 s  of  0.5 s
#
# Step: Eversion | Increment: 15875, Iterations: 3
#       Simulation Time: 0.4762 s  of  0.5 s
#
# Step: Eversion | Increment: 15880, Iterations: 3
#       Simulation Time: 0.4764 s  of  0.5 s
#
# Step: Eversion | Increment: 15885, Iterations: 3
#       Simulation Time: 0.4765 s  of  0.5 s
#
# Step: Eversion | Increment: 15890, Iterations: 3
#       Simulation Time: 0.4767 s  of  0.5 s
#
# Step: Eversion | Increment: 15895, Iterations: 3
#       Simulation Time: 0.4768 s  of  0.5 s
#
# Step: Eversion | Increment: 15900, Iterations: 3
#       Simulation Time: 0.477 s  of  0.5 s
#
# Step: Eversion | Increment: 15905, Iterations: 3
#       Simulation Time: 0.4771 s  of  0.5 s
#
# Step: Eversion | Increment: 15910, Iterations: 3
#       Simulation Time: 0.4773 s  of  0.5 s
#
# Step: Eversion | Increment: 15915, Iterations: 3
#       Simulation Time: 0.4774 s  of  0.5 s
#
# Step: Eversion | Increment: 15920, Iterations: 3
#       Simulation Time: 0.4776 s  of  0.5 s
#
# Step: Eversion | Increment: 15925, Iterations: 3
#       Simulation Time: 0.4777 s  of  0.5 s
#
# Step: Eversion | Increment: 15930, Iterations: 3
#       Simulation Time: 0.4779 s  of  0.5 s
#
# Step: Eversion | Increment: 15935, Iterations: 3
#       Simulation Time: 0.478 s  of  0.5 s
#
# Step: Eversion | Increment: 15940, Iterations: 3
#       Simulation Time: 0.4782 s  of  0.5 s
#
# Step: Eversion | Increment: 15945, Iterations: 3
#       Simulation Time: 0.4783 s  of  0.5 s
#
# Step: Eversion | Increment: 15950, Iterations: 3
#       Simulation Time: 0.4785 s  of  0.5 s
#
# Step: Eversion | Increment: 15955, Iterations: 3
#       Simulation Time: 0.4786 s  of  0.5 s
#
# Step: Eversion | Increment: 15960, Iterations: 3
#       Simulation Time: 0.4788 s  of  0.5 s
#
# Step: Eversion | Increment: 15965, Iterations: 3
#       Simulation Time: 0.4789 s  of  0.5 s
#
# Step: Eversion | Increment: 15970, Iterations: 3
#       Simulation Time: 0.4791 s  of  0.5 s
#
# Step: Eversion | Increment: 15975, Iterations: 3
#       Simulation Time: 0.4792 s  of  0.5 s
#
# Step: Eversion | Increment: 15980, Iterations: 3
#       Simulation Time: 0.4794 s  of  0.5 s
#
# Step: Eversion | Increment: 15985, Iterations: 3
#       Simulation Time: 0.4795 s  of  0.5 s
#
# Step: Eversion | Increment: 15990, Iterations: 3
#       Simulation Time: 0.4797 s  of  0.5 s
#
# Step: Eversion | Increment: 15995, Iterations: 3
#       Simulation Time: 0.4798 s  of  0.5 s
#
# Step: Eversion | Increment: 16000, Iterations: 3
#       Simulation Time: 0.48 s  of  0.5 s
#
# Step: Eversion | Increment: 16005, Iterations: 3
#       Simulation Time: 0.4801 s  of  0.5 s
#
# Step: Eversion | Increment: 16010, Iterations: 3
#       Simulation Time: 0.4803 s  of  0.5 s
#
# Step: Eversion | Increment: 16015, Iterations: 3
#       Simulation Time: 0.4804 s  of  0.5 s
#
# Step: Eversion | Increment: 16020, Iterations: 3
#       Simulation Time: 0.4806 s  of  0.5 s
#
# Step: Eversion | Increment: 16025, Iterations: 3
#       Simulation Time: 0.4807 s  of  0.5 s
#
# Step: Eversion | Increment: 16030, Iterations: 3
#       Simulation Time: 0.4809 s  of  0.5 s
#
# Step: Eversion | Increment: 16035, Iterations: 3
#       Simulation Time: 0.481 s  of  0.5 s
#
# Step: Eversion | Increment: 16040, Iterations: 3
#       Simulation Time: 0.4812 s  of  0.5 s
#
# Step: Eversion | Increment: 16045, Iterations: 3
#       Simulation Time: 0.4813 s  of  0.5 s
#
# Step: Eversion | Increment: 16050, Iterations: 3
#       Simulation Time: 0.4815 s  of  0.5 s
#
# Step: Eversion | Increment: 16055, Iterations: 3
#       Simulation Time: 0.4816 s  of  0.5 s
#
# Step: Eversion | Increment: 16060, Iterations: 3
#       Simulation Time: 0.4818 s  of  0.5 s
#
# Step: Eversion | Increment: 16065, Iterations: 3
#       Simulation Time: 0.4819 s  of  0.5 s
#
# Step: Eversion | Increment: 16070, Iterations: 3
#       Simulation Time: 0.4821 s  of  0.5 s
#
# Step: Eversion | Increment: 16075, Iterations: 3
#       Simulation Time: 0.4822 s  of  0.5 s
#
# Step: Eversion | Increment: 16080, Iterations: 3
#       Simulation Time: 0.4824 s  of  0.5 s
#
# Step: Eversion | Increment: 16085, Iterations: 3
#       Simulation Time: 0.4825 s  of  0.5 s
#
# Step: Eversion | Increment: 16090, Iterations: 3
#       Simulation Time: 0.4827 s  of  0.5 s
#
# Step: Eversion | Increment: 16095, Iterations: 3
#       Simulation Time: 0.4828 s  of  0.5 s
#
# Step: Eversion | Increment: 16100, Iterations: 3
#       Simulation Time: 0.483 s  of  0.5 s
#
# Step: Eversion | Increment: 16105, Iterations: 3
#       Simulation Time: 0.4831 s  of  0.5 s
#
# Step: Eversion | Increment: 16110, Iterations: 3
#       Simulation Time: 0.4833 s  of  0.5 s
#
# Step: Eversion | Increment: 16115, Iterations: 3
#       Simulation Time: 0.4834 s  of  0.5 s
#
# Step: Eversion | Increment: 16120, Iterations: 3
#       Simulation Time: 0.4836 s  of  0.5 s
#
# Step: Eversion | Increment: 16125, Iterations: 3
#       Simulation Time: 0.4837 s  of  0.5 s
#
# Step: Eversion | Increment: 16130, Iterations: 3
#       Simulation Time: 0.4839 s  of  0.5 s
#
# Step: Eversion | Increment: 16135, Iterations: 3
#       Simulation Time: 0.484 s  of  0.5 s
#
# Step: Eversion | Increment: 16140, Iterations: 3
#       Simulation Time: 0.4842 s  of  0.5 s
#
# Step: Eversion | Increment: 16145, Iterations: 3
#       Simulation Time: 0.4843 s  of  0.5 s
#
# Step: Eversion | Increment: 16150, Iterations: 3
#       Simulation Time: 0.4845 s  of  0.5 s
#
# Step: Eversion | Increment: 16155, Iterations: 3
#       Simulation Time: 0.4846 s  of  0.5 s
#
# Step: Eversion | Increment: 16160, Iterations: 3
#       Simulation Time: 0.4848 s  of  0.5 s
#
# Step: Eversion | Increment: 16165, Iterations: 3
#       Simulation Time: 0.4849 s  of  0.5 s
#
# Step: Eversion | Increment: 16170, Iterations: 3
#       Simulation Time: 0.4851 s  of  0.5 s
#
# Step: Eversion | Increment: 16175, Iterations: 3
#       Simulation Time: 0.4852 s  of  0.5 s
#
# Step: Eversion | Increment: 16180, Iterations: 3
#       Simulation Time: 0.4854 s  of  0.5 s
#
# Step: Eversion | Increment: 16185, Iterations: 3
#       Simulation Time: 0.4855 s  of  0.5 s
#
# Step: Eversion | Increment: 16190, Iterations: 3
#       Simulation Time: 0.4857 s  of  0.5 s
#
# Step: Eversion | Increment: 16195, Iterations: 3
#       Simulation Time: 0.4858 s  of  0.5 s
#
# Step: Eversion | Increment: 16200, Iterations: 3
#       Simulation Time: 0.486 s  of  0.5 s
#
# Step: Eversion | Increment: 16205, Iterations: 3
#       Simulation Time: 0.4861 s  of  0.5 s
#
# Step: Eversion | Increment: 16210, Iterations: 3
#       Simulation Time: 0.4863 s  of  0.5 s
#
# Step: Eversion | Increment: 16215, Iterations: 3
#       Simulation Time: 0.4864 s  of  0.5 s
#
# Step: Eversion | Increment: 16220, Iterations: 3
#       Simulation Time: 0.4866 s  of  0.5 s
#
# Step: Eversion | Increment: 16225, Iterations: 3
#       Simulation Time: 0.4867 s  of  0.5 s
#
# Step: Eversion | Increment: 16230, Iterations: 3
#       Simulation Time: 0.4869 s  of  0.5 s
#
# Step: Eversion | Increment: 16235, Iterations: 3
#       Simulation Time: 0.487 s  of  0.5 s
#
# Step: Eversion | Increment: 16240, Iterations: 3
#       Simulation Time: 0.4872 s  of  0.5 s
#
# Step: Eversion | Increment: 16245, Iterations: 3
#       Simulation Time: 0.4873 s  of  0.5 s
#
# Step: Eversion | Increment: 16250, Iterations: 3
#       Simulation Time: 0.4875 s  of  0.5 s
#
# Step: Eversion | Increment: 16255, Iterations: 3
#       Simulation Time: 0.4876 s  of  0.5 s
#
# Step: Eversion | Increment: 16260, Iterations: 3
#       Simulation Time: 0.4878 s  of  0.5 s
#
# Step: Eversion | Increment: 16265, Iterations: 3
#       Simulation Time: 0.4879 s  of  0.5 s
#
# Step: Eversion | Increment: 16270, Iterations: 3
#       Simulation Time: 0.4881 s  of  0.5 s
#
# Step: Eversion | Increment: 16275, Iterations: 3
#       Simulation Time: 0.4882 s  of  0.5 s
#
# Step: Eversion | Increment: 16280, Iterations: 3
#       Simulation Time: 0.4884 s  of  0.5 s
#
# Step: Eversion | Increment: 16285, Iterations: 3
#       Simulation Time: 0.4885 s  of  0.5 s
#
# Step: Eversion | Increment: 16290, Iterations: 3
#       Simulation Time: 0.4887 s  of  0.5 s
#
# Step: Eversion | Increment: 16295, Iterations: 3
#       Simulation Time: 0.4888 s  of  0.5 s
#
# Step: Eversion | Increment: 16300, Iterations: 3
#       Simulation Time: 0.489 s  of  0.5 s
#
# Step: Eversion | Increment: 16305, Iterations: 3
#       Simulation Time: 0.4891 s  of  0.5 s
#
# Step: Eversion | Increment: 16310, Iterations: 3
#       Simulation Time: 0.4893 s  of  0.5 s
#
# Step: Eversion | Increment: 16315, Iterations: 3
#       Simulation Time: 0.4894 s  of  0.5 s
#
# Step: Eversion | Increment: 16320, Iterations: 3
#       Simulation Time: 0.4896 s  of  0.5 s
#
# Step: Eversion | Increment: 16325, Iterations: 3
#       Simulation Time: 0.4897 s  of  0.5 s
#
# Step: Eversion | Increment: 16330, Iterations: 3
#       Simulation Time: 0.4899 s  of  0.5 s
#
# Step: Eversion | Increment: 16335, Iterations: 3
#       Simulation Time: 0.49 s  of  0.5 s
#
# Step: Eversion | Increment: 16340, Iterations: 3
#       Simulation Time: 0.4902 s  of  0.5 s
#
# Step: Eversion | Increment: 16345, Iterations: 3
#       Simulation Time: 0.4903 s  of  0.5 s
#
# Step: Eversion | Increment: 16350, Iterations: 3
#       Simulation Time: 0.4905 s  of  0.5 s
#
# Step: Eversion | Increment: 16355, Iterations: 3
#       Simulation Time: 0.4906 s  of  0.5 s
#
# Step: Eversion | Increment: 16360, Iterations: 3
#       Simulation Time: 0.4908 s  of  0.5 s
#
# Step: Eversion | Increment: 16365, Iterations: 3
#       Simulation Time: 0.4909 s  of  0.5 s
#
# Step: Eversion | Increment: 16370, Iterations: 3
#       Simulation Time: 0.4911 s  of  0.5 s
#
# Step: Eversion | Increment: 16375, Iterations: 3
#       Simulation Time: 0.4912 s  of  0.5 s
#
# Step: Eversion | Increment: 16380, Iterations: 3
#       Simulation Time: 0.4914 s  of  0.5 s
#
# Step: Eversion | Increment: 16385, Iterations: 3
#       Simulation Time: 0.4915 s  of  0.5 s
#
# Step: Eversion | Increment: 16390, Iterations: 3
#       Simulation Time: 0.4917 s  of  0.5 s
#
# Step: Eversion | Increment: 16395, Iterations: 3
#       Simulation Time: 0.4918 s  of  0.5 s
#
# Step: Eversion | Increment: 16400, Iterations: 3
#       Simulation Time: 0.492 s  of  0.5 s
#
# Step: Eversion | Increment: 16405, Iterations: 3
#       Simulation Time: 0.4921 s  of  0.5 s
#
# Step: Eversion | Increment: 16410, Iterations: 3
#       Simulation Time: 0.4923 s  of  0.5 s
#
# Step: Eversion | Increment: 16415, Iterations: 3
#       Simulation Time: 0.4924 s  of  0.5 s
#
# Step: Eversion | Increment: 16420, Iterations: 3
#       Simulation Time: 0.4926 s  of  0.5 s
#
# Step: Eversion | Increment: 16425, Iterations: 3
#       Simulation Time: 0.4927 s  of  0.5 s
#
# Step: Eversion | Increment: 16430, Iterations: 3
#       Simulation Time: 0.4929 s  of  0.5 s
#
# Step: Eversion | Increment: 16435, Iterations: 3
#       Simulation Time: 0.493 s  of  0.5 s
#
# Step: Eversion | Increment: 16440, Iterations: 3
#       Simulation Time: 0.4932 s  of  0.5 s
#
# Step: Eversion | Increment: 16445, Iterations: 3
#       Simulation Time: 0.4933 s  of  0.5 s
#
# Step: Eversion | Increment: 16450, Iterations: 3
#       Simulation Time: 0.4935 s  of  0.5 s
#
# Step: Eversion | Increment: 16455, Iterations: 3
#       Simulation Time: 0.4936 s  of  0.5 s
#
# Step: Eversion | Increment: 16460, Iterations: 3
#       Simulation Time: 0.4938 s  of  0.5 s
#
# Step: Eversion | Increment: 16465, Iterations: 3
#       Simulation Time: 0.4939 s  of  0.5 s
#
# Step: Eversion | Increment: 16470, Iterations: 3
#       Simulation Time: 0.4941 s  of  0.5 s
#
# Step: Eversion | Increment: 16475, Iterations: 3
#       Simulation Time: 0.4942 s  of  0.5 s
#
# Step: Eversion | Increment: 16480, Iterations: 3
#       Simulation Time: 0.4944 s  of  0.5 s
#
# Step: Eversion | Increment: 16485, Iterations: 3
#       Simulation Time: 0.4945 s  of  0.5 s
#
# Step: Eversion | Increment: 16490, Iterations: 3
#       Simulation Time: 0.4947 s  of  0.5 s
#
# Step: Eversion | Increment: 16495, Iterations: 3
#       Simulation Time: 0.4948 s  of  0.5 s
#
# Step: Eversion | Increment: 16500, Iterations: 3
#       Simulation Time: 0.495 s  of  0.5 s
#
# Step: Eversion | Increment: 16505, Iterations: 3
#       Simulation Time: 0.4951 s  of  0.5 s
#
# Step: Eversion | Increment: 16510, Iterations: 3
#       Simulation Time: 0.4953 s  of  0.5 s
#
# Step: Eversion | Increment: 16515, Iterations: 3
#       Simulation Time: 0.4954 s  of  0.5 s
#
# Step: Eversion | Increment: 16520, Iterations: 3
#       Simulation Time: 0.4956 s  of  0.5 s
#
# Step: Eversion | Increment: 16525, Iterations: 3
#       Simulation Time: 0.4957 s  of  0.5 s
#
# Step: Eversion | Increment: 16530, Iterations: 3
#       Simulation Time: 0.4959 s  of  0.5 s
#
# Step: Eversion | Increment: 16535, Iterations: 3
#       Simulation Time: 0.496 s  of  0.5 s
#
# Step: Eversion | Increment: 16540, Iterations: 3
#       Simulation Time: 0.4962 s  of  0.5 s
#
# Step: Eversion | Increment: 16545, Iterations: 3
#       Simulation Time: 0.4963 s  of  0.5 s
#
# Step: Eversion | Increment: 16550, Iterations: 3
#       Simulation Time: 0.4965 s  of  0.5 s
#
# Step: Eversion | Increment: 16555, Iterations: 3
#       Simulation Time: 0.4966 s  of  0.5 s
#
# Step: Eversion | Increment: 16560, Iterations: 3
#       Simulation Time: 0.4968 s  of  0.5 s
#
# Step: Eversion | Increment: 16565, Iterations: 3
#       Simulation Time: 0.4969 s  of  0.5 s
#
# Step: Eversion | Increment: 16570, Iterations: 3
#       Simulation Time: 0.4971 s  of  0.5 s
#
# Step: Eversion | Increment: 16575, Iterations: 3
#       Simulation Time: 0.4972 s  of  0.5 s
#
# Step: Eversion | Increment: 16580, Iterations: 3
#       Simulation Time: 0.4974 s  of  0.5 s
#
# Step: Eversion | Increment: 16585, Iterations: 3
#       Simulation Time: 0.4975 s  of  0.5 s
#
# Step: Eversion | Increment: 16590, Iterations: 3
#       Simulation Time: 0.4977 s  of  0.5 s
#
# Step: Eversion | Increment: 16595, Iterations: 3
#       Simulation Time: 0.4978 s  of  0.5 s
#
# Step: Eversion | Increment: 16600, Iterations: 3
#       Simulation Time: 0.498 s  of  0.5 s
#
# Step: Eversion | Increment: 16605, Iterations: 3
#       Simulation Time: 0.4981 s  of  0.5 s
#
# Step: Eversion | Increment: 16610, Iterations: 3
#       Simulation Time: 0.4983 s  of  0.5 s
#
# Step: Eversion | Increment: 16615, Iterations: 3
#       Simulation Time: 0.4984 s  of  0.5 s
#
# Step: Eversion | Increment: 16620, Iterations: 3
#       Simulation Time: 0.4986 s  of  0.5 s
#
# Step: Eversion | Increment: 16625, Iterations: 3
#       Simulation Time: 0.4987 s  of  0.5 s
#
# Step: Eversion | Increment: 16630, Iterations: 3
#       Simulation Time: 0.4989 s  of  0.5 s
#
# Step: Eversion | Increment: 16635, Iterations: 3
#       Simulation Time: 0.499 s  of  0.5 s
#
# Step: Eversion | Increment: 16640, Iterations: 3
#       Simulation Time: 0.4992 s  of  0.5 s
#
# Step: Eversion | Increment: 16645, Iterations: 3
#       Simulation Time: 0.4993 s  of  0.5 s
#
# Step: Eversion | Increment: 16650, Iterations: 3
#       Simulation Time: 0.4995 s  of  0.5 s
#
# Step: Eversion | Increment: 16655, Iterations: 3
#       Simulation Time: 0.4996 s  of  0.5 s
#
# Step: Eversion | Increment: 16660, Iterations: 3
#       Simulation Time: 0.4998 s  of  0.5 s
#
# Step: Eversion | Increment: 16665, Iterations: 3
#       Simulation Time: 0.4999 s  of  0.5 s
#
# -----------------------------------------
# End computation
# ------------------------------------------
# Elapsed real time:  2 days, 9:17:38.724610
# ------------------------------------------

# %% [markdown]
# # Plot results

# %%
        
# Set up font size, initialize colors array
font = {'size'   : 16}
plt.rc('font', **font)
#
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

# only plot as far as timeHist0 has time history for.
ind  = np.argmax(timeHist0)

plt.figure()
plt.axvline(0, c='k', linewidth=1.)
plt.axhline(0, c='k', linewidth=1.)
plt.plot(timeHist0[0:ind], timeHist2[0:ind], linewidth=2.5, \
         color=colors[3])
plt.axis('tight')
plt.xlabel(r"Time (s)")
plt.ylabel(r"$u_2$ at point A (mm)")
plt.grid(linestyle="--", linewidth=0.5, color='b')
#plt.ylim(-4, 12)
#plt.ylim(5,10)
plt.xlim(0.0,step_time)
#plt.xlim(0.9,1.4)

# save figure to file
fig = plt.gcf()
fig.set_size_inches(6, 4)
plt.tight_layout()
plt.savefig("results/hard_magnetic_eversion_Cv.png", dpi=600)
